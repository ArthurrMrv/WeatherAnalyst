# %%
from Days import Days

# %%
a = Days()
a.loadTemp("/Users/arthurmorvan/Desktop/Final_Project/data_temperature.txt")
a.data
# Out:
# {'2023-01-01|new york': <Days.Day at 0x124387950>,
#  '2023-01-02|new york': <Days.Day at 0x12443d910>,
#  '2023-01-03|new york': <Days.Day at 0x104ac6090>,
#  '2023-01-04|new york': <Days.Day at 0x122d29410>,
#  '2023-01-05|new york': <Days.Day at 0x124385f90>,
#  '2023-01-06|new york': <Days.Day at 0x124387c90>,
#  '2023-01-07|new york': <Days.Day at 0x124384390>,
#  '2023-01-08|new york': <Days.Day at 0x1243f3410>,
#  '2023-01-09|new york': <Days.Day at 0x1243f3450>,
#  '2023-01-10|new york': <Days.Day at 0x1229f51d0>,
#  '2023-01-11|new york': <Days.Day at 0x124444590>,
#  '2023-01-12|new york': <Days.Day at 0x124445950>,
#  '2023-01-13|new york': <Days.Day at 0x124445c10>,
#  '2023-01-14|new york': <Days.Day at 0x1244454d0>,
#  '2023-01-15|new york': <Days.Day at 0x124445550>,
#  '2023-01-16|new york': <Days.Day at 0x124445650>,
#  '2023-01-17|new york': <Days.Day at 0x1244456d0>,
#  '2023-01-18|new york': <Days.Day at 0x124445790>,
#  '2023-01-19|new york': <Days.Day at 0x124445850>,
#  '2023-01-20|new york': <Days.Day at 0x124445910>,
#  '2023-01-21|new york': <Days.Day at 0x124445b50>,
#  '2023-01-22|new york': <Days.Day at 0x124446190>,
#  '2023-01-23|new york': <Days.Day at 0x124446210>,
#  '2023-01-24|new york': <Days.Day at 0x124446390>,
#  '2023-01-25|new york': <Days.Day at 0x124446410>,
#  '2023-01-26|new york': <Days.Day at 0x1244464d0>,
#  '2023-01-27|new york': <Days.Day at 0x124446590>,
#  '2023-01-28|new york': <Days.Day at 0x124446650>,
#  '2023-01-29|new york': <Days.Day at 0x124446710>,
#  '2023-01-30|new york': <Days.Day at 0x124446810>,
#  '2023-01-31|new york': <Days.Day at 0x1244468d0>,
#  '2023-01-01|los angeles': <Days.Day at 0x124446c10>,
#  '2023-01-02|los angeles': <Days.Day at 0x124446a10>,
#  '2023-01-03|los angeles': <Days.Day at 0x124446ad0>,
#  '2023-01-04|los angeles': <Days.Day at 0x124446b90>,
#  '2023-01-05|los angeles': <Days.Day at 0x124446c90>,
#  '2023-01-06|los angeles': <Days.Day at 0x124446d50>,
#  '2023-01-07|los angeles': <Days.Day at 0x124446e10>,
#  '2023-01-08|los angeles': <Days.Day at 0x124446ed0>,
#  '2023-01-09|los angeles': <Days.Day at 0x124446f90>,
#  '2023-01-10|los angeles': <Days.Day at 0x124447050>,
#  '2023-01-11|los angeles': <Days.Day at 0x124447110>,
#  '2023-01-12|los angeles': <Days.Day at 0x1244471d0>,
#  '2023-01-13|los angeles': <Days.Day at 0x124447290>,
#  '2023-01-14|los angeles': <Days.Day at 0x124447350>,
#  '2023-01-15|los angeles': <Days.Day at 0x124447410>,
#  '2023-01-16|los angeles': <Days.Day at 0x1244474d0>,
#  '2023-01-17|los angeles': <Days.Day at 0x124447590>,
#  '2023-01-18|los angeles': <Days.Day at 0x124447650>,
#  '2023-01-19|los angeles': <Days.Day at 0x124447710>,
#  '2023-01-20|los angeles': <Days.Day at 0x1244477d0>,
#  '2023-01-21|los angeles': <Days.Day at 0x124447890>,
#  '2023-01-22|los angeles': <Days.Day at 0x124447950>,
#  '2023-01-23|los angeles': <Days.Day at 0x124447a10>,
#  '2023-01-24|los angeles': <Days.Day at 0x124447ad0>,
#  '2023-01-25|los angeles': <Days.Day at 0x124447b90>,
#  '2023-01-26|los angeles': <Days.Day at 0x124447c50>,
#  '2023-01-27|los angeles': <Days.Day at 0x124447d10>,
#  '2023-01-28|los angeles': <Days.Day at 0x124447dd0>,
#  '2023-01-29|los angeles': <Days.Day at 0x124447e90>,
#  '2023-01-30|los angeles': <Days.Day at 0x124447f50>,
#  '2023-01-31|los angeles': <Days.Day at 0x124460050>,
#  '2023-01-01|london': <Days.Day at 0x124460350>,
#  '2023-01-02|london': <Days.Day at 0x1244601d0>,
#  '2023-01-03|london': <Days.Day at 0x124460290>,
#  '2023-01-04|london': <Days.Day at 0x1244603d0>,
#  '2023-01-05|london': <Days.Day at 0x124460490>,
#  '2023-01-06|london': <Days.Day at 0x124460510>,
#  '2023-01-07|london': <Days.Day at 0x124460610>,
#  '2023-01-08|london': <Days.Day at 0x1244606d0>,
#  '2023-01-09|london': <Days.Day at 0x124460790>,
#  '2023-01-10|london': <Days.Day at 0x124460810>,
#  '2023-01-11|london': <Days.Day at 0x124460910>,
#  '2023-01-12|london': <Days.Day at 0x1244609d0>,
#  '2023-01-13|london': <Days.Day at 0x124460a90>,
#  '2023-01-14|london': <Days.Day at 0x124460b50>,
#  '2023-01-15|london': <Days.Day at 0x124460bd0>,
#  '2023-01-16|london': <Days.Day at 0x124460c90>,
#  '2023-01-17|london': <Days.Day at 0x124460d90>,
#  '2023-01-18|london': <Days.Day at 0x124460e50>,
#  '2023-01-19|london': <Days.Day at 0x124460f10>,
#  '2023-01-20|london': <Days.Day at 0x124460fd0>,
#  '2023-01-21|london': <Days.Day at 0x124461050>,
#  '2023-01-22|london': <Days.Day at 0x124461110>,
#  '2023-01-23|london': <Days.Day at 0x124461210>,
#  '2023-01-24|london': <Days.Day at 0x1244612d0>,
#  '2023-01-25|london': <Days.Day at 0x124461350>,
#  '2023-01-26|london': <Days.Day at 0x124461410>,
#  '2023-01-27|london': <Days.Day at 0x1244614d0>,
#  '2023-01-28|london': <Days.Day at 0x1244615d0>,
#  '2023-01-29|london': <Days.Day at 0x124461690>,
#  '2023-01-30|london': <Days.Day at 0x124461750>,
#  '2023-01-31|london': <Days.Day at 0x1244617d0>,
#  '2023-01-01|tokyo': <Days.Day at 0x124461b50>,
#  '2023-01-02|tokyo': <Days.Day at 0x124461950>,
#  '2023-01-03|tokyo': <Days.Day at 0x124461a50>,
#  '2023-01-04|tokyo': <Days.Day at 0x124461ad0>,
#  '2023-01-05|tokyo': <Days.Day at 0x124461bd0>,
#  '2023-01-06|tokyo': <Days.Day at 0x124461c90>,
#  '2023-01-07|tokyo': <Days.Day at 0x124461d50>,
#  '2023-01-08|tokyo': <Days.Day at 0x124461e10>,
#  '2023-01-09|tokyo': <Days.Day at 0x124461ed0>,
#  '2023-01-10|tokyo': <Days.Day at 0x124461f90>,
#  '2023-01-11|tokyo': <Days.Day at 0x124462050>,
#  '2023-01-12|tokyo': <Days.Day at 0x124462110>,
#  '2023-01-13|tokyo': <Days.Day at 0x1244621d0>,
#  '2023-01-14|tokyo': <Days.Day at 0x124462290>,
#  '2023-01-15|tokyo': <Days.Day at 0x124462390>,
#  '2023-01-16|tokyo': <Days.Day at 0x124462450>,
#  '2023-01-17|tokyo': <Days.Day at 0x124462510>,
#  '2023-01-18|tokyo': <Days.Day at 0x124462590>,
#  '2023-01-19|tokyo': <Days.Day at 0x124462650>,
#  '2023-01-20|tokyo': <Days.Day at 0x124462710>,
#  '2023-01-21|tokyo': <Days.Day at 0x1244627d0>,
#  '2023-01-22|tokyo': <Days.Day at 0x124462890>,
#  '2023-01-23|tokyo': <Days.Day at 0x124462950>,
#  '2023-01-24|tokyo': <Days.Day at 0x124462a50>,
#  '2023-01-25|tokyo': <Days.Day at 0x124462ad0>,
#  '2023-01-26|tokyo': <Days.Day at 0x124462b90>,
#  '2023-01-27|tokyo': <Days.Day at 0x124462c50>,
#  '2023-01-28|tokyo': <Days.Day at 0x124462d10>,
#  '2023-01-29|tokyo': <Days.Day at 0x124462e10>,
#  '2023-01-30|tokyo': <Days.Day at 0x124462e90>,
#  '2023-01-31|tokyo': <Days.Day at 0x124462f50>,
#  '2023-01-01|beijing': <Days.Day at 0x124463290>,
#  '2023-01-02|beijing': <Days.Day at 0x1244630d0>,
#  '2023-01-03|beijing': <Days.Day at 0x124463190>,
#  '2023-01-04|beijing': <Days.Day at 0x124463250>,
#  '2023-01-05|beijing': <Days.Day at 0x124463350>,
#  '2023-01-06|beijing': <Days.Day at 0x124463410>,
#  '2023-01-07|beijing': <Days.Day at 0x1244634d0>,
#  '2023-01-08|beijing': <Days.Day at 0x124463590>,
#  '2023-01-09|beijing': <Days.Day at 0x124463650>,
#  '2023-01-10|beijing': <Days.Day at 0x1244636d0>,
#  '2023-01-11|beijing': <Days.Day at 0x124463810>,
#  '2023-01-12|beijing': <Days.Day at 0x124463890>,
#  '2023-01-13|beijing': <Days.Day at 0x124463950>,
#  '2023-01-14|beijing': <Days.Day at 0x124463a50>,
#  '2023-01-15|beijing': <Days.Day at 0x124463ad0>,
#  '2023-01-16|beijing': <Days.Day at 0x124463b50>,
#  '2023-01-17|beijing': <Days.Day at 0x124463c50>,
#  '2023-01-18|beijing': <Days.Day at 0x124463d50>,
#  '2023-01-19|beijing': <Days.Day at 0x124463e10>,
#  '2023-01-20|beijing': <Days.Day at 0x124463e90>,
#  '2023-01-21|beijing': <Days.Day at 0x124463f50>,
#  '2023-01-22|beijing': <Days.Day at 0x124470050>,
#  '2023-01-23|beijing': <Days.Day at 0x124470110>,
#  '2023-01-24|beijing': <Days.Day at 0x124470210>,
#  '2023-01-25|beijing': <Days.Day at 0x124470290>,
#  '2023-01-26|beijing': <Days.Day at 0x124470350>,
#  '2023-01-27|beijing': <Days.Day at 0x124470410>,
#  '2023-01-28|beijing': <Days.Day at 0x1244704d0>,
#  '2023-01-29|beijing': <Days.Day at 0x1244705d0>,
#  '2023-01-30|beijing': <Days.Day at 0x124470650>,
#  '2023-01-31|beijing': <Days.Day at 0x124470710>,
#  '2023-01-01|sydney': <Days.Day at 0x124470a90>,
#  '2023-01-02|sydney': <Days.Day at 0x124470890>,
#  '2023-01-03|sydney': <Days.Day at 0x124470950>,
#  '2023-01-04|sydney': <Days.Day at 0x124470a10>,
#  '2023-01-05|sydney': <Days.Day at 0x124470b10>,
#  '2023-01-06|sydney': <Days.Day at 0x124470bd0>,
#  '2023-01-07|sydney': <Days.Day at 0x124470c90>,
#  '2023-01-08|sydney': <Days.Day at 0x124470d10>,
#  '2023-01-09|sydney': <Days.Day at 0x124470e10>,
#  '2023-01-10|sydney': <Days.Day at 0x124470ed0>,
#  '2023-01-11|sydney': <Days.Day at 0x124470f90>,
#  '2023-01-12|sydney': <Days.Day at 0x124471050>,
#  '2023-01-13|sydney': <Days.Day at 0x1244710d0>,
#  '2023-01-14|sydney': <Days.Day at 0x1244711d0>,
#  '2023-01-15|sydney': <Days.Day at 0x124471290>,
#  '2023-01-16|sydney': <Days.Day at 0x124471350>,
#  '2023-01-17|sydney': <Days.Day at 0x124471410>,
#  '2023-01-18|sydney': <Days.Day at 0x1244714d0>,
#  '2023-01-19|sydney': <Days.Day at 0x124471590>,
#  '2023-01-20|sydney': <Days.Day at 0x124471650>,
#  '2023-01-21|sydney': <Days.Day at 0x124471710>,
#  '2023-01-22|sydney': <Days.Day at 0x1244717d0>,
#  '2023-01-23|sydney': <Days.Day at 0x124471890>,
#  '2023-01-24|sydney': <Days.Day at 0x124471950>,
#  '2023-01-25|sydney': <Days.Day at 0x124471a10>,
#  '2023-01-26|sydney': <Days.Day at 0x124471ad0>,
#  '2023-01-27|sydney': <Days.Day at 0x124471b90>,
#  '2023-01-28|sydney': <Days.Day at 0x124471c50>,
#  '2023-01-29|sydney': <Days.Day at 0x124471d10>,
#  '2023-01-30|sydney': <Days.Day at 0x124471dd0>,
#  '2023-01-31|sydney': <Days.Day at 0x124471e90>,
#  '2023-01-01|paris': <Days.Day at 0x124472190>,
#  '2023-01-02|paris': <Days.Day at 0x124472010>,
#  '2023-01-03|paris': <Days.Day at 0x1244720d0>,
#  '2023-01-04|paris': <Days.Day at 0x124472210>,
#  '2023-01-05|paris': <Days.Day at 0x124472290>,
#  '2023-01-06|paris': <Days.Day at 0x124472390>,
#  '2023-01-07|paris': <Days.Day at 0x124472450>,
#  '2023-01-08|paris': <Days.Day at 0x124472510>,
#  '2023-01-09|paris': <Days.Day at 0x1244725d0>,
#  '2023-01-10|paris': <Days.Day at 0x124472650>,
#  '2023-01-11|paris': <Days.Day at 0x124472750>,
#  '2023-01-12|paris': <Days.Day at 0x124472810>,
#  '2023-01-13|paris': <Days.Day at 0x1244728d0>,
#  '2023-01-14|paris': <Days.Day at 0x124472990>,
#  '2023-01-15|paris': <Days.Day at 0x124472a50>,
#  '2023-01-16|paris': <Days.Day at 0x124472b10>,
#  '2023-01-17|paris': <Days.Day at 0x124472bd0>,
#  '2023-01-18|paris': <Days.Day at 0x124472c90>,
#  '2023-01-19|paris': <Days.Day at 0x124472d50>,
#  '2023-01-20|paris': <Days.Day at 0x124472e10>,
#  '2023-01-21|paris': <Days.Day at 0x124472ed0>,
#  '2023-01-22|paris': <Days.Day at 0x124472f90>,
#  '2023-01-23|paris': <Days.Day at 0x124473050>,
#  '2023-01-24|paris': <Days.Day at 0x124473110>,
#  '2023-01-25|paris': <Days.Day at 0x1244731d0>,
#  '2023-01-26|paris': <Days.Day at 0x124473290>,
#  '2023-01-27|paris': <Days.Day at 0x124473350>,
#  '2023-01-28|paris': <Days.Day at 0x124473410>,
#  '2023-01-29|paris': <Days.Day at 0x1244734d0>,
#  '2023-01-30|paris': <Days.Day at 0x124473590>,
#  '2023-01-31|paris': <Days.Day at 0x124473650>,
#  '2023-01-01|berlin': <Days.Day at 0x124473950>,
#  '2023-01-02|berlin': <Days.Day at 0x1244737d0>,
#  '2023-01-03|berlin': <Days.Day at 0x124473890>,
#  '2023-01-04|berlin': <Days.Day at 0x124473910>,
#  '2023-01-05|berlin': <Days.Day at 0x124473a10>,
#  '2023-01-06|berlin': <Days.Day at 0x124473b10>,
#  '2023-01-07|berlin': <Days.Day at 0x124473b90>,
#  '2023-01-08|berlin': <Days.Day at 0x124473c50>,
#  '2023-01-09|berlin': <Days.Day at 0x124473d10>,
#  '2023-01-10|berlin': <Days.Day at 0x124473d90>,
#  '2023-01-11|berlin': <Days.Day at 0x124473e90>,
#  '2023-01-12|berlin': <Days.Day at 0x124473f50>,
#  '2023-01-13|berlin': <Days.Day at 0x12447c090>,
#  '2023-01-14|berlin': <Days.Day at 0x12447c150>,
#  '2023-01-15|berlin': <Days.Day at 0x12447c1d0>,
#  '2023-01-16|berlin': <Days.Day at 0x12447c290>,
#  '2023-01-17|berlin': <Days.Day at 0x12447c390>,
#  '2023-01-18|berlin': <Days.Day at 0x12447c410>,
#  '2023-01-19|berlin': <Days.Day at 0x12447c510>,
#  '2023-01-20|berlin': <Days.Day at 0x12447c590>,
#  '2023-01-21|berlin': <Days.Day at 0x12447c650>,
#  '2023-01-22|berlin': <Days.Day at 0x12447c710>,
#  '2023-01-23|berlin': <Days.Day at 0x12447c810>,
#  '2023-01-24|berlin': <Days.Day at 0x12447c8d0>,
#  '2023-01-25|berlin': <Days.Day at 0x12447c990>,
#  '2023-01-26|berlin': <Days.Day at 0x12447ca10>,
#  '2023-01-27|berlin': <Days.Day at 0x12447cad0>,
#  '2023-01-28|berlin': <Days.Day at 0x12447cb90>,
#  '2023-01-29|berlin': <Days.Day at 0x12447cc90>,
#  '2023-01-30|berlin': <Days.Day at 0x12447cd50>,
#  '2023-01-31|berlin': <Days.Day at 0x12447ce10>,
#  '2023-01-01|cairo': <Days.Day at 0x12447d110>,
#  '2023-01-02|cairo': <Days.Day at 0x12447cf50>,
#  '2023-01-03|cairo': <Days.Day at 0x12447d050>,
#  '2023-01-04|cairo': <Days.Day at 0x12447d0d0>,
#  '2023-01-05|cairo': <Days.Day at 0x12447d1d0>,
#  '2023-01-06|cairo': <Days.Day at 0x12447d290>,
#  '2023-01-07|cairo': <Days.Day at 0x12447d350>,
#  '2023-01-08|cairo': <Days.Day at 0x12447d410>,
#  '2023-01-09|cairo': <Days.Day at 0x12447d4d0>,
#  '2023-01-10|cairo': <Days.Day at 0x12447d590>,
#  '2023-01-11|cairo': <Days.Day at 0x12447d650>,
#  '2023-01-12|cairo': <Days.Day at 0x12447d710>,
#  '2023-01-13|cairo': <Days.Day at 0x12447d7d0>,
#  '2023-01-14|cairo': <Days.Day at 0x12447d890>,
#  '2023-01-15|cairo': <Days.Day at 0x12447d950>,
#  '2023-01-16|cairo': <Days.Day at 0x12447da10>,
#  '2023-01-17|cairo': <Days.Day at 0x12447dad0>,
#  '2023-01-18|cairo': <Days.Day at 0x12447db90>,
#  '2023-01-19|cairo': <Days.Day at 0x12447dc50>,
#  '2023-01-20|cairo': <Days.Day at 0x12447dd10>,
#  '2023-01-21|cairo': <Days.Day at 0x12447ddd0>,
#  '2023-01-22|cairo': <Days.Day at 0x12447de90>,
#  '2023-01-23|cairo': <Days.Day at 0x12447df50>,
#  '2023-01-24|cairo': <Days.Day at 0x12447e010>,
#  '2023-01-25|cairo': <Days.Day at 0x12447e0d0>,
#  '2023-01-26|cairo': <Days.Day at 0x12447e190>,
#  '2023-01-27|cairo': <Days.Day at 0x12447e250>,
#  '2023-01-28|cairo': <Days.Day at 0x12447e310>,
#  '2023-01-29|cairo': <Days.Day at 0x12447e3d0>,
#  '2023-01-30|cairo': <Days.Day at 0x12447e490>,
#  '2023-01-31|cairo': <Days.Day at 0x12447e550>,
#  '2023-01-01|new delhi': <Days.Day at 0x12447e8d0>,
#  '2023-01-02|new delhi': <Days.Day at 0x12447e6d0>,
#  '2023-01-03|new delhi': <Days.Day at 0x12447e790>,
#  '2023-01-04|new delhi': <Days.Day at 0x12447e850>,
#  '2023-01-05|new delhi': <Days.Day at 0x12447e950>,
#  '2023-01-06|new delhi': <Days.Day at 0x12447ea10>,
#  '2023-01-07|new delhi': <Days.Day at 0x12447ead0>,
#  '2023-01-08|new delhi': <Days.Day at 0x12447eb90>,
#  '2023-01-09|new delhi': <Days.Day at 0x12447ec50>,
#  '2023-01-10|new delhi': <Days.Day at 0x12447ed10>,
#  '2023-01-11|new delhi': <Days.Day at 0x12447edd0>,
#  '2023-01-12|new delhi': <Days.Day at 0x12447ee90>,
#  '2023-01-13|new delhi': <Days.Day at 0x12447ef50>,
#  '2023-01-14|new delhi': <Days.Day at 0x12447f010>,
#  '2023-01-15|new delhi': <Days.Day at 0x12447f090>,
#  '2023-01-16|new delhi': <Days.Day at 0x12447f190>,
#  '2023-01-17|new delhi': <Days.Day at 0x12447f250>,
#  '2023-01-18|new delhi': <Days.Day at 0x12447f310>,
#  '2023-01-19|new delhi': <Days.Day at 0x12447f3d0>,
#  '2023-01-20|new delhi': <Days.Day at 0x12447f450>,
#  '2023-01-21|new delhi': <Days.Day at 0x12447f550>,
#  '2023-01-22|new delhi': <Days.Day at 0x12447f5d0>,
#  '2023-01-23|new delhi': <Days.Day at 0x12447f6d0>,
#  '2023-01-24|new delhi': <Days.Day at 0x12447f790>,
#  '2023-01-25|new delhi': <Days.Day at 0x12447f850>,
#  '2023-01-26|new delhi': <Days.Day at 0x12447f910>,
#  '2023-01-27|new delhi': <Days.Day at 0x12447f990>,
#  '2023-01-28|new delhi': <Days.Day at 0x12447fa90>,
#  '2023-01-29|new delhi': <Days.Day at 0x12447fb10>,
#  '2023-01-30|new delhi': <Days.Day at 0x12447fc10>,
#  '2023-01-31|new delhi': <Days.Day at 0x12447fcd0>}

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print("Average temperature for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getAvgTemperature(c), 2)}°C")
# Out:
# Average temperature for each city:
# Los angeles : 21.65°C
# London : 8.48°C
# Sydney : 30.87°C
# New delhi : 24.1°C
# Berlin : 2.42°C
# Cairo : 23.87°C
# Beijing : 0.74°C
# Paris : 6.74°C
# New york : 4.61°C
# Tokyo : 10.81°C

# %%
print("Total precitpitation for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getTotalPrecipitation(c), 2)}mm")
# Out:
# Total precitpitation for each city:
# Los angeles : 0.0mm
# London : 137.0mm
# Sydney : 2.9mm
# New delhi : 3.6mm
# Berlin : 16.4mm
# Cairo : 0.0mm
# Beijing : 5.4mm
# Paris : 74.0mm
# New york : 233.0mm
# Tokyo : 3.7mm

# %%
print("Minimum and Maximum wind speed for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : Min : {a.getMinWindSpeed(c)}km/h,\n{' '*len(f'{c.capitalize()} : ')}Max : {a.getMaxWindSpeed(c)}km/h")
# Out:
# Minimum and Maximum wind speed for each city:
# Los angeles : Min : 12.0km/h,
#               Max : 20.0km/h
# London : Min : 12.0km/h,
#          Max : 25.0km/h
# Sydney : Min : 14.0km/h,
#          Max : 20.0km/h
# New delhi : Min : 10.0km/h,
#             Max : 22.0km/h
# Berlin : Min : 14.0km/h,
#          Max : 20.0km/h
# Cairo : Min : 14.0km/h,
#         Max : 20.0km/h
# Beijing : Min : 10.0km/h,
#           Max : 18.0km/h
# Paris : Min : 18.0km/h,
#         Max : 24.0km/h
# New york : Min : 10.0km/h,
#            Max : 25.0km/h
# Tokyo : Min : 10.0km/h,
#         Max : 22.0km/h

# %%
a.plotTemperature(*list(a.cities))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a.plotTemperature(c for c in a.cities)
#
# File ~/Desktop/Final_Project/Days.py:127, in Days.plotTemperature(self, *city_names)
#     125 def plotTemperature(self, *city_names):
#     126     for city_name in city_names:
# --> 127         city_weather = self.getCityWeather(city_name)
#     128         plt.plot([day.getDate() for day in city_weather], [day.getMaxTemp() for day in city_weather], label = city_name)
#     129     #affiche labels
#
# File ~/Desktop/Final_Project/Days.py:21, in Days.getCityWeather(self, city_name)
#      20 def getCityWeather(self, city_name):
# ---> 21     return [day for day in self.getDays() if day.getLocation() == city_name.lower()]
#
# File ~/Desktop/Final_Project/Days.py:21, in <listcomp>(.0)
#      20 def getCityWeather(self, city_name):
# ---> 21     return [day for day in self.getDays() if day.getLocation() == city_name.lower()]
#
# AttributeError: 'generator' object has no attribute 'lower'

# %%
a.plotAvgTemperature(*list(a.cities))

# %%
print(a.categorizeDay("New York", "2023-01-15"))
# Out:
# Cold

# %%
print(f"Coldest day in New York :\n{a.coldestDay('New York')}\nHotest day in New York :\n{a.hotestDay('New York')}")
# Out:
# Coldest day in New York :
# Date: 2023-01-08
# Location: new york
# Max Temp: 1.0
# Min Temp: -6.0
# Precipitation: 10.0
# Wind Speed: 18.0
# Humidity: 88.0
# Cloud Cover: 40.0
# CO2 Levels: None
# Sea Level Rise: None
#
# Hotest day in New York :
# Date: 2023-01-03
# Location: new york
# Max Temp: 8.0
# Min Temp: 1.0
# Precipitation: 5.0
# Wind Speed: 15.0
# Humidity: 65.0
# Cloud Cover: 20.0
# CO2 Levels: None
# Sea Level Rise: None

# %%
a.plotCorrelationMatrix("New York")

# %%
a.loadTemp("/Users/arthurmorvan/Desktop/Final_Project/Paris_data_climate.txt")
a.plotCorrelationMatrix("New York")

# %%
a.plotCorrelationMatrix("New York", "Paris")
