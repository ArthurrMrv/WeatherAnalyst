# %%
from Days import Days

# %%
import numpy as np

# %%
a = Days()
a.loadTemp("data_temperature.txt")
a.data
# Out:
# {'2023-01-01|new york': <Days.Day at 0x107c01d50>,
#  '2023-01-02|new york': <Days.Day at 0x107c014d0>,
#  '2023-01-03|new york': <Days.Day at 0x107c021d0>,
#  '2023-01-04|new york': <Days.Day at 0x107c03050>,
#  '2023-01-05|new york': <Days.Day at 0x107c40250>,
#  '2023-01-06|new york': <Days.Day at 0x107c43490>,
#  '2023-01-07|new york': <Days.Day at 0x107c43150>,
#  '2023-01-08|new york': <Days.Day at 0x107c43390>,
#  '2023-01-09|new york': <Days.Day at 0x107c42d50>,
#  '2023-01-10|new york': <Days.Day at 0x107c41810>,
#  '2023-01-11|new york': <Days.Day at 0x107c425d0>,
#  '2023-01-12|new york': <Days.Day at 0x107c42690>,
#  '2023-01-13|new york': <Days.Day at 0x107c427d0>,
#  '2023-01-14|new york': <Days.Day at 0x107c42850>,
#  '2023-01-15|new york': <Days.Day at 0x107c428d0>,
#  '2023-01-16|new york': <Days.Day at 0x107c42990>,
#  '2023-01-17|new york': <Days.Day at 0x107c43450>,
#  '2023-01-18|new york': <Days.Day at 0x107c43350>,
#  '2023-01-19|new york': <Days.Day at 0x107c433d0>,
#  '2023-01-20|new york': <Days.Day at 0x107c43550>,
#  '2023-01-21|new york': <Days.Day at 0x107c43610>,
#  '2023-01-22|new york': <Days.Day at 0x107c436d0>,
#  '2023-01-23|new york': <Days.Day at 0x107c437d0>,
#  '2023-01-24|new york': <Days.Day at 0x107c43890>,
#  '2023-01-25|new york': <Days.Day at 0x107c43910>,
#  '2023-01-26|new york': <Days.Day at 0x107c439d0>,
#  '2023-01-27|new york': <Days.Day at 0x107c43a90>,
#  '2023-01-28|new york': <Days.Day at 0x107c43b50>,
#  '2023-01-29|new york': <Days.Day at 0x107c43c10>,
#  '2023-01-30|new york': <Days.Day at 0x107c43d10>,
#  '2023-01-31|new york': <Days.Day at 0x107c43dd0>,
#  '2023-01-01|los angeles': <Days.Day at 0x107c60150>,
#  '2023-01-02|los angeles': <Days.Day at 0x107c43f10>,
#  '2023-01-03|los angeles': <Days.Day at 0x107c43fd0>,
#  '2023-01-04|los angeles': <Days.Day at 0x107c600d0>,
#  '2023-01-05|los angeles': <Days.Day at 0x107c601d0>,
#  '2023-01-06|los angeles': <Days.Day at 0x107c60290>,
#  '2023-01-07|los angeles': <Days.Day at 0x107c60350>,
#  '2023-01-08|los angeles': <Days.Day at 0x107c60410>,
#  '2023-01-09|los angeles': <Days.Day at 0x107c604d0>,
#  '2023-01-10|los angeles': <Days.Day at 0x107c60590>,
#  '2023-01-11|los angeles': <Days.Day at 0x107c60650>,
#  '2023-01-12|los angeles': <Days.Day at 0x107c60710>,
#  '2023-01-13|los angeles': <Days.Day at 0x107c607d0>,
#  '2023-01-14|los angeles': <Days.Day at 0x107c60890>,
#  '2023-01-15|los angeles': <Days.Day at 0x107c60950>,
#  '2023-01-16|los angeles': <Days.Day at 0x107c60a10>,
#  '2023-01-17|los angeles': <Days.Day at 0x107c60ad0>,
#  '2023-01-18|los angeles': <Days.Day at 0x107c60b90>,
#  '2023-01-19|los angeles': <Days.Day at 0x107c60c50>,
#  '2023-01-20|los angeles': <Days.Day at 0x107c60d10>,
#  '2023-01-21|los angeles': <Days.Day at 0x107c60dd0>,
#  '2023-01-22|los angeles': <Days.Day at 0x107c60e90>,
#  '2023-01-23|los angeles': <Days.Day at 0x107c60f50>,
#  '2023-01-24|los angeles': <Days.Day at 0x107c61010>,
#  '2023-01-25|los angeles': <Days.Day at 0x107c610d0>,
#  '2023-01-26|los angeles': <Days.Day at 0x107c61190>,
#  '2023-01-27|los angeles': <Days.Day at 0x107c61250>,
#  '2023-01-28|los angeles': <Days.Day at 0x107c61310>,
#  '2023-01-29|los angeles': <Days.Day at 0x107c613d0>,
#  '2023-01-30|los angeles': <Days.Day at 0x107c61490>,
#  '2023-01-31|los angeles': <Days.Day at 0x107c61550>,
#  '2023-01-01|london': <Days.Day at 0x107c61850>,
#  '2023-01-02|london': <Days.Day at 0x107c616d0>,
#  '2023-01-03|london': <Days.Day at 0x107c61790>,
#  '2023-01-04|london': <Days.Day at 0x107c618d0>,
#  '2023-01-05|london': <Days.Day at 0x107c61990>,
#  '2023-01-06|london': <Days.Day at 0x107c61a10>,
#  '2023-01-07|london': <Days.Day at 0x107c61b10>,
#  '2023-01-08|london': <Days.Day at 0x107c61bd0>,
#  '2023-01-09|london': <Days.Day at 0x107c61c90>,
#  '2023-01-10|london': <Days.Day at 0x107c61d10>,
#  '2023-01-11|london': <Days.Day at 0x107c61e10>,
#  '2023-01-12|london': <Days.Day at 0x107c61ed0>,
#  '2023-01-13|london': <Days.Day at 0x107c61f90>,
#  '2023-01-14|london': <Days.Day at 0x107c62050>,
#  '2023-01-15|london': <Days.Day at 0x107c620d0>,
#  '2023-01-16|london': <Days.Day at 0x107c62190>,
#  '2023-01-17|london': <Days.Day at 0x107c62290>,
#  '2023-01-18|london': <Days.Day at 0x107c62350>,
#  '2023-01-19|london': <Days.Day at 0x107c62410>,
#  '2023-01-20|london': <Days.Day at 0x107c624d0>,
#  '2023-01-21|london': <Days.Day at 0x107c62550>,
#  '2023-01-22|london': <Days.Day at 0x107c62610>,
#  '2023-01-23|london': <Days.Day at 0x107c62710>,
#  '2023-01-24|london': <Days.Day at 0x107c627d0>,
#  '2023-01-25|london': <Days.Day at 0x107c62850>,
#  '2023-01-26|london': <Days.Day at 0x107c62910>,
#  '2023-01-27|london': <Days.Day at 0x107c629d0>,
#  '2023-01-28|london': <Days.Day at 0x107c62ad0>,
#  '2023-01-29|london': <Days.Day at 0x107c62b90>,
#  '2023-01-30|london': <Days.Day at 0x107c62c50>,
#  '2023-01-31|london': <Days.Day at 0x107c62cd0>,
#  '2023-01-01|tokyo': <Days.Day at 0x107c63050>,
#  '2023-01-02|tokyo': <Days.Day at 0x107c62e50>,
#  '2023-01-03|tokyo': <Days.Day at 0x107c62f50>,
#  '2023-01-04|tokyo': <Days.Day at 0x107c62fd0>,
#  '2023-01-05|tokyo': <Days.Day at 0x107c630d0>,
#  '2023-01-06|tokyo': <Days.Day at 0x107c63190>,
#  '2023-01-07|tokyo': <Days.Day at 0x107c63250>,
#  '2023-01-08|tokyo': <Days.Day at 0x107c63310>,
#  '2023-01-09|tokyo': <Days.Day at 0x107c633d0>,
#  '2023-01-10|tokyo': <Days.Day at 0x107c63490>,
#  '2023-01-11|tokyo': <Days.Day at 0x107c63550>,
#  '2023-01-12|tokyo': <Days.Day at 0x107c63610>,
#  '2023-01-13|tokyo': <Days.Day at 0x107c636d0>,
#  '2023-01-14|tokyo': <Days.Day at 0x107c63790>,
#  '2023-01-15|tokyo': <Days.Day at 0x107c63890>,
#  '2023-01-16|tokyo': <Days.Day at 0x107c63950>,
#  '2023-01-17|tokyo': <Days.Day at 0x107c63a10>,
#  '2023-01-18|tokyo': <Days.Day at 0x107c63a90>,
#  '2023-01-19|tokyo': <Days.Day at 0x107c63b50>,
#  '2023-01-20|tokyo': <Days.Day at 0x107c63c10>,
#  '2023-01-21|tokyo': <Days.Day at 0x107c63cd0>,
#  '2023-01-22|tokyo': <Days.Day at 0x107c63d90>,
#  '2023-01-23|tokyo': <Days.Day at 0x107c63e50>,
#  '2023-01-24|tokyo': <Days.Day at 0x107c63f50>,
#  '2023-01-25|tokyo': <Days.Day at 0x107c63fd0>,
#  '2023-01-26|tokyo': <Days.Day at 0x107c700d0>,
#  '2023-01-27|tokyo': <Days.Day at 0x107c70190>,
#  '2023-01-28|tokyo': <Days.Day at 0x107c70250>,
#  '2023-01-29|tokyo': <Days.Day at 0x107c70350>,
#  '2023-01-30|tokyo': <Days.Day at 0x107c703d0>,
#  '2023-01-31|tokyo': <Days.Day at 0x107c70490>,
#  '2023-01-01|beijing': <Days.Day at 0x107c707d0>,
#  '2023-01-02|beijing': <Days.Day at 0x107c70610>,
#  '2023-01-03|beijing': <Days.Day at 0x107c706d0>,
#  '2023-01-04|beijing': <Days.Day at 0x107c70790>,
#  '2023-01-05|beijing': <Days.Day at 0x107c70890>,
#  '2023-01-06|beijing': <Days.Day at 0x107c70950>,
#  '2023-01-07|beijing': <Days.Day at 0x107c70a10>,
#  '2023-01-08|beijing': <Days.Day at 0x107c70ad0>,
#  '2023-01-09|beijing': <Days.Day at 0x107c70b90>,
#  '2023-01-10|beijing': <Days.Day at 0x107c70c10>,
#  '2023-01-11|beijing': <Days.Day at 0x107c70d50>,
#  '2023-01-12|beijing': <Days.Day at 0x107c70dd0>,
#  '2023-01-13|beijing': <Days.Day at 0x107c70e90>,
#  '2023-01-14|beijing': <Days.Day at 0x107c70f90>,
#  '2023-01-15|beijing': <Days.Day at 0x107c71010>,
#  '2023-01-16|beijing': <Days.Day at 0x107c71090>,
#  '2023-01-17|beijing': <Days.Day at 0x107c71190>,
#  '2023-01-18|beijing': <Days.Day at 0x107c71290>,
#  '2023-01-19|beijing': <Days.Day at 0x107c71350>,
#  '2023-01-20|beijing': <Days.Day at 0x107c713d0>,
#  '2023-01-21|beijing': <Days.Day at 0x107c71490>,
#  '2023-01-22|beijing': <Days.Day at 0x107c71550>,
#  '2023-01-23|beijing': <Days.Day at 0x107c71610>,
#  '2023-01-24|beijing': <Days.Day at 0x107c71710>,
#  '2023-01-25|beijing': <Days.Day at 0x107c71790>,
#  '2023-01-26|beijing': <Days.Day at 0x107c71850>,
#  '2023-01-27|beijing': <Days.Day at 0x107c71910>,
#  '2023-01-28|beijing': <Days.Day at 0x107c719d0>,
#  '2023-01-29|beijing': <Days.Day at 0x107c71ad0>,
#  '2023-01-30|beijing': <Days.Day at 0x107c71b50>,
#  '2023-01-31|beijing': <Days.Day at 0x107c71c10>,
#  '2023-01-01|sydney': <Days.Day at 0x107c71f90>,
#  '2023-01-02|sydney': <Days.Day at 0x107c71d90>,
#  '2023-01-03|sydney': <Days.Day at 0x107c71e50>,
#  '2023-01-04|sydney': <Days.Day at 0x107c71f10>,
#  '2023-01-05|sydney': <Days.Day at 0x107c72010>,
#  '2023-01-06|sydney': <Days.Day at 0x107c720d0>,
#  '2023-01-07|sydney': <Days.Day at 0x107c72190>,
#  '2023-01-08|sydney': <Days.Day at 0x107c72210>,
#  '2023-01-09|sydney': <Days.Day at 0x107c72310>,
#  '2023-01-10|sydney': <Days.Day at 0x107c723d0>,
#  '2023-01-11|sydney': <Days.Day at 0x107c72490>,
#  '2023-01-12|sydney': <Days.Day at 0x107c72550>,
#  '2023-01-13|sydney': <Days.Day at 0x107c725d0>,
#  '2023-01-14|sydney': <Days.Day at 0x107c726d0>,
#  '2023-01-15|sydney': <Days.Day at 0x107c72790>,
#  '2023-01-16|sydney': <Days.Day at 0x107c72850>,
#  '2023-01-17|sydney': <Days.Day at 0x107c72910>,
#  '2023-01-18|sydney': <Days.Day at 0x107c729d0>,
#  '2023-01-19|sydney': <Days.Day at 0x107c72a90>,
#  '2023-01-20|sydney': <Days.Day at 0x107c72b50>,
#  '2023-01-21|sydney': <Days.Day at 0x107c72c10>,
#  '2023-01-22|sydney': <Days.Day at 0x107c72cd0>,
#  '2023-01-23|sydney': <Days.Day at 0x107c72d90>,
#  '2023-01-24|sydney': <Days.Day at 0x107c72e50>,
#  '2023-01-25|sydney': <Days.Day at 0x107c72f10>,
#  '2023-01-26|sydney': <Days.Day at 0x107c72fd0>,
#  '2023-01-27|sydney': <Days.Day at 0x107c73090>,
#  '2023-01-28|sydney': <Days.Day at 0x107c73150>,
#  '2023-01-29|sydney': <Days.Day at 0x107c73210>,
#  '2023-01-30|sydney': <Days.Day at 0x107c732d0>,
#  '2023-01-31|sydney': <Days.Day at 0x107c73390>,
#  '2023-01-01|paris': <Days.Day at 0x107c73690>,
#  '2023-01-02|paris': <Days.Day at 0x107c73510>,
#  '2023-01-03|paris': <Days.Day at 0x107c735d0>,
#  '2023-01-04|paris': <Days.Day at 0x107c73710>,
#  '2023-01-05|paris': <Days.Day at 0x107c73790>,
#  '2023-01-06|paris': <Days.Day at 0x107c73890>,
#  '2023-01-07|paris': <Days.Day at 0x107c73950>,
#  '2023-01-08|paris': <Days.Day at 0x107c73a10>,
#  '2023-01-09|paris': <Days.Day at 0x107c73ad0>,
#  '2023-01-10|paris': <Days.Day at 0x107c73b50>,
#  '2023-01-11|paris': <Days.Day at 0x107c73c50>,
#  '2023-01-12|paris': <Days.Day at 0x107c73d10>,
#  '2023-01-13|paris': <Days.Day at 0x107c73dd0>,
#  '2023-01-14|paris': <Days.Day at 0x107c73e90>,
#  '2023-01-15|paris': <Days.Day at 0x107c73f50>,
#  '2023-01-16|paris': <Days.Day at 0x107c78050>,
#  '2023-01-17|paris': <Days.Day at 0x107c78110>,
#  '2023-01-18|paris': <Days.Day at 0x107c781d0>,
#  '2023-01-19|paris': <Days.Day at 0x107c78290>,
#  '2023-01-20|paris': <Days.Day at 0x107c78350>,
#  '2023-01-21|paris': <Days.Day at 0x107c78410>,
#  '2023-01-22|paris': <Days.Day at 0x107c784d0>,
#  '2023-01-23|paris': <Days.Day at 0x107c78590>,
#  '2023-01-24|paris': <Days.Day at 0x107c78650>,
#  '2023-01-25|paris': <Days.Day at 0x107c78710>,
#  '2023-01-26|paris': <Days.Day at 0x107c787d0>,
#  '2023-01-27|paris': <Days.Day at 0x107c78890>,
#  '2023-01-28|paris': <Days.Day at 0x107c78950>,
#  '2023-01-29|paris': <Days.Day at 0x107c78a10>,
#  '2023-01-30|paris': <Days.Day at 0x107c78ad0>,
#  '2023-01-31|paris': <Days.Day at 0x107c78b90>,
#  '2023-01-01|berlin': <Days.Day at 0x107c78e90>,
#  '2023-01-02|berlin': <Days.Day at 0x107c78d10>,
#  '2023-01-03|berlin': <Days.Day at 0x107c78dd0>,
#  '2023-01-04|berlin': <Days.Day at 0x107c78e50>,
#  '2023-01-05|berlin': <Days.Day at 0x107c78f50>,
#  '2023-01-06|berlin': <Days.Day at 0x107c79050>,
#  '2023-01-07|berlin': <Days.Day at 0x107c790d0>,
#  '2023-01-08|berlin': <Days.Day at 0x107c79190>,
#  '2023-01-09|berlin': <Days.Day at 0x107c79250>,
#  '2023-01-10|berlin': <Days.Day at 0x107c792d0>,
#  '2023-01-11|berlin': <Days.Day at 0x107c793d0>,
#  '2023-01-12|berlin': <Days.Day at 0x107c79490>,
#  '2023-01-13|berlin': <Days.Day at 0x107c79590>,
#  '2023-01-14|berlin': <Days.Day at 0x107c79650>,
#  '2023-01-15|berlin': <Days.Day at 0x107c796d0>,
#  '2023-01-16|berlin': <Days.Day at 0x107c79790>,
#  '2023-01-17|berlin': <Days.Day at 0x107c79890>,
#  '2023-01-18|berlin': <Days.Day at 0x107c79910>,
#  '2023-01-19|berlin': <Days.Day at 0x107c79a10>,
#  '2023-01-20|berlin': <Days.Day at 0x107c79a90>,
#  '2023-01-21|berlin': <Days.Day at 0x107c79b50>,
#  '2023-01-22|berlin': <Days.Day at 0x107c79c10>,
#  '2023-01-23|berlin': <Days.Day at 0x107c79d10>,
#  '2023-01-24|berlin': <Days.Day at 0x107c79dd0>,
#  '2023-01-25|berlin': <Days.Day at 0x107c79e90>,
#  '2023-01-26|berlin': <Days.Day at 0x107c79f10>,
#  '2023-01-27|berlin': <Days.Day at 0x107c79fd0>,
#  '2023-01-28|berlin': <Days.Day at 0x107c7a090>,
#  '2023-01-29|berlin': <Days.Day at 0x107c7a190>,
#  '2023-01-30|berlin': <Days.Day at 0x107c7a250>,
#  '2023-01-31|berlin': <Days.Day at 0x107c7a310>,
#  '2023-01-01|cairo': <Days.Day at 0x107c7a610>,
#  '2023-01-02|cairo': <Days.Day at 0x107c7a450>,
#  '2023-01-03|cairo': <Days.Day at 0x107c7a550>,
#  '2023-01-04|cairo': <Days.Day at 0x107c7a5d0>,
#  '2023-01-05|cairo': <Days.Day at 0x107c7a6d0>,
#  '2023-01-06|cairo': <Days.Day at 0x107c7a790>,
#  '2023-01-07|cairo': <Days.Day at 0x107c7a850>,
#  '2023-01-08|cairo': <Days.Day at 0x107c7a910>,
#  '2023-01-09|cairo': <Days.Day at 0x107c7a9d0>,
#  '2023-01-10|cairo': <Days.Day at 0x107c7aa90>,
#  '2023-01-11|cairo': <Days.Day at 0x107c7ab50>,
#  '2023-01-12|cairo': <Days.Day at 0x107c7ac10>,
#  '2023-01-13|cairo': <Days.Day at 0x107c7acd0>,
#  '2023-01-14|cairo': <Days.Day at 0x107c7ad90>,
#  '2023-01-15|cairo': <Days.Day at 0x107c7ae50>,
#  '2023-01-16|cairo': <Days.Day at 0x107c7af10>,
#  '2023-01-17|cairo': <Days.Day at 0x107c7afd0>,
#  '2023-01-18|cairo': <Days.Day at 0x107c7b090>,
#  '2023-01-19|cairo': <Days.Day at 0x107c7b150>,
#  '2023-01-20|cairo': <Days.Day at 0x107c7b210>,
#  '2023-01-21|cairo': <Days.Day at 0x107c7b2d0>,
#  '2023-01-22|cairo': <Days.Day at 0x107c7b390>,
#  '2023-01-23|cairo': <Days.Day at 0x107c7b450>,
#  '2023-01-24|cairo': <Days.Day at 0x107c7b510>,
#  '2023-01-25|cairo': <Days.Day at 0x107c7b5d0>,
#  '2023-01-26|cairo': <Days.Day at 0x107c7b690>,
#  '2023-01-27|cairo': <Days.Day at 0x107c7b750>,
#  '2023-01-28|cairo': <Days.Day at 0x107c7b810>,
#  '2023-01-29|cairo': <Days.Day at 0x107c7b8d0>,
#  '2023-01-30|cairo': <Days.Day at 0x107c7b990>,
#  '2023-01-31|cairo': <Days.Day at 0x107c7ba50>,
#  '2023-01-01|new delhi': <Days.Day at 0x107c7bdd0>,
#  '2023-01-02|new delhi': <Days.Day at 0x107c7bbd0>,
#  '2023-01-03|new delhi': <Days.Day at 0x107c7bc90>,
#  '2023-01-04|new delhi': <Days.Day at 0x107c7bd50>,
#  '2023-01-05|new delhi': <Days.Day at 0x107c7be50>,
#  '2023-01-06|new delhi': <Days.Day at 0x107c7bf10>,
#  '2023-01-07|new delhi': <Days.Day at 0x107c7bfd0>,
#  '2023-01-08|new delhi': <Days.Day at 0x107c880d0>,
#  '2023-01-09|new delhi': <Days.Day at 0x107c88190>,
#  '2023-01-10|new delhi': <Days.Day at 0x107c88250>,
#  '2023-01-11|new delhi': <Days.Day at 0x107c88310>,
#  '2023-01-12|new delhi': <Days.Day at 0x107c883d0>,
#  '2023-01-13|new delhi': <Days.Day at 0x107c88490>,
#  '2023-01-14|new delhi': <Days.Day at 0x107c88550>,
#  '2023-01-15|new delhi': <Days.Day at 0x107c885d0>,
#  '2023-01-16|new delhi': <Days.Day at 0x107c886d0>,
#  '2023-01-17|new delhi': <Days.Day at 0x107c88790>,
#  '2023-01-18|new delhi': <Days.Day at 0x107c88850>,
#  '2023-01-19|new delhi': <Days.Day at 0x107c88910>,
#  '2023-01-20|new delhi': <Days.Day at 0x107c88990>,
#  '2023-01-21|new delhi': <Days.Day at 0x107c88a90>,
#  '2023-01-22|new delhi': <Days.Day at 0x107c88b10>,
#  '2023-01-23|new delhi': <Days.Day at 0x107c88c10>,
#  '2023-01-24|new delhi': <Days.Day at 0x107c88cd0>,
#  '2023-01-25|new delhi': <Days.Day at 0x107c88d90>,
#  '2023-01-26|new delhi': <Days.Day at 0x107c88e50>,
#  '2023-01-27|new delhi': <Days.Day at 0x107c88ed0>,
#  '2023-01-28|new delhi': <Days.Day at 0x107c88fd0>,
#  '2023-01-29|new delhi': <Days.Day at 0x107c89050>,
#  '2023-01-30|new delhi': <Days.Day at 0x107c89150>,
#  '2023-01-31|new delhi': <Days.Day at 0x107c89210>}

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print("Average temperature for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getAvgTemperature(c), 2)}°C")
# Out:
# Average temperature for each city:
# Beijing : 0.74°C
# Sydney : 30.87°C
# Paris : 6.74°C
# Berlin : 2.42°C
# Cairo : 23.87°C
# New delhi : 24.1°C
# Los angeles : 21.65°C
# New york : 4.61°C
# London : 8.48°C
# Tokyo : 10.81°C

# %%
print("Total precitpitation for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getTotalPrecipitation(c), 2)}mm")
# Out:
# Total precitpitation for each city:
# Beijing : 5.4mm
# Sydney : 2.9mm
# Paris : 74.0mm
# Berlin : 16.4mm
# Cairo : 0.0mm
# New delhi : 3.6mm
# Los angeles : 0.0mm
# New york : 233.0mm
# London : 137.0mm
# Tokyo : 3.7mm

# %%
print("Minimum and Maximum wind speed for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : Min : {a.getMinWindSpeed(c)}km/h,\n{' '*len(f'{c.capitalize()} : ')}Max : {a.getMaxWindSpeed(c)}km/h")
# Out:
# Minimum and Maximum wind speed for each city:
# Beijing : Min : 10.0km/h,
#           Max : 18.0km/h
# Sydney : Min : 14.0km/h,
#          Max : 20.0km/h
# Paris : Min : 18.0km/h,
#         Max : 24.0km/h
# Berlin : Min : 14.0km/h,
#          Max : 20.0km/h
# Cairo : Min : 14.0km/h,
#         Max : 20.0km/h
# New delhi : Min : 10.0km/h,
#             Max : 22.0km/h
# Los angeles : Min : 12.0km/h,
#               Max : 20.0km/h
# New york : Min : 10.0km/h,
#            Max : 25.0km/h
# London : Min : 12.0km/h,
#          Max : 25.0km/h
# Tokyo : Min : 10.0km/h,
#         Max : 22.0km/h

# %%
a.plotTemperature(*list(a.cities))

# %%
a.plotAvgTemperature(*list(a.cities))

# %%
print(a.categorizeDay("New York", "2023-01-15"))
# Out:
# Cold

# %%
print(f"Coldest day in New York :\n{a.coldestDay('New York')}\nHotest day in New York :\n{a.hotestDay('New York')}")
# Out:
# Coldest day in New York :
# Date: 2023-01-08
# Location: new york
# Max Temp: 1.0
# Min Temp: -6.0
# Precipitation: 10.0
# Wind Speed: 18.0
# Humidity: 88.0
# Cloud Cover: 40.0
#
# Hotest day in New York :
# Date: 2023-01-03
# Location: new york
# Max Temp: 8.0
# Min Temp: 1.0
# Precipitation: 5.0
# Wind Speed: 15.0
# Humidity: 65.0
# Cloud Cover: 20.0

# %%
a.plotCorrelationMatrix("New York")

# %%
a.correlationMatrix("New York")
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
a.loadTemp("Paris_data_climate.txt")
a.plotCorrelationMatrix("New York")

# %%
a.plotCorrelationMatrix("New York", "Paris")

# %%
corr_NY = a.correlationMatrix("New York")
corr_NY
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
len(corr_NY)
# Out:
# 2

# %%
corr_NY[0].shape
# Out:
# (6, 6)

# %%
np.max(corr_NY[0][0][2:])
# Out:
# -0.16173547865568008

# %%
#index of where the np max is in the matrix
type(corr_NY[0])
# Out:
# numpy.ndarray

# %%
#where is the most correlated data (except minimum temp)
np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])
# Out:
# 4

# %%
corr_NY[1][np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])]
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('new york')
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('paris')
# Out:
# 'Precipitation'

# %%
a.getCityNames()
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print(a.coldestDay('los angeles'))
# Out:
# Date: 2023-01-06
# Location: los angeles
# Max Temp: 18.0
# Min Temp: 10.0
# Precipitation: 0.0
# Wind Speed: 12.0
# Humidity: 65.0
# Cloud Cover: 18.0

# %%
a.correlationMatrix('los angeles')
# Out:
# (array([[ 1.00000000e+00,  9.49994268e-01,  8.91688777e-01,
#           9.56731686e-04,  8.94116618e-02],
#         [ 9.49994268e-01,  1.00000000e+00,  8.73955359e-01,
#          -2.13100710e-02,  4.97777394e-02],
#         [ 8.91688777e-01,  8.73955359e-01,  1.00000000e+00,
#          -4.97281928e-02, -2.36833834e-02],
#         [ 9.56731686e-04, -2.13100710e-02, -4.97281928e-02,
#           1.00000000e+00,  9.44886482e-01],
#         [ 8.94116618e-02,  4.97777394e-02, -2.36833834e-02,
#           9.44886482e-01,  1.00000000e+00]]),
#  ['Max Temp', 'Min Temp', 'Wind Speed', 'Humidity', 'Cloud Cover'])

# %%
a.plotCorrelationMatrix('los angeles')

# %%
a.factors_max_temp('los angeles')
# Out:
# 'Wind Speed'

# %%
for c in a.getCityNames():
    print(f"max temp in {c.capitalize()} is correlated to {a.factors_max_temp(c)}")
# Out:
# max temp in Beijing is correlated to Wind Speed
# max temp in Sydney is correlated to Wind Speed
# max temp in Paris is correlated to Precipitation
# max temp in Berlin is correlated to Wind Speed
# max temp in Cairo is correlated to Cloud Cover
# max temp in New delhi is correlated to Wind Speed
# max temp in Los angeles is correlated to Wind Speed
# max temp in New york is correlated to Cloud Cover
# max temp in London is correlated to Wind Speed
# max temp in Tokyo is correlated to Wind Speed

# %%
corr_TK = a.correlationMatrix('tokyo')
corr_TK
# Out:
# (array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#          -0.0532858 ],
#         [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#          -0.01049208],
#         [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#          -0.17628808],
#         [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#          -0.32054589],
#         [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#           0.24301979],
#         [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
corr_TK[0]
# Out:
# array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#         -0.0532858 ],
#        [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#         -0.01049208],
#        [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#         -0.17628808],
#        [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#         -0.32054589],
#        [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#          0.24301979],
#        [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#          1.        ]])

# %%
np.abs

# %%
corr_TK[0][0, 2:]
# Out:
# array([0.15981949, 0.54018546, 0.14611816, 0.0532858 ])

# %%
np.max(corr_TK[0][0][2:])
# Out:
# 0.1598194875836748

# %%
corr_TK[1]
# Out:
# ['Max Temp',
#  'Min Temp',
#  'Wind Speed',
#  'Humidity',
#  'Cloud Cover',
#  'Precipitation']

# %%
np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))
# Out:
# (array([0]), array([2]))

# %%
np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:])))
# Out:
# 2

# %%
corr_TK[1][np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))[0])]
# Out:
# 'Max Temp'
