# %%
from Days import Days

# %%
import numpy as np

# %%
a = Days()
a.loadTemp("data_temperature.txt")
a.data
# Out:
# {'2023-01-01|new york': <Days.Day at 0x105ba34d0>,
#  '2023-01-02|new york': <Days.Day at 0x105bfde90>,
#  '2023-01-03|new york': <Days.Day at 0x10535f350>,
#  '2023-01-04|new york': <Days.Day at 0x105b01550>,
#  '2023-01-05|new york': <Days.Day at 0x105b4dbd0>,
#  '2023-01-06|new york': <Days.Day at 0x105ba1f90>,
#  '2023-01-07|new york': <Days.Day at 0x105c44510>,
#  '2023-01-08|new york': <Days.Day at 0x105c44150>,
#  '2023-01-09|new york': <Days.Day at 0x105c45bd0>,
#  '2023-01-10|new york': <Days.Day at 0x105c45490>,
#  '2023-01-11|new york': <Days.Day at 0x105c45550>,
#  '2023-01-12|new york': <Days.Day at 0x105c45590>,
#  '2023-01-13|new york': <Days.Day at 0x105c45710>,
#  '2023-01-14|new york': <Days.Day at 0x105c457d0>,
#  '2023-01-15|new york': <Days.Day at 0x105c45850>,
#  '2023-01-16|new york': <Days.Day at 0x105c46010>,
#  '2023-01-17|new york': <Days.Day at 0x105c460d0>,
#  '2023-01-18|new york': <Days.Day at 0x105c462d0>,
#  '2023-01-19|new york': <Days.Day at 0x105c46210>,
#  '2023-01-20|new york': <Days.Day at 0x105c46390>,
#  '2023-01-21|new york': <Days.Day at 0x105c46450>,
#  '2023-01-22|new york': <Days.Day at 0x105c46510>,
#  '2023-01-23|new york': <Days.Day at 0x105c46610>,
#  '2023-01-24|new york': <Days.Day at 0x105c466d0>,
#  '2023-01-25|new york': <Days.Day at 0x105c46750>,
#  '2023-01-26|new york': <Days.Day at 0x105c46810>,
#  '2023-01-27|new york': <Days.Day at 0x105c468d0>,
#  '2023-01-28|new york': <Days.Day at 0x105c46990>,
#  '2023-01-29|new york': <Days.Day at 0x105c46a50>,
#  '2023-01-30|new york': <Days.Day at 0x105c46b50>,
#  '2023-01-31|new york': <Days.Day at 0x105c46c10>,
#  '2023-01-01|los angeles': <Days.Day at 0x105c46f50>,
#  '2023-01-02|los angeles': <Days.Day at 0x105c46d50>,
#  '2023-01-03|los angeles': <Days.Day at 0x105c46e10>,
#  '2023-01-04|los angeles': <Days.Day at 0x105c46ed0>,
#  '2023-01-05|los angeles': <Days.Day at 0x105c46fd0>,
#  '2023-01-06|los angeles': <Days.Day at 0x105c47090>,
#  '2023-01-07|los angeles': <Days.Day at 0x105c47150>,
#  '2023-01-08|los angeles': <Days.Day at 0x105c47210>,
#  '2023-01-09|los angeles': <Days.Day at 0x105c472d0>,
#  '2023-01-10|los angeles': <Days.Day at 0x105c47390>,
#  '2023-01-11|los angeles': <Days.Day at 0x105c47450>,
#  '2023-01-12|los angeles': <Days.Day at 0x105c47510>,
#  '2023-01-13|los angeles': <Days.Day at 0x105c475d0>,
#  '2023-01-14|los angeles': <Days.Day at 0x105c47690>,
#  '2023-01-15|los angeles': <Days.Day at 0x105c47750>,
#  '2023-01-16|los angeles': <Days.Day at 0x105c47810>,
#  '2023-01-17|los angeles': <Days.Day at 0x105c478d0>,
#  '2023-01-18|los angeles': <Days.Day at 0x105c47990>,
#  '2023-01-19|los angeles': <Days.Day at 0x105c47a50>,
#  '2023-01-20|los angeles': <Days.Day at 0x105c47b10>,
#  '2023-01-21|los angeles': <Days.Day at 0x105c47bd0>,
#  '2023-01-22|los angeles': <Days.Day at 0x105c47c90>,
#  '2023-01-23|los angeles': <Days.Day at 0x105c47d50>,
#  '2023-01-24|los angeles': <Days.Day at 0x105c47e10>,
#  '2023-01-25|los angeles': <Days.Day at 0x105c47ed0>,
#  '2023-01-26|los angeles': <Days.Day at 0x105c47f90>,
#  '2023-01-27|los angeles': <Days.Day at 0x105c64090>,
#  '2023-01-28|los angeles': <Days.Day at 0x105c64150>,
#  '2023-01-29|los angeles': <Days.Day at 0x105c64210>,
#  '2023-01-30|los angeles': <Days.Day at 0x105c642d0>,
#  '2023-01-31|los angeles': <Days.Day at 0x105c64390>,
#  '2023-01-01|london': <Days.Day at 0x105c64690>,
#  '2023-01-02|london': <Days.Day at 0x105c64510>,
#  '2023-01-03|london': <Days.Day at 0x105c645d0>,
#  '2023-01-04|london': <Days.Day at 0x105c64710>,
#  '2023-01-05|london': <Days.Day at 0x105c647d0>,
#  '2023-01-06|london': <Days.Day at 0x105c64850>,
#  '2023-01-07|london': <Days.Day at 0x105c64950>,
#  '2023-01-08|london': <Days.Day at 0x105c64a10>,
#  '2023-01-09|london': <Days.Day at 0x105c64ad0>,
#  '2023-01-10|london': <Days.Day at 0x105c64b50>,
#  '2023-01-11|london': <Days.Day at 0x105c64c50>,
#  '2023-01-12|london': <Days.Day at 0x105c64d10>,
#  '2023-01-13|london': <Days.Day at 0x105c64dd0>,
#  '2023-01-14|london': <Days.Day at 0x105c64e90>,
#  '2023-01-15|london': <Days.Day at 0x105c64f10>,
#  '2023-01-16|london': <Days.Day at 0x105c64fd0>,
#  '2023-01-17|london': <Days.Day at 0x105c650d0>,
#  '2023-01-18|london': <Days.Day at 0x105c65190>,
#  '2023-01-19|london': <Days.Day at 0x105c65250>,
#  '2023-01-20|london': <Days.Day at 0x105c65310>,
#  '2023-01-21|london': <Days.Day at 0x105c65390>,
#  '2023-01-22|london': <Days.Day at 0x105c65450>,
#  '2023-01-23|london': <Days.Day at 0x105c65550>,
#  '2023-01-24|london': <Days.Day at 0x105c65610>,
#  '2023-01-25|london': <Days.Day at 0x105c65690>,
#  '2023-01-26|london': <Days.Day at 0x105c65750>,
#  '2023-01-27|london': <Days.Day at 0x105c65810>,
#  '2023-01-28|london': <Days.Day at 0x105c65910>,
#  '2023-01-29|london': <Days.Day at 0x105c659d0>,
#  '2023-01-30|london': <Days.Day at 0x105c65a90>,
#  '2023-01-31|london': <Days.Day at 0x105c65b10>,
#  '2023-01-01|tokyo': <Days.Day at 0x105c65e90>,
#  '2023-01-02|tokyo': <Days.Day at 0x105c65c90>,
#  '2023-01-03|tokyo': <Days.Day at 0x105c65d90>,
#  '2023-01-04|tokyo': <Days.Day at 0x105c65e10>,
#  '2023-01-05|tokyo': <Days.Day at 0x105c65f10>,
#  '2023-01-06|tokyo': <Days.Day at 0x105c65fd0>,
#  '2023-01-07|tokyo': <Days.Day at 0x105c66090>,
#  '2023-01-08|tokyo': <Days.Day at 0x105c66150>,
#  '2023-01-09|tokyo': <Days.Day at 0x105c66210>,
#  '2023-01-10|tokyo': <Days.Day at 0x105c662d0>,
#  '2023-01-11|tokyo': <Days.Day at 0x105c66390>,
#  '2023-01-12|tokyo': <Days.Day at 0x105c66450>,
#  '2023-01-13|tokyo': <Days.Day at 0x105c66510>,
#  '2023-01-14|tokyo': <Days.Day at 0x105c665d0>,
#  '2023-01-15|tokyo': <Days.Day at 0x105c666d0>,
#  '2023-01-16|tokyo': <Days.Day at 0x105c66790>,
#  '2023-01-17|tokyo': <Days.Day at 0x105c66850>,
#  '2023-01-18|tokyo': <Days.Day at 0x105c668d0>,
#  '2023-01-19|tokyo': <Days.Day at 0x105c66990>,
#  '2023-01-20|tokyo': <Days.Day at 0x105c66a50>,
#  '2023-01-21|tokyo': <Days.Day at 0x105c66b10>,
#  '2023-01-22|tokyo': <Days.Day at 0x105c66bd0>,
#  '2023-01-23|tokyo': <Days.Day at 0x105c66c90>,
#  '2023-01-24|tokyo': <Days.Day at 0x105c66d90>,
#  '2023-01-25|tokyo': <Days.Day at 0x105c66e10>,
#  '2023-01-26|tokyo': <Days.Day at 0x105c66ed0>,
#  '2023-01-27|tokyo': <Days.Day at 0x105c66f90>,
#  '2023-01-28|tokyo': <Days.Day at 0x105c67050>,
#  '2023-01-29|tokyo': <Days.Day at 0x105c67150>,
#  '2023-01-30|tokyo': <Days.Day at 0x105c671d0>,
#  '2023-01-31|tokyo': <Days.Day at 0x105c67290>,
#  '2023-01-01|beijing': <Days.Day at 0x105c675d0>,
#  '2023-01-02|beijing': <Days.Day at 0x105c67410>,
#  '2023-01-03|beijing': <Days.Day at 0x105c674d0>,
#  '2023-01-04|beijing': <Days.Day at 0x105c67590>,
#  '2023-01-05|beijing': <Days.Day at 0x105c67690>,
#  '2023-01-06|beijing': <Days.Day at 0x105c67750>,
#  '2023-01-07|beijing': <Days.Day at 0x105c67810>,
#  '2023-01-08|beijing': <Days.Day at 0x105c678d0>,
#  '2023-01-09|beijing': <Days.Day at 0x105c67990>,
#  '2023-01-10|beijing': <Days.Day at 0x105c67a10>,
#  '2023-01-11|beijing': <Days.Day at 0x105c67b50>,
#  '2023-01-12|beijing': <Days.Day at 0x105c67bd0>,
#  '2023-01-13|beijing': <Days.Day at 0x105c67c90>,
#  '2023-01-14|beijing': <Days.Day at 0x105c67d90>,
#  '2023-01-15|beijing': <Days.Day at 0x105c67e10>,
#  '2023-01-16|beijing': <Days.Day at 0x105c67e90>,
#  '2023-01-17|beijing': <Days.Day at 0x105c67f90>,
#  '2023-01-18|beijing': <Days.Day at 0x105c700d0>,
#  '2023-01-19|beijing': <Days.Day at 0x105c70190>,
#  '2023-01-20|beijing': <Days.Day at 0x105c70210>,
#  '2023-01-21|beijing': <Days.Day at 0x105c702d0>,
#  '2023-01-22|beijing': <Days.Day at 0x105c70390>,
#  '2023-01-23|beijing': <Days.Day at 0x105c70450>,
#  '2023-01-24|beijing': <Days.Day at 0x105c70550>,
#  '2023-01-25|beijing': <Days.Day at 0x105c705d0>,
#  '2023-01-26|beijing': <Days.Day at 0x105c70690>,
#  '2023-01-27|beijing': <Days.Day at 0x105c70750>,
#  '2023-01-28|beijing': <Days.Day at 0x105c70810>,
#  '2023-01-29|beijing': <Days.Day at 0x105c70910>,
#  '2023-01-30|beijing': <Days.Day at 0x105c70990>,
#  '2023-01-31|beijing': <Days.Day at 0x105c70a50>,
#  '2023-01-01|sydney': <Days.Day at 0x105c70dd0>,
#  '2023-01-02|sydney': <Days.Day at 0x105c70bd0>,
#  '2023-01-03|sydney': <Days.Day at 0x105c70c90>,
#  '2023-01-04|sydney': <Days.Day at 0x105c70d50>,
#  '2023-01-05|sydney': <Days.Day at 0x105c70e50>,
#  '2023-01-06|sydney': <Days.Day at 0x105c70f10>,
#  '2023-01-07|sydney': <Days.Day at 0x105c70fd0>,
#  '2023-01-08|sydney': <Days.Day at 0x105c71050>,
#  '2023-01-09|sydney': <Days.Day at 0x105c71150>,
#  '2023-01-10|sydney': <Days.Day at 0x105c71210>,
#  '2023-01-11|sydney': <Days.Day at 0x105c712d0>,
#  '2023-01-12|sydney': <Days.Day at 0x105c71390>,
#  '2023-01-13|sydney': <Days.Day at 0x105c71410>,
#  '2023-01-14|sydney': <Days.Day at 0x105c71510>,
#  '2023-01-15|sydney': <Days.Day at 0x105c715d0>,
#  '2023-01-16|sydney': <Days.Day at 0x105c71690>,
#  '2023-01-17|sydney': <Days.Day at 0x105c71750>,
#  '2023-01-18|sydney': <Days.Day at 0x105c71810>,
#  '2023-01-19|sydney': <Days.Day at 0x105c718d0>,
#  '2023-01-20|sydney': <Days.Day at 0x105c71990>,
#  '2023-01-21|sydney': <Days.Day at 0x105c71a50>,
#  '2023-01-22|sydney': <Days.Day at 0x105c71b10>,
#  '2023-01-23|sydney': <Days.Day at 0x105c71bd0>,
#  '2023-01-24|sydney': <Days.Day at 0x105c71c90>,
#  '2023-01-25|sydney': <Days.Day at 0x105c71d50>,
#  '2023-01-26|sydney': <Days.Day at 0x105c71e10>,
#  '2023-01-27|sydney': <Days.Day at 0x105c71ed0>,
#  '2023-01-28|sydney': <Days.Day at 0x105c71f90>,
#  '2023-01-29|sydney': <Days.Day at 0x105c72050>,
#  '2023-01-30|sydney': <Days.Day at 0x105c72110>,
#  '2023-01-31|sydney': <Days.Day at 0x105c721d0>,
#  '2023-01-01|paris': <Days.Day at 0x105c724d0>,
#  '2023-01-02|paris': <Days.Day at 0x105c72350>,
#  '2023-01-03|paris': <Days.Day at 0x105c72410>,
#  '2023-01-04|paris': <Days.Day at 0x105c72550>,
#  '2023-01-05|paris': <Days.Day at 0x105c725d0>,
#  '2023-01-06|paris': <Days.Day at 0x105c726d0>,
#  '2023-01-07|paris': <Days.Day at 0x105c72790>,
#  '2023-01-08|paris': <Days.Day at 0x105c72850>,
#  '2023-01-09|paris': <Days.Day at 0x105c72910>,
#  '2023-01-10|paris': <Days.Day at 0x105c72990>,
#  '2023-01-11|paris': <Days.Day at 0x105c72a90>,
#  '2023-01-12|paris': <Days.Day at 0x105c72b50>,
#  '2023-01-13|paris': <Days.Day at 0x105c72c10>,
#  '2023-01-14|paris': <Days.Day at 0x105c72cd0>,
#  '2023-01-15|paris': <Days.Day at 0x105c72d90>,
#  '2023-01-16|paris': <Days.Day at 0x105c72e50>,
#  '2023-01-17|paris': <Days.Day at 0x105c72f10>,
#  '2023-01-18|paris': <Days.Day at 0x105c72fd0>,
#  '2023-01-19|paris': <Days.Day at 0x105c73090>,
#  '2023-01-20|paris': <Days.Day at 0x105c73150>,
#  '2023-01-21|paris': <Days.Day at 0x105c73210>,
#  '2023-01-22|paris': <Days.Day at 0x105c732d0>,
#  '2023-01-23|paris': <Days.Day at 0x105c73390>,
#  '2023-01-24|paris': <Days.Day at 0x105c73450>,
#  '2023-01-25|paris': <Days.Day at 0x105c73510>,
#  '2023-01-26|paris': <Days.Day at 0x105c735d0>,
#  '2023-01-27|paris': <Days.Day at 0x105c73690>,
#  '2023-01-28|paris': <Days.Day at 0x105c73750>,
#  '2023-01-29|paris': <Days.Day at 0x105c73810>,
#  '2023-01-30|paris': <Days.Day at 0x105c738d0>,
#  '2023-01-31|paris': <Days.Day at 0x105c73990>,
#  '2023-01-01|berlin': <Days.Day at 0x105c73c90>,
#  '2023-01-02|berlin': <Days.Day at 0x105c73b10>,
#  '2023-01-03|berlin': <Days.Day at 0x105c73bd0>,
#  '2023-01-04|berlin': <Days.Day at 0x105c73c50>,
#  '2023-01-05|berlin': <Days.Day at 0x105c73d50>,
#  '2023-01-06|berlin': <Days.Day at 0x105c73e50>,
#  '2023-01-07|berlin': <Days.Day at 0x105c73ed0>,
#  '2023-01-08|berlin': <Days.Day at 0x105c73f90>,
#  '2023-01-09|berlin': <Days.Day at 0x105c7c090>,
#  '2023-01-10|berlin': <Days.Day at 0x105c7c110>,
#  '2023-01-11|berlin': <Days.Day at 0x105c7c210>,
#  '2023-01-12|berlin': <Days.Day at 0x105c7c2d0>,
#  '2023-01-13|berlin': <Days.Day at 0x105c7c3d0>,
#  '2023-01-14|berlin': <Days.Day at 0x105c7c490>,
#  '2023-01-15|berlin': <Days.Day at 0x105c7c510>,
#  '2023-01-16|berlin': <Days.Day at 0x105c7c5d0>,
#  '2023-01-17|berlin': <Days.Day at 0x105c7c6d0>,
#  '2023-01-18|berlin': <Days.Day at 0x105c7c750>,
#  '2023-01-19|berlin': <Days.Day at 0x105c7c850>,
#  '2023-01-20|berlin': <Days.Day at 0x105c7c8d0>,
#  '2023-01-21|berlin': <Days.Day at 0x105c7c990>,
#  '2023-01-22|berlin': <Days.Day at 0x105c7ca50>,
#  '2023-01-23|berlin': <Days.Day at 0x105c7cb50>,
#  '2023-01-24|berlin': <Days.Day at 0x105c7cc10>,
#  '2023-01-25|berlin': <Days.Day at 0x105c7ccd0>,
#  '2023-01-26|berlin': <Days.Day at 0x105c7cd50>,
#  '2023-01-27|berlin': <Days.Day at 0x105c7ce10>,
#  '2023-01-28|berlin': <Days.Day at 0x105c7ced0>,
#  '2023-01-29|berlin': <Days.Day at 0x105c7cfd0>,
#  '2023-01-30|berlin': <Days.Day at 0x105c7d090>,
#  '2023-01-31|berlin': <Days.Day at 0x105c7d150>,
#  '2023-01-01|cairo': <Days.Day at 0x105c7d450>,
#  '2023-01-02|cairo': <Days.Day at 0x105c7d290>,
#  '2023-01-03|cairo': <Days.Day at 0x105c7d390>,
#  '2023-01-04|cairo': <Days.Day at 0x105c7d410>,
#  '2023-01-05|cairo': <Days.Day at 0x105c7d510>,
#  '2023-01-06|cairo': <Days.Day at 0x105c7d5d0>,
#  '2023-01-07|cairo': <Days.Day at 0x105c7d690>,
#  '2023-01-08|cairo': <Days.Day at 0x105c7d750>,
#  '2023-01-09|cairo': <Days.Day at 0x105c7d810>,
#  '2023-01-10|cairo': <Days.Day at 0x105c7d8d0>,
#  '2023-01-11|cairo': <Days.Day at 0x105c7d990>,
#  '2023-01-12|cairo': <Days.Day at 0x105c7da50>,
#  '2023-01-13|cairo': <Days.Day at 0x105c7db10>,
#  '2023-01-14|cairo': <Days.Day at 0x105c7dbd0>,
#  '2023-01-15|cairo': <Days.Day at 0x105c7dc90>,
#  '2023-01-16|cairo': <Days.Day at 0x105c7dd50>,
#  '2023-01-17|cairo': <Days.Day at 0x105c7de10>,
#  '2023-01-18|cairo': <Days.Day at 0x105c7ded0>,
#  '2023-01-19|cairo': <Days.Day at 0x105c7df90>,
#  '2023-01-20|cairo': <Days.Day at 0x105c7e050>,
#  '2023-01-21|cairo': <Days.Day at 0x105c7e110>,
#  '2023-01-22|cairo': <Days.Day at 0x105c7e1d0>,
#  '2023-01-23|cairo': <Days.Day at 0x105c7e290>,
#  '2023-01-24|cairo': <Days.Day at 0x105c7e350>,
#  '2023-01-25|cairo': <Days.Day at 0x105c7e410>,
#  '2023-01-26|cairo': <Days.Day at 0x105c7e4d0>,
#  '2023-01-27|cairo': <Days.Day at 0x105c7e590>,
#  '2023-01-28|cairo': <Days.Day at 0x105c7e650>,
#  '2023-01-29|cairo': <Days.Day at 0x105c7e710>,
#  '2023-01-30|cairo': <Days.Day at 0x105c7e7d0>,
#  '2023-01-31|cairo': <Days.Day at 0x105c7e890>,
#  '2023-01-01|new delhi': <Days.Day at 0x105c7ec10>,
#  '2023-01-02|new delhi': <Days.Day at 0x105c7ea10>,
#  '2023-01-03|new delhi': <Days.Day at 0x105c7ead0>,
#  '2023-01-04|new delhi': <Days.Day at 0x105c7eb90>,
#  '2023-01-05|new delhi': <Days.Day at 0x105c7ec90>,
#  '2023-01-06|new delhi': <Days.Day at 0x105c7ed50>,
#  '2023-01-07|new delhi': <Days.Day at 0x105c7ee10>,
#  '2023-01-08|new delhi': <Days.Day at 0x105c7eed0>,
#  '2023-01-09|new delhi': <Days.Day at 0x105c7ef90>,
#  '2023-01-10|new delhi': <Days.Day at 0x105c7f050>,
#  '2023-01-11|new delhi': <Days.Day at 0x105c7f110>,
#  '2023-01-12|new delhi': <Days.Day at 0x105c7f1d0>,
#  '2023-01-13|new delhi': <Days.Day at 0x105c7f290>,
#  '2023-01-14|new delhi': <Days.Day at 0x105c7f350>,
#  '2023-01-15|new delhi': <Days.Day at 0x105c7f3d0>,
#  '2023-01-16|new delhi': <Days.Day at 0x105c7f4d0>,
#  '2023-01-17|new delhi': <Days.Day at 0x105c7f590>,
#  '2023-01-18|new delhi': <Days.Day at 0x105c7f650>,
#  '2023-01-19|new delhi': <Days.Day at 0x105c7f710>,
#  '2023-01-20|new delhi': <Days.Day at 0x105c7f790>,
#  '2023-01-21|new delhi': <Days.Day at 0x105c7f890>,
#  '2023-01-22|new delhi': <Days.Day at 0x105c7f910>,
#  '2023-01-23|new delhi': <Days.Day at 0x105c7fa10>,
#  '2023-01-24|new delhi': <Days.Day at 0x105c7fad0>,
#  '2023-01-25|new delhi': <Days.Day at 0x105c7fb90>,
#  '2023-01-26|new delhi': <Days.Day at 0x105c7fc50>,
#  '2023-01-27|new delhi': <Days.Day at 0x105c7fcd0>,
#  '2023-01-28|new delhi': <Days.Day at 0x105c7fdd0>,
#  '2023-01-29|new delhi': <Days.Day at 0x105c7fe50>,
#  '2023-01-30|new delhi': <Days.Day at 0x105c7ff50>,
#  '2023-01-31|new delhi': <Days.Day at 0x105c88050>}

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print("Average temperature for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getAvgTemperature(c), 2)}°C")
# Out:
# Average temperature for each city:
# New york : 4.61°C
# London : 8.48°C
# Beijing : 0.74°C
# Tokyo : 10.81°C
# Berlin : 2.42°C
# Los angeles : 21.65°C
# Paris : 6.74°C
# Sydney : 30.87°C
# Cairo : 23.87°C
# New delhi : 24.1°C

# %%
print("Total precitpitation for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getTotalPrecipitation(c), 2)}mm")
# Out:
# Total precitpitation for each city:
# New york : 233.0mm
# London : 137.0mm
# Beijing : 5.4mm
# Tokyo : 3.7mm
# Berlin : 16.4mm
# Los angeles : 0.0mm
# Paris : 74.0mm
# Sydney : 2.9mm
# Cairo : 0.0mm
# New delhi : 3.6mm

# %%
print("Minimum and Maximum wind speed for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : Min : {a.getMinWindSpeed(c)}km/h,\n{' '*len(f'{c.capitalize()} : ')}Max : {a.getMaxWindSpeed(c)}km/h")
# Out:
# Minimum and Maximum wind speed for each city:
# New york : Min : 10.0km/h,
#            Max : 25.0km/h
# London : Min : 12.0km/h,
#          Max : 25.0km/h
# Beijing : Min : 10.0km/h,
#           Max : 18.0km/h
# Tokyo : Min : 10.0km/h,
#         Max : 22.0km/h
# Berlin : Min : 14.0km/h,
#          Max : 20.0km/h
# Los angeles : Min : 12.0km/h,
#               Max : 20.0km/h
# Paris : Min : 18.0km/h,
#         Max : 24.0km/h
# Sydney : Min : 14.0km/h,
#          Max : 20.0km/h
# Cairo : Min : 14.0km/h,
#         Max : 20.0km/h
# New delhi : Min : 10.0km/h,
#             Max : 22.0km/h

# %%
a.plotTemperature(*list(a.cities))

# %%
a.plotAvgTemperature(*list(a.cities))

# %%
print(a.categorizeDay("New York", "2023-01-15"))
# Out:
# Cold

# %%
print(f"Coldest day in New York :\n{a.coldestDay('New York')}\nHotest day in New York :\n{a.hotestDay('New York')}")
# Out:
# Coldest day in New York :
# Date: 2023-01-08
# Location: new york
# Max Temp: 1.0
# Min Temp: -6.0
# Precipitation: 10.0
# Wind Speed: 18.0
# Humidity: 88.0
# Cloud Cover: 40.0
#
# Hotest day in New York :
# Date: 2023-01-03
# Location: new york
# Max Temp: 8.0
# Min Temp: 1.0
# Precipitation: 5.0
# Wind Speed: 15.0
# Humidity: 65.0
# Cloud Cover: 20.0

# %%
a.plotCorrelationMatrix("New York")

# %%
a.correlationMatrix("New York")
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
a.loadTemp("Paris_data_climate.txt")
a.plotCorrelationMatrix("New York")

# %%
a.plotCorrelationMatrix("New York", "Paris")

# %%
corr_NY = a.correlationMatrix("New York")
corr_NY
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
len(corr_NY)
# Out:
# 2

# %%
corr_NY[0].shape
# Out:
# (6, 6)

# %%
np.max(corr_NY[0][0][2:])
# Out:
# -0.16173547865568008

# %%
#index of where the np max is in the matrix
type(corr_NY[0])
# Out:
# numpy.ndarray

# %%
#where is the most correlated data (except minimum temp)
np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])
# Out:
# 4

# %%
corr_NY[1][np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])]
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('new york')
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('paris')
# Out:
# 'Precipitation'

# %%
a.getCityNames()
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print(a.coldestDay('los angeles'))
# Out:
# Date: 2023-01-06
# Location: los angeles
# Max Temp: 18.0
# Min Temp: 10.0
# Precipitation: 0.0
# Wind Speed: 12.0
# Humidity: 65.0
# Cloud Cover: 18.0

# %%
a.correlationMatrix('los angeles')
# Out:
# (array([[ 1.00000000e+00,  9.49994268e-01,  8.91688777e-01,
#           9.56731686e-04,  8.94116618e-02],
#         [ 9.49994268e-01,  1.00000000e+00,  8.73955359e-01,
#          -2.13100710e-02,  4.97777394e-02],
#         [ 8.91688777e-01,  8.73955359e-01,  1.00000000e+00,
#          -4.97281928e-02, -2.36833834e-02],
#         [ 9.56731686e-04, -2.13100710e-02, -4.97281928e-02,
#           1.00000000e+00,  9.44886482e-01],
#         [ 8.94116618e-02,  4.97777394e-02, -2.36833834e-02,
#           9.44886482e-01,  1.00000000e+00]]),
#  ['Max Temp', 'Min Temp', 'Wind Speed', 'Humidity', 'Cloud Cover'])

# %%
a.plotCorrelationMatrix('los angeles')

# %%
a.factors_max_temp('los angeles')
# Out:
# 'Wind Speed'

# %%
for c in a.getCityNames():
    print(f"max temp in {c.capitalize()} is correlated to {a.factors_max_temp(c)}")
# Out:
# max temp in New york is correlated to Cloud Cover
# max temp in London is correlated to Wind Speed
# max temp in Beijing is correlated to Wind Speed
# max temp in Tokyo is correlated to Wind Speed
# max temp in Berlin is correlated to Wind Speed
# max temp in Los angeles is correlated to Wind Speed
# max temp in Paris is correlated to Precipitation
# max temp in Sydney is correlated to Wind Speed
# max temp in Cairo is correlated to Cloud Cover
# max temp in New delhi is correlated to Wind Speed

# %%
corr_TK = a.correlationMatrix('tokyo')
corr_TK
# Out:
# (array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#          -0.0532858 ],
#         [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#          -0.01049208],
#         [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#          -0.17628808],
#         [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#          -0.32054589],
#         [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#           0.24301979],
#         [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
corr_TK[0]
# Out:
# array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#         -0.0532858 ],
#        [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#         -0.01049208],
#        [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#         -0.17628808],
#        [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#         -0.32054589],
#        [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#          0.24301979],
#        [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#          1.        ]])

# %%
corr_TK[0][0, 2:]
# Out:
# array([ 0.15981949, -0.54018546, -0.14611816, -0.0532858 ])

# %%
np.max(corr_TK[0][0][2:])
# Out:
# 0.1598194875836748

# %%
corr_TK[1]
# Out:
# ['Max Temp',
#  'Min Temp',
#  'Wind Speed',
#  'Humidity',
#  'Cloud Cover',
#  'Precipitation']

# %%
np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))
# Out:
# (array([0]), array([2]))

# %%
np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:])))
# Out:
# 2

# %%
corr_TK[1][np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))[0])]
# Out:
# 'Max Temp'
