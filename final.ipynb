# %%
from Days import Days

# %%
import numpy as np

# %%
a = Days()
a.loadTemp("data_temperature.txt")
a.data
# Out:
# {'2023-01-01|new york': <Days.Day at 0x11f933f90>,
#  '2023-01-02|new york': <Days.Day at 0x11f8eb190>,
#  '2023-01-03|new york': <Days.Day at 0x11fa6bd10>,
#  '2023-01-04|new york': <Days.Day at 0x11f09d150>,
#  '2023-01-05|new york': <Days.Day at 0x11f09f310>,
#  '2023-01-06|new york': <Days.Day at 0x11fb44dd0>,
#  '2023-01-07|new york': <Days.Day at 0x11fb46990>,
#  '2023-01-08|new york': <Days.Day at 0x11fb46b10>,
#  '2023-01-09|new york': <Days.Day at 0x11fb46090>,
#  '2023-01-10|new york': <Days.Day at 0x11fb46410>,
#  '2023-01-11|new york': <Days.Day at 0x11fb45c90>,
#  '2023-01-12|new york': <Days.Day at 0x11fb45d50>,
#  '2023-01-13|new york': <Days.Day at 0x11fb45dd0>,
#  '2023-01-14|new york': <Days.Day at 0x11fb45f10>,
#  '2023-01-15|new york': <Days.Day at 0x11fb45f90>,
#  '2023-01-16|new york': <Days.Day at 0x11fb46050>,
#  '2023-01-17|new york': <Days.Day at 0x11fb46c10>,
#  '2023-01-18|new york': <Days.Day at 0x11fb46a50>,
#  '2023-01-19|new york': <Days.Day at 0x11fb46d90>,
#  '2023-01-20|new york': <Days.Day at 0x11fb46e50>,
#  '2023-01-21|new york': <Days.Day at 0x11fb46f10>,
#  '2023-01-22|new york': <Days.Day at 0x11fb46fd0>,
#  '2023-01-23|new york': <Days.Day at 0x11fb470d0>,
#  '2023-01-24|new york': <Days.Day at 0x11fb47190>,
#  '2023-01-25|new york': <Days.Day at 0x11fb47210>,
#  '2023-01-26|new york': <Days.Day at 0x11fb472d0>,
#  '2023-01-27|new york': <Days.Day at 0x11fb47390>,
#  '2023-01-28|new york': <Days.Day at 0x11fb47450>,
#  '2023-01-29|new york': <Days.Day at 0x11fb47510>,
#  '2023-01-30|new york': <Days.Day at 0x11fb47610>,
#  '2023-01-31|new york': <Days.Day at 0x11fb476d0>,
#  '2023-01-01|los angeles': <Days.Day at 0x11fb47a10>,
#  '2023-01-02|los angeles': <Days.Day at 0x11fb47810>,
#  '2023-01-03|los angeles': <Days.Day at 0x11fb478d0>,
#  '2023-01-04|los angeles': <Days.Day at 0x11fb47990>,
#  '2023-01-05|los angeles': <Days.Day at 0x11fb47a90>,
#  '2023-01-06|los angeles': <Days.Day at 0x11fb47b50>,
#  '2023-01-07|los angeles': <Days.Day at 0x11fb47c10>,
#  '2023-01-08|los angeles': <Days.Day at 0x11fb47cd0>,
#  '2023-01-09|los angeles': <Days.Day at 0x11fb47d90>,
#  '2023-01-10|los angeles': <Days.Day at 0x11fb47e50>,
#  '2023-01-11|los angeles': <Days.Day at 0x11fb47f10>,
#  '2023-01-12|los angeles': <Days.Day at 0x11fb47fd0>,
#  '2023-01-13|los angeles': <Days.Day at 0x11fb600d0>,
#  '2023-01-14|los angeles': <Days.Day at 0x11fb60190>,
#  '2023-01-15|los angeles': <Days.Day at 0x11fb60250>,
#  '2023-01-16|los angeles': <Days.Day at 0x11fb60310>,
#  '2023-01-17|los angeles': <Days.Day at 0x11fb603d0>,
#  '2023-01-18|los angeles': <Days.Day at 0x11fb60490>,
#  '2023-01-19|los angeles': <Days.Day at 0x11fb60550>,
#  '2023-01-20|los angeles': <Days.Day at 0x11fb60610>,
#  '2023-01-21|los angeles': <Days.Day at 0x11fb606d0>,
#  '2023-01-22|los angeles': <Days.Day at 0x11fb60790>,
#  '2023-01-23|los angeles': <Days.Day at 0x11fb60850>,
#  '2023-01-24|los angeles': <Days.Day at 0x11fb60910>,
#  '2023-01-25|los angeles': <Days.Day at 0x11fb609d0>,
#  '2023-01-26|los angeles': <Days.Day at 0x11fb60a90>,
#  '2023-01-27|los angeles': <Days.Day at 0x11fb60b50>,
#  '2023-01-28|los angeles': <Days.Day at 0x11fb60c10>,
#  '2023-01-29|los angeles': <Days.Day at 0x11fb60cd0>,
#  '2023-01-30|los angeles': <Days.Day at 0x11fb60d90>,
#  '2023-01-31|los angeles': <Days.Day at 0x11fb60e50>,
#  '2023-01-01|london': <Days.Day at 0x11fb61150>,
#  '2023-01-02|london': <Days.Day at 0x11fb60fd0>,
#  '2023-01-03|london': <Days.Day at 0x11fb61090>,
#  '2023-01-04|london': <Days.Day at 0x11fb611d0>,
#  '2023-01-05|london': <Days.Day at 0x11fb61290>,
#  '2023-01-06|london': <Days.Day at 0x11fb61310>,
#  '2023-01-07|london': <Days.Day at 0x11fb61410>,
#  '2023-01-08|london': <Days.Day at 0x11fb614d0>,
#  '2023-01-09|london': <Days.Day at 0x11fb61590>,
#  '2023-01-10|london': <Days.Day at 0x11fb61610>,
#  '2023-01-11|london': <Days.Day at 0x11fb61710>,
#  '2023-01-12|london': <Days.Day at 0x11fb617d0>,
#  '2023-01-13|london': <Days.Day at 0x11fb61890>,
#  '2023-01-14|london': <Days.Day at 0x11fb61950>,
#  '2023-01-15|london': <Days.Day at 0x11fb619d0>,
#  '2023-01-16|london': <Days.Day at 0x11fb61a90>,
#  '2023-01-17|london': <Days.Day at 0x11fb61b90>,
#  '2023-01-18|london': <Days.Day at 0x11fb61c50>,
#  '2023-01-19|london': <Days.Day at 0x11fb61d10>,
#  '2023-01-20|london': <Days.Day at 0x11fb61dd0>,
#  '2023-01-21|london': <Days.Day at 0x11fb61e50>,
#  '2023-01-22|london': <Days.Day at 0x11fb61f10>,
#  '2023-01-23|london': <Days.Day at 0x11fb62010>,
#  '2023-01-24|london': <Days.Day at 0x11fb620d0>,
#  '2023-01-25|london': <Days.Day at 0x11fb62150>,
#  '2023-01-26|london': <Days.Day at 0x11fb62210>,
#  '2023-01-27|london': <Days.Day at 0x11fb622d0>,
#  '2023-01-28|london': <Days.Day at 0x11fb623d0>,
#  '2023-01-29|london': <Days.Day at 0x11fb62490>,
#  '2023-01-30|london': <Days.Day at 0x11fb62550>,
#  '2023-01-31|london': <Days.Day at 0x11fb625d0>,
#  '2023-01-01|tokyo': <Days.Day at 0x11fb62950>,
#  '2023-01-02|tokyo': <Days.Day at 0x11fb62750>,
#  '2023-01-03|tokyo': <Days.Day at 0x11fb62850>,
#  '2023-01-04|tokyo': <Days.Day at 0x11fb628d0>,
#  '2023-01-05|tokyo': <Days.Day at 0x11fb629d0>,
#  '2023-01-06|tokyo': <Days.Day at 0x11fb62a90>,
#  '2023-01-07|tokyo': <Days.Day at 0x11fb62b50>,
#  '2023-01-08|tokyo': <Days.Day at 0x11fb62c10>,
#  '2023-01-09|tokyo': <Days.Day at 0x11fb62cd0>,
#  '2023-01-10|tokyo': <Days.Day at 0x11fb62d90>,
#  '2023-01-11|tokyo': <Days.Day at 0x11fb62e50>,
#  '2023-01-12|tokyo': <Days.Day at 0x11fb62f10>,
#  '2023-01-13|tokyo': <Days.Day at 0x11fb62fd0>,
#  '2023-01-14|tokyo': <Days.Day at 0x11fb63090>,
#  '2023-01-15|tokyo': <Days.Day at 0x11fb63190>,
#  '2023-01-16|tokyo': <Days.Day at 0x11fb63250>,
#  '2023-01-17|tokyo': <Days.Day at 0x11fb63310>,
#  '2023-01-18|tokyo': <Days.Day at 0x11fb63390>,
#  '2023-01-19|tokyo': <Days.Day at 0x11fb63450>,
#  '2023-01-20|tokyo': <Days.Day at 0x11fb63510>,
#  '2023-01-21|tokyo': <Days.Day at 0x11fb635d0>,
#  '2023-01-22|tokyo': <Days.Day at 0x11fb63690>,
#  '2023-01-23|tokyo': <Days.Day at 0x11fb63750>,
#  '2023-01-24|tokyo': <Days.Day at 0x11fb63850>,
#  '2023-01-25|tokyo': <Days.Day at 0x11fb638d0>,
#  '2023-01-26|tokyo': <Days.Day at 0x11fb63990>,
#  '2023-01-27|tokyo': <Days.Day at 0x11fb63a50>,
#  '2023-01-28|tokyo': <Days.Day at 0x11fb63b10>,
#  '2023-01-29|tokyo': <Days.Day at 0x11fb63c10>,
#  '2023-01-30|tokyo': <Days.Day at 0x11fb63c90>,
#  '2023-01-31|tokyo': <Days.Day at 0x11fb63d50>,
#  '2023-01-01|beijing': <Days.Day at 0x11fb700d0>,
#  '2023-01-02|beijing': <Days.Day at 0x11fb63ed0>,
#  '2023-01-03|beijing': <Days.Day at 0x11fb63f90>,
#  '2023-01-04|beijing': <Days.Day at 0x11fb70090>,
#  '2023-01-05|beijing': <Days.Day at 0x11fb70190>,
#  '2023-01-06|beijing': <Days.Day at 0x11fb70250>,
#  '2023-01-07|beijing': <Days.Day at 0x11fb70310>,
#  '2023-01-08|beijing': <Days.Day at 0x11fb703d0>,
#  '2023-01-09|beijing': <Days.Day at 0x11fb70490>,
#  '2023-01-10|beijing': <Days.Day at 0x11fb70510>,
#  '2023-01-11|beijing': <Days.Day at 0x11fb70650>,
#  '2023-01-12|beijing': <Days.Day at 0x11fb706d0>,
#  '2023-01-13|beijing': <Days.Day at 0x11fb70790>,
#  '2023-01-14|beijing': <Days.Day at 0x11fb70890>,
#  '2023-01-15|beijing': <Days.Day at 0x11fb70910>,
#  '2023-01-16|beijing': <Days.Day at 0x11fb70990>,
#  '2023-01-17|beijing': <Days.Day at 0x11fb70a90>,
#  '2023-01-18|beijing': <Days.Day at 0x11fb70b90>,
#  '2023-01-19|beijing': <Days.Day at 0x11fb70c50>,
#  '2023-01-20|beijing': <Days.Day at 0x11fb70cd0>,
#  '2023-01-21|beijing': <Days.Day at 0x11fb70d90>,
#  '2023-01-22|beijing': <Days.Day at 0x11fb70e50>,
#  '2023-01-23|beijing': <Days.Day at 0x11fb70f10>,
#  '2023-01-24|beijing': <Days.Day at 0x11fb71010>,
#  '2023-01-25|beijing': <Days.Day at 0x11fb71090>,
#  '2023-01-26|beijing': <Days.Day at 0x11fb71150>,
#  '2023-01-27|beijing': <Days.Day at 0x11fb71210>,
#  '2023-01-28|beijing': <Days.Day at 0x11fb712d0>,
#  '2023-01-29|beijing': <Days.Day at 0x11fb713d0>,
#  '2023-01-30|beijing': <Days.Day at 0x11fb71450>,
#  '2023-01-31|beijing': <Days.Day at 0x11fb71510>,
#  '2023-01-01|sydney': <Days.Day at 0x11fb71890>,
#  '2023-01-02|sydney': <Days.Day at 0x11fb71690>,
#  '2023-01-03|sydney': <Days.Day at 0x11fb71750>,
#  '2023-01-04|sydney': <Days.Day at 0x11fb71810>,
#  '2023-01-05|sydney': <Days.Day at 0x11fb71910>,
#  '2023-01-06|sydney': <Days.Day at 0x11fb719d0>,
#  '2023-01-07|sydney': <Days.Day at 0x11fb71a90>,
#  '2023-01-08|sydney': <Days.Day at 0x11fb71b10>,
#  '2023-01-09|sydney': <Days.Day at 0x11fb71c10>,
#  '2023-01-10|sydney': <Days.Day at 0x11fb71cd0>,
#  '2023-01-11|sydney': <Days.Day at 0x11fb71d90>,
#  '2023-01-12|sydney': <Days.Day at 0x11fb71e50>,
#  '2023-01-13|sydney': <Days.Day at 0x11fb71ed0>,
#  '2023-01-14|sydney': <Days.Day at 0x11fb71fd0>,
#  '2023-01-15|sydney': <Days.Day at 0x11fb72090>,
#  '2023-01-16|sydney': <Days.Day at 0x11fb72150>,
#  '2023-01-17|sydney': <Days.Day at 0x11fb72210>,
#  '2023-01-18|sydney': <Days.Day at 0x11fb722d0>,
#  '2023-01-19|sydney': <Days.Day at 0x11fb72390>,
#  '2023-01-20|sydney': <Days.Day at 0x11fb72450>,
#  '2023-01-21|sydney': <Days.Day at 0x11fb72510>,
#  '2023-01-22|sydney': <Days.Day at 0x11fb725d0>,
#  '2023-01-23|sydney': <Days.Day at 0x11fb72690>,
#  '2023-01-24|sydney': <Days.Day at 0x11fb72750>,
#  '2023-01-25|sydney': <Days.Day at 0x11fb72810>,
#  '2023-01-26|sydney': <Days.Day at 0x11fb728d0>,
#  '2023-01-27|sydney': <Days.Day at 0x11fb72990>,
#  '2023-01-28|sydney': <Days.Day at 0x11fb72a50>,
#  '2023-01-29|sydney': <Days.Day at 0x11fb72b10>,
#  '2023-01-30|sydney': <Days.Day at 0x11fb72bd0>,
#  '2023-01-31|sydney': <Days.Day at 0x11fb72c90>,
#  '2023-01-01|paris': <Days.Day at 0x11fb72f90>,
#  '2023-01-02|paris': <Days.Day at 0x11fb72e10>,
#  '2023-01-03|paris': <Days.Day at 0x11fb72ed0>,
#  '2023-01-04|paris': <Days.Day at 0x11fb73010>,
#  '2023-01-05|paris': <Days.Day at 0x11fb73090>,
#  '2023-01-06|paris': <Days.Day at 0x11fb73190>,
#  '2023-01-07|paris': <Days.Day at 0x11fb73250>,
#  '2023-01-08|paris': <Days.Day at 0x11fb73310>,
#  '2023-01-09|paris': <Days.Day at 0x11fb733d0>,
#  '2023-01-10|paris': <Days.Day at 0x11fb73450>,
#  '2023-01-11|paris': <Days.Day at 0x11fb73550>,
#  '2023-01-12|paris': <Days.Day at 0x11fb73610>,
#  '2023-01-13|paris': <Days.Day at 0x11fb736d0>,
#  '2023-01-14|paris': <Days.Day at 0x11fb73790>,
#  '2023-01-15|paris': <Days.Day at 0x11fb73850>,
#  '2023-01-16|paris': <Days.Day at 0x11fb73910>,
#  '2023-01-17|paris': <Days.Day at 0x11fb739d0>,
#  '2023-01-18|paris': <Days.Day at 0x11fb73a90>,
#  '2023-01-19|paris': <Days.Day at 0x11fb73b50>,
#  '2023-01-20|paris': <Days.Day at 0x11fb73c10>,
#  '2023-01-21|paris': <Days.Day at 0x11fb73cd0>,
#  '2023-01-22|paris': <Days.Day at 0x11fb73d90>,
#  '2023-01-23|paris': <Days.Day at 0x11fb73e50>,
#  '2023-01-24|paris': <Days.Day at 0x11fb73f10>,
#  '2023-01-25|paris': <Days.Day at 0x11fb73fd0>,
#  '2023-01-26|paris': <Days.Day at 0x11fb780d0>,
#  '2023-01-27|paris': <Days.Day at 0x11fb78190>,
#  '2023-01-28|paris': <Days.Day at 0x11fb78250>,
#  '2023-01-29|paris': <Days.Day at 0x11fb78310>,
#  '2023-01-30|paris': <Days.Day at 0x11fb783d0>,
#  '2023-01-31|paris': <Days.Day at 0x11fb78490>,
#  '2023-01-01|berlin': <Days.Day at 0x11fb78790>,
#  '2023-01-02|berlin': <Days.Day at 0x11fb78610>,
#  '2023-01-03|berlin': <Days.Day at 0x11fb786d0>,
#  '2023-01-04|berlin': <Days.Day at 0x11fb78750>,
#  '2023-01-05|berlin': <Days.Day at 0x11fb78850>,
#  '2023-01-06|berlin': <Days.Day at 0x11fb78950>,
#  '2023-01-07|berlin': <Days.Day at 0x11fb789d0>,
#  '2023-01-08|berlin': <Days.Day at 0x11fb78a90>,
#  '2023-01-09|berlin': <Days.Day at 0x11fb78b50>,
#  '2023-01-10|berlin': <Days.Day at 0x11fb78bd0>,
#  '2023-01-11|berlin': <Days.Day at 0x11fb78cd0>,
#  '2023-01-12|berlin': <Days.Day at 0x11fb78d90>,
#  '2023-01-13|berlin': <Days.Day at 0x11fb78e90>,
#  '2023-01-14|berlin': <Days.Day at 0x11fb78f50>,
#  '2023-01-15|berlin': <Days.Day at 0x11fb78fd0>,
#  '2023-01-16|berlin': <Days.Day at 0x11fb79090>,
#  '2023-01-17|berlin': <Days.Day at 0x11fb79190>,
#  '2023-01-18|berlin': <Days.Day at 0x11fb79210>,
#  '2023-01-19|berlin': <Days.Day at 0x11fb79310>,
#  '2023-01-20|berlin': <Days.Day at 0x11fb79390>,
#  '2023-01-21|berlin': <Days.Day at 0x11fb79450>,
#  '2023-01-22|berlin': <Days.Day at 0x11fb79510>,
#  '2023-01-23|berlin': <Days.Day at 0x11fb79610>,
#  '2023-01-24|berlin': <Days.Day at 0x11fb796d0>,
#  '2023-01-25|berlin': <Days.Day at 0x11fb79790>,
#  '2023-01-26|berlin': <Days.Day at 0x11fb79810>,
#  '2023-01-27|berlin': <Days.Day at 0x11fb798d0>,
#  '2023-01-28|berlin': <Days.Day at 0x11fb79990>,
#  '2023-01-29|berlin': <Days.Day at 0x11fb79a90>,
#  '2023-01-30|berlin': <Days.Day at 0x11fb79b50>,
#  '2023-01-31|berlin': <Days.Day at 0x11fb79c10>,
#  '2023-01-01|cairo': <Days.Day at 0x11fb79f10>,
#  '2023-01-02|cairo': <Days.Day at 0x11fb79d50>,
#  '2023-01-03|cairo': <Days.Day at 0x11fb79e50>,
#  '2023-01-04|cairo': <Days.Day at 0x11fb79ed0>,
#  '2023-01-05|cairo': <Days.Day at 0x11fb79fd0>,
#  '2023-01-06|cairo': <Days.Day at 0x11fb7a090>,
#  '2023-01-07|cairo': <Days.Day at 0x11fb7a150>,
#  '2023-01-08|cairo': <Days.Day at 0x11fb7a210>,
#  '2023-01-09|cairo': <Days.Day at 0x11fb7a2d0>,
#  '2023-01-10|cairo': <Days.Day at 0x11fb7a390>,
#  '2023-01-11|cairo': <Days.Day at 0x11fb7a450>,
#  '2023-01-12|cairo': <Days.Day at 0x11fb7a510>,
#  '2023-01-13|cairo': <Days.Day at 0x11fb7a5d0>,
#  '2023-01-14|cairo': <Days.Day at 0x11fb7a690>,
#  '2023-01-15|cairo': <Days.Day at 0x11fb7a750>,
#  '2023-01-16|cairo': <Days.Day at 0x11fb7a810>,
#  '2023-01-17|cairo': <Days.Day at 0x11fb7a8d0>,
#  '2023-01-18|cairo': <Days.Day at 0x11fb7a990>,
#  '2023-01-19|cairo': <Days.Day at 0x11fb7aa50>,
#  '2023-01-20|cairo': <Days.Day at 0x11fb7ab10>,
#  '2023-01-21|cairo': <Days.Day at 0x11fb7abd0>,
#  '2023-01-22|cairo': <Days.Day at 0x11fb7ac90>,
#  '2023-01-23|cairo': <Days.Day at 0x11fb7ad50>,
#  '2023-01-24|cairo': <Days.Day at 0x11fb7ae10>,
#  '2023-01-25|cairo': <Days.Day at 0x11fb7aed0>,
#  '2023-01-26|cairo': <Days.Day at 0x11fb7af90>,
#  '2023-01-27|cairo': <Days.Day at 0x11fb7b050>,
#  '2023-01-28|cairo': <Days.Day at 0x11fb7b110>,
#  '2023-01-29|cairo': <Days.Day at 0x11fb7b1d0>,
#  '2023-01-30|cairo': <Days.Day at 0x11fb7b290>,
#  '2023-01-31|cairo': <Days.Day at 0x11fb7b350>,
#  '2023-01-01|new delhi': <Days.Day at 0x11fb7b6d0>,
#  '2023-01-02|new delhi': <Days.Day at 0x11fb7b4d0>,
#  '2023-01-03|new delhi': <Days.Day at 0x11fb7b590>,
#  '2023-01-04|new delhi': <Days.Day at 0x11fb7b650>,
#  '2023-01-05|new delhi': <Days.Day at 0x11fb7b750>,
#  '2023-01-06|new delhi': <Days.Day at 0x11fb7b810>,
#  '2023-01-07|new delhi': <Days.Day at 0x11fb7b8d0>,
#  '2023-01-08|new delhi': <Days.Day at 0x11fb7b990>,
#  '2023-01-09|new delhi': <Days.Day at 0x11fb7ba50>,
#  '2023-01-10|new delhi': <Days.Day at 0x11fb7bb10>,
#  '2023-01-11|new delhi': <Days.Day at 0x11fb7bbd0>,
#  '2023-01-12|new delhi': <Days.Day at 0x11fb7bc90>,
#  '2023-01-13|new delhi': <Days.Day at 0x11fb7bd50>,
#  '2023-01-14|new delhi': <Days.Day at 0x11fb7be10>,
#  '2023-01-15|new delhi': <Days.Day at 0x11fb7be90>,
#  '2023-01-16|new delhi': <Days.Day at 0x11fb7bf90>,
#  '2023-01-17|new delhi': <Days.Day at 0x11fb88090>,
#  '2023-01-18|new delhi': <Days.Day at 0x11fb88150>,
#  '2023-01-19|new delhi': <Days.Day at 0x11fb88210>,
#  '2023-01-20|new delhi': <Days.Day at 0x11fb88290>,
#  '2023-01-21|new delhi': <Days.Day at 0x11fb88390>,
#  '2023-01-22|new delhi': <Days.Day at 0x11fb88410>,
#  '2023-01-23|new delhi': <Days.Day at 0x11fb88510>,
#  '2023-01-24|new delhi': <Days.Day at 0x11fb885d0>,
#  '2023-01-25|new delhi': <Days.Day at 0x11fb88690>,
#  '2023-01-26|new delhi': <Days.Day at 0x11fb88750>,
#  '2023-01-27|new delhi': <Days.Day at 0x11fb887d0>,
#  '2023-01-28|new delhi': <Days.Day at 0x11fb888d0>,
#  '2023-01-29|new delhi': <Days.Day at 0x11fb88950>,
#  '2023-01-30|new delhi': <Days.Day at 0x11fb88a50>,
#  '2023-01-31|new delhi': <Days.Day at 0x11fb88b10>}

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print("Average temperature for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getAvgTemperature(c), 2)}°C")
# Out:
# Average temperature for each city:
# Beijing : 0.74°C
# London : 8.48°C
# New delhi : 24.1°C
# Los angeles : 21.65°C
# Berlin : 2.42°C
# Sydney : 30.87°C
# New york : 4.61°C
# Paris : 6.74°C
# Cairo : 23.87°C
# Tokyo : 10.81°C

# %%
print("Total precitpitation for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getTotalPrecipitation(c), 2)}mm")
# Out:
# Total precitpitation for each city:
# Beijing : 5.4mm
# London : 137.0mm
# New delhi : 3.6mm
# Los angeles : 0.0mm
# Berlin : 16.4mm
# Sydney : 2.9mm
# New york : 233.0mm
# Paris : 74.0mm
# Cairo : 0.0mm
# Tokyo : 3.7mm

# %%
print("Minimum and Maximum wind speed for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : Min : {a.getMinWindSpeed(c)}km/h,\n{' '*len(f'{c.capitalize()} : ')}Max : {a.getMaxWindSpeed(c)}km/h")
# Out:
# Minimum and Maximum wind speed for each city:
# Beijing : Min : 10.0km/h,
#           Max : 18.0km/h
# London : Min : 12.0km/h,
#          Max : 25.0km/h
# New delhi : Min : 10.0km/h,
#             Max : 22.0km/h
# Los angeles : Min : 12.0km/h,
#               Max : 20.0km/h
# Berlin : Min : 14.0km/h,
#          Max : 20.0km/h
# Sydney : Min : 14.0km/h,
#          Max : 20.0km/h
# New york : Min : 10.0km/h,
#            Max : 25.0km/h
# Paris : Min : 18.0km/h,
#         Max : 24.0km/h
# Cairo : Min : 14.0km/h,
#         Max : 20.0km/h
# Tokyo : Min : 10.0km/h,
#         Max : 22.0km/h

# %%
a.plotTemperature(*list(a.cities))

# %%
a.plotAvgTemperature(*list(a.cities))

# %%
print(a.categorizeDay("New York", "2023-01-15"))
# Out:
# Cold

# %%
print(f"Coldest day in New York :\n{a.coldestDay('New York')}\nHotest day in New York :\n{a.hotestDay('New York')}")
# Out:
# Coldest day in New York :
# Date: 2023-01-08
# Location: new york
# Max Temp: 1.0
# Min Temp: -6.0
# Precipitation: 10.0
# Wind Speed: 18.0
# Humidity: 88.0
# Cloud Cover: 40.0
#
# Hotest day in New York :
# Date: 2023-01-03
# Location: new york
# Max Temp: 8.0
# Min Temp: 1.0
# Precipitation: 5.0
# Wind Speed: 15.0
# Humidity: 65.0
# Cloud Cover: 20.0

# %%
a.plotCorrelationMatrix("New York")

# %%
a.correlationMatrix("New York")
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
a.loadTemp("Paris_data_climate.txt")
a.plotCorrelationMatrix("New York")

# %%
a.plotCorrelationMatrix("New York", "Paris")

# %%
corr_NY = a.correlationMatrix("New York")
corr_NY
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
len(corr_NY)
# Out:
# 2

# %%
corr_NY[0].shape
# Out:
# (6, 6)

# %%
np.max(corr_NY[0][0][2:])
# Out:
# -0.16173547865568008

# %%
#index of where the np max is in the matrix
type(corr_NY[0])
# Out:
# numpy.ndarray

# %%
#where is the most correlated data (except minimum temp)
np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])
# Out:
# 4

# %%
corr_NY[1][np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])]
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('new york')
# Out:
# 'Wind Speed'

# %%
a.factors_max_temp('paris')
# Out:
# 'Humidity'

# %%
a.getCityNames()
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print(a.coldestDay('los angeles'))
# Out:
# Date: 2023-01-06
# Location: los angeles
# Max Temp: 18.0
# Min Temp: 10.0
# Precipitation: 0.0
# Wind Speed: 12.0
# Humidity: 65.0
# Cloud Cover: 18.0

# %%
a.correlationMatrix('los angeles')
# Out:
# (array([[ 1.00000000e+00,  9.49994268e-01,  8.91688777e-01,
#           9.56731686e-04,  8.94116618e-02],
#         [ 9.49994268e-01,  1.00000000e+00,  8.73955359e-01,
#          -2.13100710e-02,  4.97777394e-02],
#         [ 8.91688777e-01,  8.73955359e-01,  1.00000000e+00,
#          -4.97281928e-02, -2.36833834e-02],
#         [ 9.56731686e-04, -2.13100710e-02, -4.97281928e-02,
#           1.00000000e+00,  9.44886482e-01],
#         [ 8.94116618e-02,  4.97777394e-02, -2.36833834e-02,
#           9.44886482e-01,  1.00000000e+00]]),
#  ['Max Temp', 'Min Temp', 'Wind Speed', 'Humidity', 'Cloud Cover'])

# %%
a.plotCorrelationMatrix('los angeles')

# %%
a.factors_max_temp('los angeles')
# Out:
# 'Wind Speed'

# %%
for c in a.getCityNames():
    print(f"max temp in {c.capitalize()} is correlated to {a.factors_max_temp(c)}")
# Out:
# max temp in Beijing is correlated to Cloud Cover
# max temp in London is correlated to Precipitation
# max temp in New delhi is correlated to Humidity
# max temp in Los angeles is correlated to Wind Speed
# max temp in Berlin is correlated to Humidity
# max temp in Sydney is correlated to Humidity
# max temp in New york is correlated to Wind Speed
# max temp in Paris is correlated to Humidity
# max temp in Cairo is correlated to Cloud Cover
# max temp in Tokyo is correlated to Humidity

# %%
corr_TK = a.correlationMatrix('tokyo')
corr_TK
# Out:
# (array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#          -0.0532858 ],
#         [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#          -0.01049208],
#         [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#          -0.17628808],
#         [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#          -0.32054589],
#         [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#           0.24301979],
#         [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
corr_TK[0]
# Out:
# array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#         -0.0532858 ],
#        [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#         -0.01049208],
#        [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#         -0.17628808],
#        [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#         -0.32054589],
#        [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#          0.24301979],
#        [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#          1.        ]])

# %%
np.abs
# Out:
# <ufunc 'absolute'>

# %%
corr_TK[0][0, 2:]
# Out:
# array([ 0.15981949, -0.54018546, -0.14611816, -0.0532858 ])

# %%
np.max(corr_TK[0][0][2:])
# Out:
# 0.1598194875836748

# %%
corr_TK[1]
# Out:
# ['Max Temp',
#  'Min Temp',
#  'Wind Speed',
#  'Humidity',
#  'Cloud Cover',
#  'Precipitation']

# %%
np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))
# Out:
# (array([0]), array([2]))

# %%
np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:])))
# Out:
# 2

# %%
corr_TK[1][np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))[0])]
# Out:
# 'Max Temp'

# %%
print(a.coldestDay('Paris'))
# Out:
# Date: 2023-01-02
# Location: paris
# Max Temp: 4.0
# Min Temp: -2.0
# Precipitation: 5.0
# Wind Speed: 18.0
# Humidity: 92.0
# Cloud Cover: 80.0
# CO2 Levels: 415.0
# Sea Level Rise: 3.0

# %%
a.getDayArttibutes()
# Out:
# ['date',
#  'location',
#  'maxTemp',
#  'minTemp',
#  'precipitation',
#  'windSpeed',
#  'humidity',
#  'cloudCover',
#  'co2Levels',
#  'seaLevelRise']

# %%
a.compare_variables('humidity', 'windSpeed', 'Paris', 'tokyo', "hello")
# Out:
# Error: hello is not a valid city name

# %%
a.compare_variables('humidity', 'windSpeed', 'Paris')

# %%
a.compare_variables('humidity', 'windSpeed', *a.getCityNames())

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
a.compare_variables('seaLevelRise', 'windSpeed', 'london')

# %%
a.compare_variables('maxTemp', 'precipitation', 'Paris', 'tokyo', "hello")
# Out:
# Error: hello is not a valid city name
