# %%
from Days import Days

# %%
a = Days()
a.loadTemp("/Users/arthurmorvan/Desktop/Final_Project/data_temperature.txt")
a.data
# Out:
# {'2023-01-01|new york': <Days.Day at 0x10ddec510>,
#  '2023-01-02|new york': <Days.Day at 0x108163210>,
#  '2023-01-03|new york': <Days.Day at 0x1081357d0>,
#  '2023-01-04|new york': <Days.Day at 0x10ddec450>,
#  '2023-01-05|new york': <Days.Day at 0x10ddee5d0>,
#  '2023-01-06|new york': <Days.Day at 0x10ddee6d0>,
#  '2023-01-07|new york': <Days.Day at 0x12873d290>,
#  '2023-01-08|new york': <Days.Day at 0x12873d310>,
#  '2023-01-09|new york': <Days.Day at 0x12873f310>,
#  '2023-01-10|new york': <Days.Day at 0x12873cf90>,
#  '2023-01-11|new york': <Days.Day at 0x128745390>,
#  '2023-01-12|new york': <Days.Day at 0x128744c50>,
#  '2023-01-13|new york': <Days.Day at 0x128744b90>,
#  '2023-01-14|new york': <Days.Day at 0x128745190>,
#  '2023-01-15|new york': <Days.Day at 0x128744810>,
#  '2023-01-16|new york': <Days.Day at 0x1287448d0>,
#  '2023-01-17|new york': <Days.Day at 0x1287449d0>,
#  '2023-01-18|new york': <Days.Day at 0x128744a50>,
#  '2023-01-19|new york': <Days.Day at 0x128744b10>,
#  '2023-01-20|new york': <Days.Day at 0x1287454d0>,
#  '2023-01-21|new york': <Days.Day at 0x128745610>,
#  '2023-01-22|new york': <Days.Day at 0x128745710>,
#  '2023-01-23|new york': <Days.Day at 0x1287457d0>,
#  '2023-01-24|new york': <Days.Day at 0x128745890>,
#  '2023-01-25|new york': <Days.Day at 0x128745910>,
#  '2023-01-26|new york': <Days.Day at 0x1287459d0>,
#  '2023-01-27|new york': <Days.Day at 0x128745a90>,
#  '2023-01-28|new york': <Days.Day at 0x128745b50>,
#  '2023-01-29|new york': <Days.Day at 0x128745c10>,
#  '2023-01-30|new york': <Days.Day at 0x128745d10>,
#  '2023-01-31|new york': <Days.Day at 0x128745dd0>,
#  '2023-01-01|los angeles': <Days.Day at 0x128746110>,
#  '2023-01-02|los angeles': <Days.Day at 0x128745f10>,
#  '2023-01-03|los angeles': <Days.Day at 0x128745fd0>,
#  '2023-01-04|los angeles': <Days.Day at 0x128746090>,
#  '2023-01-05|los angeles': <Days.Day at 0x128746190>,
#  '2023-01-06|los angeles': <Days.Day at 0x128746250>,
#  '2023-01-07|los angeles': <Days.Day at 0x128746310>,
#  '2023-01-08|los angeles': <Days.Day at 0x1287463d0>,
#  '2023-01-09|los angeles': <Days.Day at 0x128746490>,
#  '2023-01-10|los angeles': <Days.Day at 0x128746550>,
#  '2023-01-11|los angeles': <Days.Day at 0x128746610>,
#  '2023-01-12|los angeles': <Days.Day at 0x1287466d0>,
#  '2023-01-13|los angeles': <Days.Day at 0x128746790>,
#  '2023-01-14|los angeles': <Days.Day at 0x128746850>,
#  '2023-01-15|los angeles': <Days.Day at 0x128746910>,
#  '2023-01-16|los angeles': <Days.Day at 0x1287469d0>,
#  '2023-01-17|los angeles': <Days.Day at 0x128746a90>,
#  '2023-01-18|los angeles': <Days.Day at 0x128746b50>,
#  '2023-01-19|los angeles': <Days.Day at 0x128746c10>,
#  '2023-01-20|los angeles': <Days.Day at 0x128746cd0>,
#  '2023-01-21|los angeles': <Days.Day at 0x128746d90>,
#  '2023-01-22|los angeles': <Days.Day at 0x128746e50>,
#  '2023-01-23|los angeles': <Days.Day at 0x128746f10>,
#  '2023-01-24|los angeles': <Days.Day at 0x128746fd0>,
#  '2023-01-25|los angeles': <Days.Day at 0x128747090>,
#  '2023-01-26|los angeles': <Days.Day at 0x128747150>,
#  '2023-01-27|los angeles': <Days.Day at 0x128747210>,
#  '2023-01-28|los angeles': <Days.Day at 0x1287472d0>,
#  '2023-01-29|los angeles': <Days.Day at 0x128747390>,
#  '2023-01-30|los angeles': <Days.Day at 0x128747450>,
#  '2023-01-31|los angeles': <Days.Day at 0x128747510>,
#  '2023-01-01|london': <Days.Day at 0x128747810>,
#  '2023-01-02|london': <Days.Day at 0x128747690>,
#  '2023-01-03|london': <Days.Day at 0x128747750>,
#  '2023-01-04|london': <Days.Day at 0x128747890>,
#  '2023-01-05|london': <Days.Day at 0x128747950>,
#  '2023-01-06|london': <Days.Day at 0x1287479d0>,
#  '2023-01-07|london': <Days.Day at 0x128747ad0>,
#  '2023-01-08|london': <Days.Day at 0x128747b90>,
#  '2023-01-09|london': <Days.Day at 0x128747c50>,
#  '2023-01-10|london': <Days.Day at 0x128747cd0>,
#  '2023-01-11|london': <Days.Day at 0x128747dd0>,
#  '2023-01-12|london': <Days.Day at 0x128747e90>,
#  '2023-01-13|london': <Days.Day at 0x128747f50>,
#  '2023-01-14|london': <Days.Day at 0x128768050>,
#  '2023-01-15|london': <Days.Day at 0x1287680d0>,
#  '2023-01-16|london': <Days.Day at 0x128768190>,
#  '2023-01-17|london': <Days.Day at 0x128768290>,
#  '2023-01-18|london': <Days.Day at 0x128768350>,
#  '2023-01-19|london': <Days.Day at 0x128768410>,
#  '2023-01-20|london': <Days.Day at 0x1287684d0>,
#  '2023-01-21|london': <Days.Day at 0x128768550>,
#  '2023-01-22|london': <Days.Day at 0x128768610>,
#  '2023-01-23|london': <Days.Day at 0x128768710>,
#  '2023-01-24|london': <Days.Day at 0x1287687d0>,
#  '2023-01-25|london': <Days.Day at 0x128768850>,
#  '2023-01-26|london': <Days.Day at 0x128768910>,
#  '2023-01-27|london': <Days.Day at 0x1287689d0>,
#  '2023-01-28|london': <Days.Day at 0x128768ad0>,
#  '2023-01-29|london': <Days.Day at 0x128768b90>,
#  '2023-01-30|london': <Days.Day at 0x128768c50>,
#  '2023-01-31|london': <Days.Day at 0x128768cd0>,
#  '2023-01-01|tokyo': <Days.Day at 0x128769050>,
#  '2023-01-02|tokyo': <Days.Day at 0x128768e50>,
#  '2023-01-03|tokyo': <Days.Day at 0x128768f50>,
#  '2023-01-04|tokyo': <Days.Day at 0x128768fd0>,
#  '2023-01-05|tokyo': <Days.Day at 0x1287690d0>,
#  '2023-01-06|tokyo': <Days.Day at 0x128769190>,
#  '2023-01-07|tokyo': <Days.Day at 0x128769250>,
#  '2023-01-08|tokyo': <Days.Day at 0x128769310>,
#  '2023-01-09|tokyo': <Days.Day at 0x1287693d0>,
#  '2023-01-10|tokyo': <Days.Day at 0x128769490>,
#  '2023-01-11|tokyo': <Days.Day at 0x128769550>,
#  '2023-01-12|tokyo': <Days.Day at 0x128769610>,
#  '2023-01-13|tokyo': <Days.Day at 0x1287696d0>,
#  '2023-01-14|tokyo': <Days.Day at 0x128769790>,
#  '2023-01-15|tokyo': <Days.Day at 0x128769890>,
#  '2023-01-16|tokyo': <Days.Day at 0x128769950>,
#  '2023-01-17|tokyo': <Days.Day at 0x128769a10>,
#  '2023-01-18|tokyo': <Days.Day at 0x128769a90>,
#  '2023-01-19|tokyo': <Days.Day at 0x128769b50>,
#  '2023-01-20|tokyo': <Days.Day at 0x128769c10>,
#  '2023-01-21|tokyo': <Days.Day at 0x128769cd0>,
#  '2023-01-22|tokyo': <Days.Day at 0x128769d90>,
#  '2023-01-23|tokyo': <Days.Day at 0x128769e50>,
#  '2023-01-24|tokyo': <Days.Day at 0x128769f50>,
#  '2023-01-25|tokyo': <Days.Day at 0x128769fd0>,
#  '2023-01-26|tokyo': <Days.Day at 0x12876a090>,
#  '2023-01-27|tokyo': <Days.Day at 0x12876a150>,
#  '2023-01-28|tokyo': <Days.Day at 0x12876a210>,
#  '2023-01-29|tokyo': <Days.Day at 0x12876a310>,
#  '2023-01-30|tokyo': <Days.Day at 0x12876a390>,
#  '2023-01-31|tokyo': <Days.Day at 0x12876a450>,
#  '2023-01-01|beijing': <Days.Day at 0x12876a790>,
#  '2023-01-02|beijing': <Days.Day at 0x12876a5d0>,
#  '2023-01-03|beijing': <Days.Day at 0x12876a690>,
#  '2023-01-04|beijing': <Days.Day at 0x12876a750>,
#  '2023-01-05|beijing': <Days.Day at 0x12876a850>,
#  '2023-01-06|beijing': <Days.Day at 0x12876a910>,
#  '2023-01-07|beijing': <Days.Day at 0x12876a9d0>,
#  '2023-01-08|beijing': <Days.Day at 0x12876aa90>,
#  '2023-01-09|beijing': <Days.Day at 0x12876ab50>,
#  '2023-01-10|beijing': <Days.Day at 0x12876abd0>,
#  '2023-01-11|beijing': <Days.Day at 0x12876ad10>,
#  '2023-01-12|beijing': <Days.Day at 0x12876ad90>,
#  '2023-01-13|beijing': <Days.Day at 0x12876ae50>,
#  '2023-01-14|beijing': <Days.Day at 0x12876af50>,
#  '2023-01-15|beijing': <Days.Day at 0x12876afd0>,
#  '2023-01-16|beijing': <Days.Day at 0x12876b050>,
#  '2023-01-17|beijing': <Days.Day at 0x12876b150>,
#  '2023-01-18|beijing': <Days.Day at 0x12876b250>,
#  '2023-01-19|beijing': <Days.Day at 0x12876b310>,
#  '2023-01-20|beijing': <Days.Day at 0x12876b390>,
#  '2023-01-21|beijing': <Days.Day at 0x12876b450>,
#  '2023-01-22|beijing': <Days.Day at 0x12876b510>,
#  '2023-01-23|beijing': <Days.Day at 0x12876b5d0>,
#  '2023-01-24|beijing': <Days.Day at 0x12876b6d0>,
#  '2023-01-25|beijing': <Days.Day at 0x12876b750>,
#  '2023-01-26|beijing': <Days.Day at 0x12876b810>,
#  '2023-01-27|beijing': <Days.Day at 0x12876b8d0>,
#  '2023-01-28|beijing': <Days.Day at 0x12876b990>,
#  '2023-01-29|beijing': <Days.Day at 0x12876ba90>,
#  '2023-01-30|beijing': <Days.Day at 0x12876bb10>,
#  '2023-01-31|beijing': <Days.Day at 0x12876bbd0>,
#  '2023-01-01|sydney': <Days.Day at 0x12876bf50>,
#  '2023-01-02|sydney': <Days.Day at 0x12876bd50>,
#  '2023-01-03|sydney': <Days.Day at 0x12876be10>,
#  '2023-01-04|sydney': <Days.Day at 0x12876bed0>,
#  '2023-01-05|sydney': <Days.Day at 0x12876bfd0>,
#  '2023-01-06|sydney': <Days.Day at 0x1287700d0>,
#  '2023-01-07|sydney': <Days.Day at 0x128770190>,
#  '2023-01-08|sydney': <Days.Day at 0x128770210>,
#  '2023-01-09|sydney': <Days.Day at 0x128770310>,
#  '2023-01-10|sydney': <Days.Day at 0x1287703d0>,
#  '2023-01-11|sydney': <Days.Day at 0x128770490>,
#  '2023-01-12|sydney': <Days.Day at 0x128770550>,
#  '2023-01-13|sydney': <Days.Day at 0x1287705d0>,
#  '2023-01-14|sydney': <Days.Day at 0x1287706d0>,
#  '2023-01-15|sydney': <Days.Day at 0x128770790>,
#  '2023-01-16|sydney': <Days.Day at 0x128770850>,
#  '2023-01-17|sydney': <Days.Day at 0x128770910>,
#  '2023-01-18|sydney': <Days.Day at 0x1287709d0>,
#  '2023-01-19|sydney': <Days.Day at 0x128770a90>,
#  '2023-01-20|sydney': <Days.Day at 0x128770b50>,
#  '2023-01-21|sydney': <Days.Day at 0x128770c10>,
#  '2023-01-22|sydney': <Days.Day at 0x128770cd0>,
#  '2023-01-23|sydney': <Days.Day at 0x128770d90>,
#  '2023-01-24|sydney': <Days.Day at 0x128770e50>,
#  '2023-01-25|sydney': <Days.Day at 0x128770f10>,
#  '2023-01-26|sydney': <Days.Day at 0x128770fd0>,
#  '2023-01-27|sydney': <Days.Day at 0x128771090>,
#  '2023-01-28|sydney': <Days.Day at 0x128771150>,
#  '2023-01-29|sydney': <Days.Day at 0x128771210>,
#  '2023-01-30|sydney': <Days.Day at 0x1287712d0>,
#  '2023-01-31|sydney': <Days.Day at 0x128771390>,
#  '2023-01-01|paris': <Days.Day at 0x128771690>,
#  '2023-01-02|paris': <Days.Day at 0x128771510>,
#  '2023-01-03|paris': <Days.Day at 0x1287715d0>,
#  '2023-01-04|paris': <Days.Day at 0x128771710>,
#  '2023-01-05|paris': <Days.Day at 0x128771790>,
#  '2023-01-06|paris': <Days.Day at 0x128771890>,
#  '2023-01-07|paris': <Days.Day at 0x128771950>,
#  '2023-01-08|paris': <Days.Day at 0x128771a10>,
#  '2023-01-09|paris': <Days.Day at 0x128771ad0>,
#  '2023-01-10|paris': <Days.Day at 0x128771b50>,
#  '2023-01-11|paris': <Days.Day at 0x128771c50>,
#  '2023-01-12|paris': <Days.Day at 0x128771d10>,
#  '2023-01-13|paris': <Days.Day at 0x128771dd0>,
#  '2023-01-14|paris': <Days.Day at 0x128771e90>,
#  '2023-01-15|paris': <Days.Day at 0x128771f50>,
#  '2023-01-16|paris': <Days.Day at 0x128772010>,
#  '2023-01-17|paris': <Days.Day at 0x1287720d0>,
#  '2023-01-18|paris': <Days.Day at 0x128772190>,
#  '2023-01-19|paris': <Days.Day at 0x128772250>,
#  '2023-01-20|paris': <Days.Day at 0x128772310>,
#  '2023-01-21|paris': <Days.Day at 0x1287723d0>,
#  '2023-01-22|paris': <Days.Day at 0x128772490>,
#  '2023-01-23|paris': <Days.Day at 0x128772550>,
#  '2023-01-24|paris': <Days.Day at 0x128772610>,
#  '2023-01-25|paris': <Days.Day at 0x1287726d0>,
#  '2023-01-26|paris': <Days.Day at 0x128772790>,
#  '2023-01-27|paris': <Days.Day at 0x128772850>,
#  '2023-01-28|paris': <Days.Day at 0x128772910>,
#  '2023-01-29|paris': <Days.Day at 0x1287729d0>,
#  '2023-01-30|paris': <Days.Day at 0x128772a90>,
#  '2023-01-31|paris': <Days.Day at 0x128772b50>,
#  '2023-01-01|berlin': <Days.Day at 0x128772e50>,
#  '2023-01-02|berlin': <Days.Day at 0x128772cd0>,
#  '2023-01-03|berlin': <Days.Day at 0x128772d90>,
#  '2023-01-04|berlin': <Days.Day at 0x128772e10>,
#  '2023-01-05|berlin': <Days.Day at 0x128772f10>,
#  '2023-01-06|berlin': <Days.Day at 0x128773010>,
#  '2023-01-07|berlin': <Days.Day at 0x128773090>,
#  '2023-01-08|berlin': <Days.Day at 0x128773150>,
#  '2023-01-09|berlin': <Days.Day at 0x128773210>,
#  '2023-01-10|berlin': <Days.Day at 0x128773290>,
#  '2023-01-11|berlin': <Days.Day at 0x128773390>,
#  '2023-01-12|berlin': <Days.Day at 0x128773450>,
#  '2023-01-13|berlin': <Days.Day at 0x128773550>,
#  '2023-01-14|berlin': <Days.Day at 0x128773610>,
#  '2023-01-15|berlin': <Days.Day at 0x128773690>,
#  '2023-01-16|berlin': <Days.Day at 0x128773750>,
#  '2023-01-17|berlin': <Days.Day at 0x128773850>,
#  '2023-01-18|berlin': <Days.Day at 0x1287738d0>,
#  '2023-01-19|berlin': <Days.Day at 0x1287739d0>,
#  '2023-01-20|berlin': <Days.Day at 0x128773a50>,
#  '2023-01-21|berlin': <Days.Day at 0x128773b10>,
#  '2023-01-22|berlin': <Days.Day at 0x128773bd0>,
#  '2023-01-23|berlin': <Days.Day at 0x128773cd0>,
#  '2023-01-24|berlin': <Days.Day at 0x128773d90>,
#  '2023-01-25|berlin': <Days.Day at 0x128773e50>,
#  '2023-01-26|berlin': <Days.Day at 0x128773ed0>,
#  '2023-01-27|berlin': <Days.Day at 0x128773f90>,
#  '2023-01-28|berlin': <Days.Day at 0x12877c090>,
#  '2023-01-29|berlin': <Days.Day at 0x12877c190>,
#  '2023-01-30|berlin': <Days.Day at 0x12877c250>,
#  '2023-01-31|berlin': <Days.Day at 0x12877c310>,
#  '2023-01-01|cairo': <Days.Day at 0x12877c610>,
#  '2023-01-02|cairo': <Days.Day at 0x12877c450>,
#  '2023-01-03|cairo': <Days.Day at 0x12877c550>,
#  '2023-01-04|cairo': <Days.Day at 0x12877c5d0>,
#  '2023-01-05|cairo': <Days.Day at 0x12877c6d0>,
#  '2023-01-06|cairo': <Days.Day at 0x12877c790>,
#  '2023-01-07|cairo': <Days.Day at 0x12877c850>,
#  '2023-01-08|cairo': <Days.Day at 0x12877c910>,
#  '2023-01-09|cairo': <Days.Day at 0x12877c9d0>,
#  '2023-01-10|cairo': <Days.Day at 0x12877ca90>,
#  '2023-01-11|cairo': <Days.Day at 0x12877cb50>,
#  '2023-01-12|cairo': <Days.Day at 0x12877cc10>,
#  '2023-01-13|cairo': <Days.Day at 0x12877ccd0>,
#  '2023-01-14|cairo': <Days.Day at 0x12877cd90>,
#  '2023-01-15|cairo': <Days.Day at 0x12877ce50>,
#  '2023-01-16|cairo': <Days.Day at 0x12877cf10>,
#  '2023-01-17|cairo': <Days.Day at 0x12877cfd0>,
#  '2023-01-18|cairo': <Days.Day at 0x12877d090>,
#  '2023-01-19|cairo': <Days.Day at 0x12877d150>,
#  '2023-01-20|cairo': <Days.Day at 0x12877d210>,
#  '2023-01-21|cairo': <Days.Day at 0x12877d2d0>,
#  '2023-01-22|cairo': <Days.Day at 0x12877d390>,
#  '2023-01-23|cairo': <Days.Day at 0x12877d450>,
#  '2023-01-24|cairo': <Days.Day at 0x12877d510>,
#  '2023-01-25|cairo': <Days.Day at 0x12877d5d0>,
#  '2023-01-26|cairo': <Days.Day at 0x12877d690>,
#  '2023-01-27|cairo': <Days.Day at 0x12877d750>,
#  '2023-01-28|cairo': <Days.Day at 0x12877d810>,
#  '2023-01-29|cairo': <Days.Day at 0x12877d8d0>,
#  '2023-01-30|cairo': <Days.Day at 0x12877d990>,
#  '2023-01-31|cairo': <Days.Day at 0x12877da50>,
#  '2023-01-01|new delhi': <Days.Day at 0x12877ddd0>,
#  '2023-01-02|new delhi': <Days.Day at 0x12877dbd0>,
#  '2023-01-03|new delhi': <Days.Day at 0x12877dc90>,
#  '2023-01-04|new delhi': <Days.Day at 0x12877dd50>,
#  '2023-01-05|new delhi': <Days.Day at 0x12877de50>,
#  '2023-01-06|new delhi': <Days.Day at 0x12877df10>,
#  '2023-01-07|new delhi': <Days.Day at 0x12877dfd0>,
#  '2023-01-08|new delhi': <Days.Day at 0x12877e090>,
#  '2023-01-09|new delhi': <Days.Day at 0x12877e150>,
#  '2023-01-10|new delhi': <Days.Day at 0x12877e210>,
#  '2023-01-11|new delhi': <Days.Day at 0x12877e2d0>,
#  '2023-01-12|new delhi': <Days.Day at 0x12877e390>,
#  '2023-01-13|new delhi': <Days.Day at 0x12877e450>,
#  '2023-01-14|new delhi': <Days.Day at 0x12877e510>,
#  '2023-01-15|new delhi': <Days.Day at 0x12877e590>,
#  '2023-01-16|new delhi': <Days.Day at 0x12877e690>,
#  '2023-01-17|new delhi': <Days.Day at 0x12877e750>,
#  '2023-01-18|new delhi': <Days.Day at 0x12877e810>,
#  '2023-01-19|new delhi': <Days.Day at 0x12877e8d0>,
#  '2023-01-20|new delhi': <Days.Day at 0x12877e950>,
#  '2023-01-21|new delhi': <Days.Day at 0x12877ea50>,
#  '2023-01-22|new delhi': <Days.Day at 0x12877ead0>,
#  '2023-01-23|new delhi': <Days.Day at 0x12877ebd0>,
#  '2023-01-24|new delhi': <Days.Day at 0x12877ec90>,
#  '2023-01-25|new delhi': <Days.Day at 0x12877ed50>,
#  '2023-01-26|new delhi': <Days.Day at 0x12877ee10>,
#  '2023-01-27|new delhi': <Days.Day at 0x12877ee90>,
#  '2023-01-28|new delhi': <Days.Day at 0x12877ef90>,
#  '2023-01-29|new delhi': <Days.Day at 0x12877f010>,
#  '2023-01-30|new delhi': <Days.Day at 0x12877f110>,
#  '2023-01-31|new delhi': <Days.Day at 0x12877f1d0>}

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print("Average temperature for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getAvgTemperature(c), 2)}°C")
# Out:
# Average temperature for each city:
# Los angeles : 21.65°C
# New york : 4.61°C
# Cairo : 23.87°C
# Tokyo : 10.81°C
# Paris : 6.74°C
# New delhi : 24.1°C
# London : 8.48°C
# Beijing : 0.74°C
# Berlin : 2.42°C
# Sydney : 30.87°C

# %%
print("Total precitpitation for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getTotalPrecipitation(c), 2)}mm")
# Out:
# Total precitpitation for each city:
# Los angeles : 0.0mm
# New york : 233.0mm
# Cairo : 0.0mm
# Tokyo : 3.7mm
# Paris : 74.0mm
# New delhi : 3.6mm
# London : 137.0mm
# Beijing : 5.4mm
# Berlin : 16.4mm
# Sydney : 2.9mm

# %%
print("Minimum and Maximum wind speed for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : Min : {a.getMinWindSpeed(c)}km/h,\n{' '*len(f'{c.capitalize()} : ')}Max : {a.getMaxWindSpeed(c)}km/h")
# Out:
# Minimum and Maximum wind speed for each city:
# Los angeles : Min : 12.0km/h,
#               Max : 20.0km/h
# New york : Min : 10.0km/h,
#            Max : 25.0km/h
# Cairo : Min : 14.0km/h,
#         Max : 20.0km/h
# Tokyo : Min : 10.0km/h,
#         Max : 22.0km/h
# Paris : Min : 18.0km/h,
#         Max : 24.0km/h
# New delhi : Min : 10.0km/h,
#             Max : 22.0km/h
# London : Min : 12.0km/h,
#          Max : 25.0km/h
# Beijing : Min : 10.0km/h,
#           Max : 18.0km/h
# Berlin : Min : 14.0km/h,
#          Max : 20.0km/h
# Sydney : Min : 14.0km/h,
#          Max : 20.0km/h

# %%
a.plotTemperature(*list(a.cities))

# %%
a.plotAvgTemperature(*list(a.cities))

# %%
print(a.categorizeDay("New York", "2023-01-15"))
# Out:
# Cold

# %%
print(f"Coldest day in New York :\n{a.coldestDay('New York')}\nHotest day in New York :\n{a.hotestDay('New York')}")
# Out:
# Coldest day in New York :
# Date: 2023-01-08
# Location: new york
# Max Temp: 1.0
# Min Temp: -6.0
# Precipitation: 10.0
# Wind Speed: 18.0
# Humidity: 88.0
# Cloud Cover: 40.0
# CO2 Levels: None
# Sea Level Rise: None
#
# Hotest day in New York :
# Date: 2023-01-03
# Location: new york
# Max Temp: 8.0
# Min Temp: 1.0
# Precipitation: 5.0
# Wind Speed: 15.0
# Humidity: 65.0
# Cloud Cover: 20.0
# CO2 Levels: None
# Sea Level Rise: None

# %%
a.plotCorrelationMatrix("New York")

# %%
a.correlationMatrix("New York")
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
a.loadTemp("/Users/arthurmorvan/Desktop/Final_Project/Paris_data_climate.txt")
a.plotCorrelationMatrix("New York")

# %%
a.plotCorrelationMatrix("New York", "Paris")
