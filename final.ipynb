# %%
from Days import Days

# %%
import numpy as np

# %%
a = Days()
a.loadTemp("data_temperature.txt")
a.data
# Out:
# {'2023-01-01|new york': <Days.Day at 0x11938c310>,
#  '2023-01-02|new york': <Days.Day at 0x119367190>,
#  '2023-01-03|new york': <Days.Day at 0x119455f10>,
#  '2023-01-04|new york': <Days.Day at 0x119584790>,
#  '2023-01-05|new york': <Days.Day at 0x11949ce50>,
#  '2023-01-06|new york': <Days.Day at 0x1195d6110>,
#  '2023-01-07|new york': <Days.Day at 0x1195d6fd0>,
#  '2023-01-08|new york': <Days.Day at 0x1195d6410>,
#  '2023-01-09|new york': <Days.Day at 0x1195d5a50>,
#  '2023-01-10|new york': <Days.Day at 0x1195d61d0>,
#  '2023-01-11|new york': <Days.Day at 0x1195d74d0>,
#  '2023-01-12|new york': <Days.Day at 0x1195d69d0>,
#  '2023-01-13|new york': <Days.Day at 0x1195d7510>,
#  '2023-01-14|new york': <Days.Day at 0x1195d7d90>,
#  '2023-01-15|new york': <Days.Day at 0x1195a2b50>,
#  '2023-01-16|new york': <Days.Day at 0x1195a2ad0>,
#  '2023-01-17|new york': <Days.Day at 0x1195a3ad0>,
#  '2023-01-18|new york': <Days.Day at 0x1195a3010>,
#  '2023-01-19|new york': <Days.Day at 0x1195a2550>,
#  '2023-01-20|new york': <Days.Day at 0x1195a3250>,
#  '2023-01-21|new york': <Days.Day at 0x1195a3650>,
#  '2023-01-22|new york': <Days.Day at 0x1195b7950>,
#  '2023-01-23|new york': <Days.Day at 0x1195b4390>,
#  '2023-01-24|new york': <Days.Day at 0x1195b6390>,
#  '2023-01-25|new york': <Days.Day at 0x1195b7dd0>,
#  '2023-01-26|new york': <Days.Day at 0x1195b4d10>,
#  '2023-01-27|new york': <Days.Day at 0x1195b4990>,
#  '2023-01-28|new york': <Days.Day at 0x1195b6150>,
#  '2023-01-29|new york': <Days.Day at 0x1195b5790>,
#  '2023-01-30|new york': <Days.Day at 0x1195b4cd0>,
#  '2023-01-31|new york': <Days.Day at 0x1195b7150>,
#  '2023-01-01|los angeles': <Days.Day at 0x1195d9390>,
#  '2023-01-02|los angeles': <Days.Day at 0x1195d9610>,
#  '2023-01-03|los angeles': <Days.Day at 0x1195d8690>,
#  '2023-01-04|los angeles': <Days.Day at 0x1195d9750>,
#  '2023-01-05|los angeles': <Days.Day at 0x1195d98d0>,
#  '2023-01-06|los angeles': <Days.Day at 0x1195d9050>,
#  '2023-01-07|los angeles': <Days.Day at 0x1195d9910>,
#  '2023-01-08|los angeles': <Days.Day at 0x1195d9bd0>,
#  '2023-01-09|los angeles': <Days.Day at 0x1195d95d0>,
#  '2023-01-10|los angeles': <Days.Day at 0x1195d8610>,
#  '2023-01-11|los angeles': <Days.Day at 0x1195d8190>,
#  '2023-01-12|los angeles': <Days.Day at 0x1195d9510>,
#  '2023-01-13|los angeles': <Days.Day at 0x1195d9a50>,
#  '2023-01-14|los angeles': <Days.Day at 0x1195d8210>,
#  '2023-01-15|los angeles': <Days.Day at 0x1195d8a50>,
#  '2023-01-16|los angeles': <Days.Day at 0x1195d9b10>,
#  '2023-01-17|los angeles': <Days.Day at 0x1195d9ad0>,
#  '2023-01-18|los angeles': <Days.Day at 0x1195d9590>,
#  '2023-01-19|los angeles': <Days.Day at 0x1195d9450>,
#  '2023-01-20|los angeles': <Days.Day at 0x1195d9d10>,
#  '2023-01-21|los angeles': <Days.Day at 0x1195d9010>,
#  '2023-01-22|los angeles': <Days.Day at 0x1195d9dd0>,
#  '2023-01-23|los angeles': <Days.Day at 0x1195d9e90>,
#  '2023-01-24|los angeles': <Days.Day at 0x1195d9f50>,
#  '2023-01-25|los angeles': <Days.Day at 0x1195da010>,
#  '2023-01-26|los angeles': <Days.Day at 0x1195da0d0>,
#  '2023-01-27|los angeles': <Days.Day at 0x1195da190>,
#  '2023-01-28|los angeles': <Days.Day at 0x1195da250>,
#  '2023-01-29|los angeles': <Days.Day at 0x1195da310>,
#  '2023-01-30|los angeles': <Days.Day at 0x1195da3d0>,
#  '2023-01-31|los angeles': <Days.Day at 0x1195da490>,
#  '2023-01-01|london': <Days.Day at 0x1195da790>,
#  '2023-01-02|london': <Days.Day at 0x1195da610>,
#  '2023-01-03|london': <Days.Day at 0x1195da6d0>,
#  '2023-01-04|london': <Days.Day at 0x1195da810>,
#  '2023-01-05|london': <Days.Day at 0x1195da8d0>,
#  '2023-01-06|london': <Days.Day at 0x1195da950>,
#  '2023-01-07|london': <Days.Day at 0x1195daa50>,
#  '2023-01-08|london': <Days.Day at 0x1195dab10>,
#  '2023-01-09|london': <Days.Day at 0x1195dabd0>,
#  '2023-01-10|london': <Days.Day at 0x1195dac50>,
#  '2023-01-11|london': <Days.Day at 0x1195dad50>,
#  '2023-01-12|london': <Days.Day at 0x1195dae10>,
#  '2023-01-13|london': <Days.Day at 0x1195daed0>,
#  '2023-01-14|london': <Days.Day at 0x1195daf90>,
#  '2023-01-15|london': <Days.Day at 0x1195db010>,
#  '2023-01-16|london': <Days.Day at 0x1195db0d0>,
#  '2023-01-17|london': <Days.Day at 0x1195db1d0>,
#  '2023-01-18|london': <Days.Day at 0x1195db290>,
#  '2023-01-19|london': <Days.Day at 0x1195db350>,
#  '2023-01-20|london': <Days.Day at 0x1195db410>,
#  '2023-01-21|london': <Days.Day at 0x1195db490>,
#  '2023-01-22|london': <Days.Day at 0x1195db550>,
#  '2023-01-23|london': <Days.Day at 0x1195db650>,
#  '2023-01-24|london': <Days.Day at 0x1195db710>,
#  '2023-01-25|london': <Days.Day at 0x1195db790>,
#  '2023-01-26|london': <Days.Day at 0x1195db850>,
#  '2023-01-27|london': <Days.Day at 0x1195db910>,
#  '2023-01-28|london': <Days.Day at 0x1195dba10>,
#  '2023-01-29|london': <Days.Day at 0x1195dbad0>,
#  '2023-01-30|london': <Days.Day at 0x1195dbb90>,
#  '2023-01-31|london': <Days.Day at 0x1195dbc10>,
#  '2023-01-01|tokyo': <Days.Day at 0x1195dbf90>,
#  '2023-01-02|tokyo': <Days.Day at 0x1195dbd90>,
#  '2023-01-03|tokyo': <Days.Day at 0x1195dbe90>,
#  '2023-01-04|tokyo': <Days.Day at 0x1195dbf10>,
#  '2023-01-05|tokyo': <Days.Day at 0x1195f4050>,
#  '2023-01-06|tokyo': <Days.Day at 0x1195f4110>,
#  '2023-01-07|tokyo': <Days.Day at 0x1195f41d0>,
#  '2023-01-08|tokyo': <Days.Day at 0x1195f4290>,
#  '2023-01-09|tokyo': <Days.Day at 0x1195f4350>,
#  '2023-01-10|tokyo': <Days.Day at 0x1195f4410>,
#  '2023-01-11|tokyo': <Days.Day at 0x1195f44d0>,
#  '2023-01-12|tokyo': <Days.Day at 0x1195f4590>,
#  '2023-01-13|tokyo': <Days.Day at 0x1195f4650>,
#  '2023-01-14|tokyo': <Days.Day at 0x1195f4710>,
#  '2023-01-15|tokyo': <Days.Day at 0x1195f4810>,
#  '2023-01-16|tokyo': <Days.Day at 0x1195f48d0>,
#  '2023-01-17|tokyo': <Days.Day at 0x1195f4990>,
#  '2023-01-18|tokyo': <Days.Day at 0x1195f4a10>,
#  '2023-01-19|tokyo': <Days.Day at 0x1195f4ad0>,
#  '2023-01-20|tokyo': <Days.Day at 0x1195f4b90>,
#  '2023-01-21|tokyo': <Days.Day at 0x1195f4c50>,
#  '2023-01-22|tokyo': <Days.Day at 0x1195f4d10>,
#  '2023-01-23|tokyo': <Days.Day at 0x1195f4dd0>,
#  '2023-01-24|tokyo': <Days.Day at 0x1195f4ed0>,
#  '2023-01-25|tokyo': <Days.Day at 0x1195f4f50>,
#  '2023-01-26|tokyo': <Days.Day at 0x1195f5010>,
#  '2023-01-27|tokyo': <Days.Day at 0x1195f50d0>,
#  '2023-01-28|tokyo': <Days.Day at 0x1195f5190>,
#  '2023-01-29|tokyo': <Days.Day at 0x1195f5290>,
#  '2023-01-30|tokyo': <Days.Day at 0x1195f5310>,
#  '2023-01-31|tokyo': <Days.Day at 0x1195f53d0>,
#  '2023-01-01|beijing': <Days.Day at 0x1195f5710>,
#  '2023-01-02|beijing': <Days.Day at 0x1195f5550>,
#  '2023-01-03|beijing': <Days.Day at 0x1195f5610>,
#  '2023-01-04|beijing': <Days.Day at 0x1195f56d0>,
#  '2023-01-05|beijing': <Days.Day at 0x1195f57d0>,
#  '2023-01-06|beijing': <Days.Day at 0x1195f5890>,
#  '2023-01-07|beijing': <Days.Day at 0x1195f5950>,
#  '2023-01-08|beijing': <Days.Day at 0x1195f5a10>,
#  '2023-01-09|beijing': <Days.Day at 0x1195f5ad0>,
#  '2023-01-10|beijing': <Days.Day at 0x1195f5b50>,
#  '2023-01-11|beijing': <Days.Day at 0x1195f5c90>,
#  '2023-01-12|beijing': <Days.Day at 0x1195f5d10>,
#  '2023-01-13|beijing': <Days.Day at 0x1195f5dd0>,
#  '2023-01-14|beijing': <Days.Day at 0x1195f5ed0>,
#  '2023-01-15|beijing': <Days.Day at 0x1195f5f50>,
#  '2023-01-16|beijing': <Days.Day at 0x1195f5fd0>,
#  '2023-01-17|beijing': <Days.Day at 0x1195f60d0>,
#  '2023-01-18|beijing': <Days.Day at 0x1195f61d0>,
#  '2023-01-19|beijing': <Days.Day at 0x1195f6290>,
#  '2023-01-20|beijing': <Days.Day at 0x1195f6310>,
#  '2023-01-21|beijing': <Days.Day at 0x1195f63d0>,
#  '2023-01-22|beijing': <Days.Day at 0x1195f6490>,
#  '2023-01-23|beijing': <Days.Day at 0x1195f6550>,
#  '2023-01-24|beijing': <Days.Day at 0x1195f6650>,
#  '2023-01-25|beijing': <Days.Day at 0x1195f66d0>,
#  '2023-01-26|beijing': <Days.Day at 0x1195f6790>,
#  '2023-01-27|beijing': <Days.Day at 0x1195f6850>,
#  '2023-01-28|beijing': <Days.Day at 0x1195f6910>,
#  '2023-01-29|beijing': <Days.Day at 0x1195f6a10>,
#  '2023-01-30|beijing': <Days.Day at 0x1195f6a90>,
#  '2023-01-31|beijing': <Days.Day at 0x1195f6b50>,
#  '2023-01-01|sydney': <Days.Day at 0x1195f6ed0>,
#  '2023-01-02|sydney': <Days.Day at 0x1195f6cd0>,
#  '2023-01-03|sydney': <Days.Day at 0x1195f6d90>,
#  '2023-01-04|sydney': <Days.Day at 0x1195f6e50>,
#  '2023-01-05|sydney': <Days.Day at 0x1195f6f50>,
#  '2023-01-06|sydney': <Days.Day at 0x1195f7010>,
#  '2023-01-07|sydney': <Days.Day at 0x1195f70d0>,
#  '2023-01-08|sydney': <Days.Day at 0x1195f7150>,
#  '2023-01-09|sydney': <Days.Day at 0x1195f7250>,
#  '2023-01-10|sydney': <Days.Day at 0x1195f7310>,
#  '2023-01-11|sydney': <Days.Day at 0x1195f73d0>,
#  '2023-01-12|sydney': <Days.Day at 0x1195f7490>,
#  '2023-01-13|sydney': <Days.Day at 0x1195f7510>,
#  '2023-01-14|sydney': <Days.Day at 0x1195f7610>,
#  '2023-01-15|sydney': <Days.Day at 0x1195f76d0>,
#  '2023-01-16|sydney': <Days.Day at 0x1195f7790>,
#  '2023-01-17|sydney': <Days.Day at 0x1195f7850>,
#  '2023-01-18|sydney': <Days.Day at 0x1195f7910>,
#  '2023-01-19|sydney': <Days.Day at 0x1195f79d0>,
#  '2023-01-20|sydney': <Days.Day at 0x1195f7a90>,
#  '2023-01-21|sydney': <Days.Day at 0x1195f7b50>,
#  '2023-01-22|sydney': <Days.Day at 0x1195f7c10>,
#  '2023-01-23|sydney': <Days.Day at 0x1195f7cd0>,
#  '2023-01-24|sydney': <Days.Day at 0x1195f7d90>,
#  '2023-01-25|sydney': <Days.Day at 0x1195f7e50>,
#  '2023-01-26|sydney': <Days.Day at 0x1195f7f10>,
#  '2023-01-27|sydney': <Days.Day at 0x1195f7fd0>,
#  '2023-01-28|sydney': <Days.Day at 0x11ec480d0>,
#  '2023-01-29|sydney': <Days.Day at 0x11ec48190>,
#  '2023-01-30|sydney': <Days.Day at 0x11ec48250>,
#  '2023-01-31|sydney': <Days.Day at 0x11ec48310>,
#  '2023-01-01|paris': <Days.Day at 0x11ec48610>,
#  '2023-01-02|paris': <Days.Day at 0x11ec48490>,
#  '2023-01-03|paris': <Days.Day at 0x11ec48550>,
#  '2023-01-04|paris': <Days.Day at 0x11ec48690>,
#  '2023-01-05|paris': <Days.Day at 0x11ec48710>,
#  '2023-01-06|paris': <Days.Day at 0x11ec48810>,
#  '2023-01-07|paris': <Days.Day at 0x11ec488d0>,
#  '2023-01-08|paris': <Days.Day at 0x11ec48990>,
#  '2023-01-09|paris': <Days.Day at 0x11ec48a50>,
#  '2023-01-10|paris': <Days.Day at 0x11ec48ad0>,
#  '2023-01-11|paris': <Days.Day at 0x11ec48bd0>,
#  '2023-01-12|paris': <Days.Day at 0x11ec48c90>,
#  '2023-01-13|paris': <Days.Day at 0x11ec48d50>,
#  '2023-01-14|paris': <Days.Day at 0x11ec48e10>,
#  '2023-01-15|paris': <Days.Day at 0x11ec48ed0>,
#  '2023-01-16|paris': <Days.Day at 0x11ec48f90>,
#  '2023-01-17|paris': <Days.Day at 0x11ec49050>,
#  '2023-01-18|paris': <Days.Day at 0x11ec49110>,
#  '2023-01-19|paris': <Days.Day at 0x11ec491d0>,
#  '2023-01-20|paris': <Days.Day at 0x11ec49290>,
#  '2023-01-21|paris': <Days.Day at 0x11ec49350>,
#  '2023-01-22|paris': <Days.Day at 0x11ec49410>,
#  '2023-01-23|paris': <Days.Day at 0x11ec494d0>,
#  '2023-01-24|paris': <Days.Day at 0x11ec49590>,
#  '2023-01-25|paris': <Days.Day at 0x11ec49650>,
#  '2023-01-26|paris': <Days.Day at 0x11ec49710>,
#  '2023-01-27|paris': <Days.Day at 0x11ec497d0>,
#  '2023-01-28|paris': <Days.Day at 0x11ec49890>,
#  '2023-01-29|paris': <Days.Day at 0x11ec49950>,
#  '2023-01-30|paris': <Days.Day at 0x11ec49a10>,
#  '2023-01-31|paris': <Days.Day at 0x11ec49ad0>,
#  '2023-01-01|berlin': <Days.Day at 0x11ec49dd0>,
#  '2023-01-02|berlin': <Days.Day at 0x11ec49c50>,
#  '2023-01-03|berlin': <Days.Day at 0x11ec49d10>,
#  '2023-01-04|berlin': <Days.Day at 0x11ec49d90>,
#  '2023-01-05|berlin': <Days.Day at 0x11ec49e90>,
#  '2023-01-06|berlin': <Days.Day at 0x11ec49f90>,
#  '2023-01-07|berlin': <Days.Day at 0x11ec4a010>,
#  '2023-01-08|berlin': <Days.Day at 0x11ec4a0d0>,
#  '2023-01-09|berlin': <Days.Day at 0x11ec4a190>,
#  '2023-01-10|berlin': <Days.Day at 0x11ec4a210>,
#  '2023-01-11|berlin': <Days.Day at 0x11ec4a310>,
#  '2023-01-12|berlin': <Days.Day at 0x11ec4a3d0>,
#  '2023-01-13|berlin': <Days.Day at 0x11ec4a4d0>,
#  '2023-01-14|berlin': <Days.Day at 0x11ec4a590>,
#  '2023-01-15|berlin': <Days.Day at 0x11ec4a610>,
#  '2023-01-16|berlin': <Days.Day at 0x11ec4a6d0>,
#  '2023-01-17|berlin': <Days.Day at 0x11ec4a7d0>,
#  '2023-01-18|berlin': <Days.Day at 0x11ec4a850>,
#  '2023-01-19|berlin': <Days.Day at 0x11ec4a950>,
#  '2023-01-20|berlin': <Days.Day at 0x11ec4a9d0>,
#  '2023-01-21|berlin': <Days.Day at 0x11ec4aa90>,
#  '2023-01-22|berlin': <Days.Day at 0x11ec4ab50>,
#  '2023-01-23|berlin': <Days.Day at 0x11ec4ac50>,
#  '2023-01-24|berlin': <Days.Day at 0x11ec4ad10>,
#  '2023-01-25|berlin': <Days.Day at 0x11ec4add0>,
#  '2023-01-26|berlin': <Days.Day at 0x11ec4ae50>,
#  '2023-01-27|berlin': <Days.Day at 0x11ec4af10>,
#  '2023-01-28|berlin': <Days.Day at 0x11ec4afd0>,
#  '2023-01-29|berlin': <Days.Day at 0x11ec4b0d0>,
#  '2023-01-30|berlin': <Days.Day at 0x11ec4b190>,
#  '2023-01-31|berlin': <Days.Day at 0x11ec4b250>,
#  '2023-01-01|cairo': <Days.Day at 0x11ec4b550>,
#  '2023-01-02|cairo': <Days.Day at 0x11ec4b390>,
#  '2023-01-03|cairo': <Days.Day at 0x11ec4b490>,
#  '2023-01-04|cairo': <Days.Day at 0x11ec4b510>,
#  '2023-01-05|cairo': <Days.Day at 0x11ec4b610>,
#  '2023-01-06|cairo': <Days.Day at 0x11ec4b6d0>,
#  '2023-01-07|cairo': <Days.Day at 0x11ec4b790>,
#  '2023-01-08|cairo': <Days.Day at 0x11ec4b850>,
#  '2023-01-09|cairo': <Days.Day at 0x11ec4b910>,
#  '2023-01-10|cairo': <Days.Day at 0x11ec4b9d0>,
#  '2023-01-11|cairo': <Days.Day at 0x11ec4ba90>,
#  '2023-01-12|cairo': <Days.Day at 0x11ec4bb50>,
#  '2023-01-13|cairo': <Days.Day at 0x11ec4bc10>,
#  '2023-01-14|cairo': <Days.Day at 0x11ec4bcd0>,
#  '2023-01-15|cairo': <Days.Day at 0x11ec4bd90>,
#  '2023-01-16|cairo': <Days.Day at 0x11ec4be50>,
#  '2023-01-17|cairo': <Days.Day at 0x11ec4bf10>,
#  '2023-01-18|cairo': <Days.Day at 0x11ec4bfd0>,
#  '2023-01-19|cairo': <Days.Day at 0x11ec540d0>,
#  '2023-01-20|cairo': <Days.Day at 0x11ec54190>,
#  '2023-01-21|cairo': <Days.Day at 0x11ec54250>,
#  '2023-01-22|cairo': <Days.Day at 0x11ec54310>,
#  '2023-01-23|cairo': <Days.Day at 0x11ec543d0>,
#  '2023-01-24|cairo': <Days.Day at 0x11ec54490>,
#  '2023-01-25|cairo': <Days.Day at 0x11ec54550>,
#  '2023-01-26|cairo': <Days.Day at 0x11ec54610>,
#  '2023-01-27|cairo': <Days.Day at 0x11ec546d0>,
#  '2023-01-28|cairo': <Days.Day at 0x11ec54790>,
#  '2023-01-29|cairo': <Days.Day at 0x11ec54850>,
#  '2023-01-30|cairo': <Days.Day at 0x11ec54910>,
#  '2023-01-31|cairo': <Days.Day at 0x11ec549d0>,
#  '2023-01-01|new delhi': <Days.Day at 0x11ec54d50>,
#  '2023-01-02|new delhi': <Days.Day at 0x11ec54b50>,
#  '2023-01-03|new delhi': <Days.Day at 0x11ec54c10>,
#  '2023-01-04|new delhi': <Days.Day at 0x11ec54cd0>,
#  '2023-01-05|new delhi': <Days.Day at 0x11ec54dd0>,
#  '2023-01-06|new delhi': <Days.Day at 0x11ec54e90>,
#  '2023-01-07|new delhi': <Days.Day at 0x11ec54f50>,
#  '2023-01-08|new delhi': <Days.Day at 0x11ec55010>,
#  '2023-01-09|new delhi': <Days.Day at 0x11ec550d0>,
#  '2023-01-10|new delhi': <Days.Day at 0x11ec55190>,
#  '2023-01-11|new delhi': <Days.Day at 0x11ec55250>,
#  '2023-01-12|new delhi': <Days.Day at 0x11ec55310>,
#  '2023-01-13|new delhi': <Days.Day at 0x11ec553d0>,
#  '2023-01-14|new delhi': <Days.Day at 0x11ec55490>,
#  '2023-01-15|new delhi': <Days.Day at 0x11ec55510>,
#  '2023-01-16|new delhi': <Days.Day at 0x11ec55610>,
#  '2023-01-17|new delhi': <Days.Day at 0x11ec556d0>,
#  '2023-01-18|new delhi': <Days.Day at 0x11ec55790>,
#  '2023-01-19|new delhi': <Days.Day at 0x11ec55850>,
#  '2023-01-20|new delhi': <Days.Day at 0x11ec558d0>,
#  '2023-01-21|new delhi': <Days.Day at 0x11ec559d0>,
#  '2023-01-22|new delhi': <Days.Day at 0x11ec55a50>,
#  '2023-01-23|new delhi': <Days.Day at 0x11ec55b50>,
#  '2023-01-24|new delhi': <Days.Day at 0x11ec55c10>,
#  '2023-01-25|new delhi': <Days.Day at 0x11ec55cd0>,
#  '2023-01-26|new delhi': <Days.Day at 0x11ec55d90>,
#  '2023-01-27|new delhi': <Days.Day at 0x11ec55e10>,
#  '2023-01-28|new delhi': <Days.Day at 0x11ec55f10>,
#  '2023-01-29|new delhi': <Days.Day at 0x11ec55f90>,
#  '2023-01-30|new delhi': <Days.Day at 0x11ec56090>,
#  '2023-01-31|new delhi': <Days.Day at 0x11ec56150>}

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print("Average temperature for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getAvgTemperature(c), 2)}°C")
# Out:
# Average temperature for each city:
# Sydney : 30.87°C
# Tokyo : 10.81°C
# London : 8.48°C
# Berlin : 2.42°C
# New delhi : 24.1°C
# New york : 4.61°C
# Paris : 6.74°C
# Cairo : 23.87°C
# Beijing : 0.74°C
# Los angeles : 21.65°C

# %%
print("Total precitpitation for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getTotalPrecipitation(c), 2)}mm")
# Out:
# Total precitpitation for each city:
# Sydney : 2.9mm
# Tokyo : 3.7mm
# London : 137.0mm
# Berlin : 16.4mm
# New delhi : 3.6mm
# New york : 233.0mm
# Paris : 74.0mm
# Cairo : 0.0mm
# Beijing : 5.4mm
# Los angeles : 0.0mm

# %%
print("Minimum and Maximum wind speed for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : Min : {a.getMinWindSpeed(c)}km/h,\n{' '*len(f'{c.capitalize()} : ')}Max : {a.getMaxWindSpeed(c)}km/h")
# Out:
# Minimum and Maximum wind speed for each city:
# Sydney : Min : 14.0km/h,
#          Max : 20.0km/h
# Tokyo : Min : 10.0km/h,
#         Max : 22.0km/h
# London : Min : 12.0km/h,
#          Max : 25.0km/h
# Berlin : Min : 14.0km/h,
#          Max : 20.0km/h
# New delhi : Min : 10.0km/h,
#             Max : 22.0km/h
# New york : Min : 10.0km/h,
#            Max : 25.0km/h
# Paris : Min : 18.0km/h,
#         Max : 24.0km/h
# Cairo : Min : 14.0km/h,
#         Max : 20.0km/h
# Beijing : Min : 10.0km/h,
#           Max : 18.0km/h
# Los angeles : Min : 12.0km/h,
#               Max : 20.0km/h

# %%
a.plotTemperature(*list(a.cities))

# %%
a.plotAvgTemperature(*list(a.cities))

# %%
print(a.categorizeDay("New York", "2023-01-15"))
# Out:
# Cold

# %%
print(f"Coldest day in New York :\n{a.coldestDay('New York')}\nHotest day in New York :\n{a.hotestDay('New York')}")
# Out:
# Coldest day in New York :
# Date: 2023-01-08
# Location: new york
# Max Temp: 1.0
# Min Temp: -6.0
# Precipitation: 10.0
# Wind Speed: 18.0
# Humidity: 88.0
# Cloud Cover: 40.0
#
# Hotest day in New York :
# Date: 2023-01-03
# Location: new york
# Max Temp: 8.0
# Min Temp: 1.0
# Precipitation: 5.0
# Wind Speed: 15.0
# Humidity: 65.0
# Cloud Cover: 20.0

# %%
a.plotCorrelationMatrix("New York")

# %%
a.correlationMatrix("New York")
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
a.loadTemp("Paris_data_climate.txt")
a.plotCorrelationMatrix("New York")

# %%
a.plotCorrelationMatrix("New York", "Paris")

# %%
corr_NY = a.correlationMatrix("New York")
corr_NY
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
len(corr_NY)
# Out:
# 2

# %%
corr_NY[0].shape
# Out:
# (6, 6)

# %%
np.max(corr_NY[0][0][2:])
# Out:
# -0.16173547865568008

# %%
#index of where the np max is in the matrix
type(corr_NY[0])
# Out:
# numpy.ndarray

# %%
#where is the most correlated data (except minimum temp)
np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])
# Out:
# 4

# %%
corr_NY[1][np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])]
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('new york')
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('paris')
# Out:
# 'Max Temp'

# %%
a.getCityNames()
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print(a.coldestDay('los angeles'))
# Out:
# Date: 2023-01-06
# Location: los angeles
# Max Temp: 18.0
# Min Temp: 10.0
# Precipitation: 0.0
# Wind Speed: 12.0
# Humidity: 65.0
# Cloud Cover: 18.0

# %%
a.correlationMatrix('los angeles')
# Out:
# (array([[ 1.00000000e+00,  9.49994268e-01,  8.91688777e-01,
#           9.56731686e-04,  8.94116618e-02],
#         [ 9.49994268e-01,  1.00000000e+00,  8.73955359e-01,
#          -2.13100710e-02,  4.97777394e-02],
#         [ 8.91688777e-01,  8.73955359e-01,  1.00000000e+00,
#          -4.97281928e-02, -2.36833834e-02],
#         [ 9.56731686e-04, -2.13100710e-02, -4.97281928e-02,
#           1.00000000e+00,  9.44886482e-01],
#         [ 8.94116618e-02,  4.97777394e-02, -2.36833834e-02,
#           9.44886482e-01,  1.00000000e+00]]),
#  ['Max Temp', 'Min Temp', 'Wind Speed', 'Humidity', 'Cloud Cover'])

# %%
a.plotCorrelationMatrix('los angeles')

# %%
a.factors_max_temp('los angeles')
# Out:
# 'Max Temp'

# %%
for c in a.getCityNames():
    print(f"max temp in {c.capitalize()} is correlated to {a.factors_max_temp(c)}")
# Out:
# max temp in Sydney is correlated to Wind Speed
# max temp in Tokyo is correlated to Max Temp
# max temp in London is correlated to Max Temp
# max temp in Berlin is correlated to Wind Speed
# max temp in New delhi is correlated to Max Temp
# max temp in New york is correlated to Cloud Cover
# max temp in Paris is correlated to Max Temp
# max temp in Cairo is correlated to Cloud Cover
# max temp in Beijing is correlated to Wind Speed
# max temp in Los angeles is correlated to Max Temp

# %%
corr_TK = a.correlationMatrix('tokyo')
corr_TK
# Out:
# (array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#          -0.0532858 ],
#         [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#          -0.01049208],
#         [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#          -0.17628808],
#         [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#          -0.32054589],
#         [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#           0.24301979],
#         [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
corr_TK[0]
# Out:
# array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#         -0.0532858 ],
#        [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#         -0.01049208],
#        [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#         -0.17628808],
#        [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#         -0.32054589],
#        [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#          0.24301979],
#        [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#          1.        ]])

# %%
corr_TK[0][0, 2:]
# Out:
# array([ 0.15981949, -0.54018546, -0.14611816, -0.0532858 ])

# %%
np.max(corr_TK[0][0][2:])
# Out:
# 0.1598194875836748

# %%
corr_TK[1]
# Out:
# ['Max Temp',
#  'Min Temp',
#  'Wind Speed',
#  'Humidity',
#  'Cloud Cover',
#  'Precipitation']

# %%
np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))
# Out:
# (array([0]), array([2]))

# %%
np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:])))
# Out:
# 0

# %%
corr_TK[1][np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))[0])]
# Out:
# 'Max Temp'
