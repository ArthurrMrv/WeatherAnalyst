# %%
from Days import Days

# %%
import numpy as np

# %%
a = Days()
a.loadTemp("data_temperature.txt")
a.data
# Out:
# {'2023-01-01|new york': <Days.Day at 0x1203006d0>,
#  '2023-01-02|new york': <Days.Day at 0x120307390>,
#  '2023-01-03|new york': <Days.Day at 0x113df3b10>,
#  '2023-01-04|new york': <Days.Day at 0x120300b50>,
#  '2023-01-05|new york': <Days.Day at 0x1203018d0>,
#  '2023-01-06|new york': <Days.Day at 0x120301490>,
#  '2023-01-07|new york': <Days.Day at 0x120346f10>,
#  '2023-01-08|new york': <Days.Day at 0x120346d10>,
#  '2023-01-09|new york': <Days.Day at 0x1203452d0>,
#  '2023-01-10|new york': <Days.Day at 0x120344e90>,
#  '2023-01-11|new york': <Days.Day at 0x120344e50>,
#  '2023-01-12|new york': <Days.Day at 0x1203467d0>,
#  '2023-01-13|new york': <Days.Day at 0x120346ad0>,
#  '2023-01-14|new york': <Days.Day at 0x120346390>,
#  '2023-01-15|new york': <Days.Day at 0x120346410>,
#  '2023-01-16|new york': <Days.Day at 0x120346510>,
#  '2023-01-17|new york': <Days.Day at 0x120346590>,
#  '2023-01-18|new york': <Days.Day at 0x120346650>,
#  '2023-01-19|new york': <Days.Day at 0x120346710>,
#  '2023-01-20|new york': <Days.Day at 0x120346890>,
#  '2023-01-21|new york': <Days.Day at 0x120347010>,
#  '2023-01-22|new york': <Days.Day at 0x120346950>,
#  '2023-01-23|new york': <Days.Day at 0x120346f90>,
#  '2023-01-24|new york': <Days.Day at 0x120347210>,
#  '2023-01-25|new york': <Days.Day at 0x120347190>,
#  '2023-01-26|new york': <Days.Day at 0x120347310>,
#  '2023-01-27|new york': <Days.Day at 0x1203473d0>,
#  '2023-01-28|new york': <Days.Day at 0x120347490>,
#  '2023-01-29|new york': <Days.Day at 0x120347550>,
#  '2023-01-30|new york': <Days.Day at 0x120347650>,
#  '2023-01-31|new york': <Days.Day at 0x120347710>,
#  '2023-01-01|los angeles': <Days.Day at 0x120347a50>,
#  '2023-01-02|los angeles': <Days.Day at 0x120347850>,
#  '2023-01-03|los angeles': <Days.Day at 0x120347910>,
#  '2023-01-04|los angeles': <Days.Day at 0x1203479d0>,
#  '2023-01-05|los angeles': <Days.Day at 0x120347ad0>,
#  '2023-01-06|los angeles': <Days.Day at 0x120347b90>,
#  '2023-01-07|los angeles': <Days.Day at 0x120347c50>,
#  '2023-01-08|los angeles': <Days.Day at 0x120347d10>,
#  '2023-01-09|los angeles': <Days.Day at 0x120347dd0>,
#  '2023-01-10|los angeles': <Days.Day at 0x120347e90>,
#  '2023-01-11|los angeles': <Days.Day at 0x120347f50>,
#  '2023-01-12|los angeles': <Days.Day at 0x120360050>,
#  '2023-01-13|los angeles': <Days.Day at 0x120360110>,
#  '2023-01-14|los angeles': <Days.Day at 0x1203601d0>,
#  '2023-01-15|los angeles': <Days.Day at 0x120360290>,
#  '2023-01-16|los angeles': <Days.Day at 0x120360350>,
#  '2023-01-17|los angeles': <Days.Day at 0x120360410>,
#  '2023-01-18|los angeles': <Days.Day at 0x1203604d0>,
#  '2023-01-19|los angeles': <Days.Day at 0x120360590>,
#  '2023-01-20|los angeles': <Days.Day at 0x120360650>,
#  '2023-01-21|los angeles': <Days.Day at 0x120360710>,
#  '2023-01-22|los angeles': <Days.Day at 0x1203607d0>,
#  '2023-01-23|los angeles': <Days.Day at 0x120360890>,
#  '2023-01-24|los angeles': <Days.Day at 0x120360950>,
#  '2023-01-25|los angeles': <Days.Day at 0x120360a10>,
#  '2023-01-26|los angeles': <Days.Day at 0x120360ad0>,
#  '2023-01-27|los angeles': <Days.Day at 0x120360b90>,
#  '2023-01-28|los angeles': <Days.Day at 0x120360c50>,
#  '2023-01-29|los angeles': <Days.Day at 0x120360d10>,
#  '2023-01-30|los angeles': <Days.Day at 0x120360dd0>,
#  '2023-01-31|los angeles': <Days.Day at 0x120360e90>,
#  '2023-01-01|london': <Days.Day at 0x120361190>,
#  '2023-01-02|london': <Days.Day at 0x120361010>,
#  '2023-01-03|london': <Days.Day at 0x1203610d0>,
#  '2023-01-04|london': <Days.Day at 0x120361210>,
#  '2023-01-05|london': <Days.Day at 0x1203612d0>,
#  '2023-01-06|london': <Days.Day at 0x120361350>,
#  '2023-01-07|london': <Days.Day at 0x120361450>,
#  '2023-01-08|london': <Days.Day at 0x120361510>,
#  '2023-01-09|london': <Days.Day at 0x1203615d0>,
#  '2023-01-10|london': <Days.Day at 0x120361650>,
#  '2023-01-11|london': <Days.Day at 0x120361750>,
#  '2023-01-12|london': <Days.Day at 0x120361810>,
#  '2023-01-13|london': <Days.Day at 0x1203618d0>,
#  '2023-01-14|london': <Days.Day at 0x120361990>,
#  '2023-01-15|london': <Days.Day at 0x120361a10>,
#  '2023-01-16|london': <Days.Day at 0x120361ad0>,
#  '2023-01-17|london': <Days.Day at 0x120361bd0>,
#  '2023-01-18|london': <Days.Day at 0x120361c90>,
#  '2023-01-19|london': <Days.Day at 0x120361d50>,
#  '2023-01-20|london': <Days.Day at 0x120361e10>,
#  '2023-01-21|london': <Days.Day at 0x120361e90>,
#  '2023-01-22|london': <Days.Day at 0x120361f50>,
#  '2023-01-23|london': <Days.Day at 0x120362050>,
#  '2023-01-24|london': <Days.Day at 0x120362110>,
#  '2023-01-25|london': <Days.Day at 0x120362190>,
#  '2023-01-26|london': <Days.Day at 0x120362250>,
#  '2023-01-27|london': <Days.Day at 0x120362310>,
#  '2023-01-28|london': <Days.Day at 0x120362410>,
#  '2023-01-29|london': <Days.Day at 0x1203624d0>,
#  '2023-01-30|london': <Days.Day at 0x120362590>,
#  '2023-01-31|london': <Days.Day at 0x120362610>,
#  '2023-01-01|tokyo': <Days.Day at 0x120362990>,
#  '2023-01-02|tokyo': <Days.Day at 0x120362790>,
#  '2023-01-03|tokyo': <Days.Day at 0x120362890>,
#  '2023-01-04|tokyo': <Days.Day at 0x120362910>,
#  '2023-01-05|tokyo': <Days.Day at 0x120362a10>,
#  '2023-01-06|tokyo': <Days.Day at 0x120362ad0>,
#  '2023-01-07|tokyo': <Days.Day at 0x120362b90>,
#  '2023-01-08|tokyo': <Days.Day at 0x120362c50>,
#  '2023-01-09|tokyo': <Days.Day at 0x120362d10>,
#  '2023-01-10|tokyo': <Days.Day at 0x120362dd0>,
#  '2023-01-11|tokyo': <Days.Day at 0x120362e90>,
#  '2023-01-12|tokyo': <Days.Day at 0x120362f50>,
#  '2023-01-13|tokyo': <Days.Day at 0x120363010>,
#  '2023-01-14|tokyo': <Days.Day at 0x1203630d0>,
#  '2023-01-15|tokyo': <Days.Day at 0x1203631d0>,
#  '2023-01-16|tokyo': <Days.Day at 0x120363290>,
#  '2023-01-17|tokyo': <Days.Day at 0x120363350>,
#  '2023-01-18|tokyo': <Days.Day at 0x1203633d0>,
#  '2023-01-19|tokyo': <Days.Day at 0x120363490>,
#  '2023-01-20|tokyo': <Days.Day at 0x120363550>,
#  '2023-01-21|tokyo': <Days.Day at 0x120363610>,
#  '2023-01-22|tokyo': <Days.Day at 0x1203636d0>,
#  '2023-01-23|tokyo': <Days.Day at 0x120363790>,
#  '2023-01-24|tokyo': <Days.Day at 0x120363890>,
#  '2023-01-25|tokyo': <Days.Day at 0x120363910>,
#  '2023-01-26|tokyo': <Days.Day at 0x1203639d0>,
#  '2023-01-27|tokyo': <Days.Day at 0x120363a90>,
#  '2023-01-28|tokyo': <Days.Day at 0x120363b50>,
#  '2023-01-29|tokyo': <Days.Day at 0x120363c50>,
#  '2023-01-30|tokyo': <Days.Day at 0x120363cd0>,
#  '2023-01-31|tokyo': <Days.Day at 0x120363d90>,
#  '2023-01-01|beijing': <Days.Day at 0x120370110>,
#  '2023-01-02|beijing': <Days.Day at 0x120363f10>,
#  '2023-01-03|beijing': <Days.Day at 0x120363fd0>,
#  '2023-01-04|beijing': <Days.Day at 0x1203700d0>,
#  '2023-01-05|beijing': <Days.Day at 0x1203701d0>,
#  '2023-01-06|beijing': <Days.Day at 0x120370290>,
#  '2023-01-07|beijing': <Days.Day at 0x120370350>,
#  '2023-01-08|beijing': <Days.Day at 0x120370410>,
#  '2023-01-09|beijing': <Days.Day at 0x1203704d0>,
#  '2023-01-10|beijing': <Days.Day at 0x120370550>,
#  '2023-01-11|beijing': <Days.Day at 0x120370690>,
#  '2023-01-12|beijing': <Days.Day at 0x120370710>,
#  '2023-01-13|beijing': <Days.Day at 0x1203707d0>,
#  '2023-01-14|beijing': <Days.Day at 0x1203708d0>,
#  '2023-01-15|beijing': <Days.Day at 0x120370950>,
#  '2023-01-16|beijing': <Days.Day at 0x1203709d0>,
#  '2023-01-17|beijing': <Days.Day at 0x120370ad0>,
#  '2023-01-18|beijing': <Days.Day at 0x120370bd0>,
#  '2023-01-19|beijing': <Days.Day at 0x120370c90>,
#  '2023-01-20|beijing': <Days.Day at 0x120370d10>,
#  '2023-01-21|beijing': <Days.Day at 0x120370dd0>,
#  '2023-01-22|beijing': <Days.Day at 0x120370e90>,
#  '2023-01-23|beijing': <Days.Day at 0x120370f50>,
#  '2023-01-24|beijing': <Days.Day at 0x120371050>,
#  '2023-01-25|beijing': <Days.Day at 0x1203710d0>,
#  '2023-01-26|beijing': <Days.Day at 0x120371190>,
#  '2023-01-27|beijing': <Days.Day at 0x120371250>,
#  '2023-01-28|beijing': <Days.Day at 0x120371310>,
#  '2023-01-29|beijing': <Days.Day at 0x120371410>,
#  '2023-01-30|beijing': <Days.Day at 0x120371490>,
#  '2023-01-31|beijing': <Days.Day at 0x120371550>,
#  '2023-01-01|sydney': <Days.Day at 0x1203718d0>,
#  '2023-01-02|sydney': <Days.Day at 0x1203716d0>,
#  '2023-01-03|sydney': <Days.Day at 0x120371790>,
#  '2023-01-04|sydney': <Days.Day at 0x120371850>,
#  '2023-01-05|sydney': <Days.Day at 0x120371950>,
#  '2023-01-06|sydney': <Days.Day at 0x120371a10>,
#  '2023-01-07|sydney': <Days.Day at 0x120371ad0>,
#  '2023-01-08|sydney': <Days.Day at 0x120371b50>,
#  '2023-01-09|sydney': <Days.Day at 0x120371c50>,
#  '2023-01-10|sydney': <Days.Day at 0x120371d10>,
#  '2023-01-11|sydney': <Days.Day at 0x120371dd0>,
#  '2023-01-12|sydney': <Days.Day at 0x120371e90>,
#  '2023-01-13|sydney': <Days.Day at 0x120371f10>,
#  '2023-01-14|sydney': <Days.Day at 0x120372010>,
#  '2023-01-15|sydney': <Days.Day at 0x1203720d0>,
#  '2023-01-16|sydney': <Days.Day at 0x120372190>,
#  '2023-01-17|sydney': <Days.Day at 0x120372250>,
#  '2023-01-18|sydney': <Days.Day at 0x120372310>,
#  '2023-01-19|sydney': <Days.Day at 0x1203723d0>,
#  '2023-01-20|sydney': <Days.Day at 0x120372490>,
#  '2023-01-21|sydney': <Days.Day at 0x120372550>,
#  '2023-01-22|sydney': <Days.Day at 0x120372610>,
#  '2023-01-23|sydney': <Days.Day at 0x1203726d0>,
#  '2023-01-24|sydney': <Days.Day at 0x120372790>,
#  '2023-01-25|sydney': <Days.Day at 0x120372850>,
#  '2023-01-26|sydney': <Days.Day at 0x120372910>,
#  '2023-01-27|sydney': <Days.Day at 0x1203729d0>,
#  '2023-01-28|sydney': <Days.Day at 0x120372a90>,
#  '2023-01-29|sydney': <Days.Day at 0x120372b50>,
#  '2023-01-30|sydney': <Days.Day at 0x120372c10>,
#  '2023-01-31|sydney': <Days.Day at 0x120372cd0>,
#  '2023-01-01|paris': <Days.Day at 0x120372fd0>,
#  '2023-01-02|paris': <Days.Day at 0x120372e50>,
#  '2023-01-03|paris': <Days.Day at 0x120372f10>,
#  '2023-01-04|paris': <Days.Day at 0x120373050>,
#  '2023-01-05|paris': <Days.Day at 0x1203730d0>,
#  '2023-01-06|paris': <Days.Day at 0x1203731d0>,
#  '2023-01-07|paris': <Days.Day at 0x120373290>,
#  '2023-01-08|paris': <Days.Day at 0x120373350>,
#  '2023-01-09|paris': <Days.Day at 0x120373410>,
#  '2023-01-10|paris': <Days.Day at 0x120373490>,
#  '2023-01-11|paris': <Days.Day at 0x120373590>,
#  '2023-01-12|paris': <Days.Day at 0x120373650>,
#  '2023-01-13|paris': <Days.Day at 0x120373710>,
#  '2023-01-14|paris': <Days.Day at 0x1203737d0>,
#  '2023-01-15|paris': <Days.Day at 0x120373890>,
#  '2023-01-16|paris': <Days.Day at 0x120373950>,
#  '2023-01-17|paris': <Days.Day at 0x120373a10>,
#  '2023-01-18|paris': <Days.Day at 0x120373ad0>,
#  '2023-01-19|paris': <Days.Day at 0x120373b90>,
#  '2023-01-20|paris': <Days.Day at 0x120373c50>,
#  '2023-01-21|paris': <Days.Day at 0x120373d10>,
#  '2023-01-22|paris': <Days.Day at 0x120373dd0>,
#  '2023-01-23|paris': <Days.Day at 0x120373e90>,
#  '2023-01-24|paris': <Days.Day at 0x120373f50>,
#  '2023-01-25|paris': <Days.Day at 0x120378050>,
#  '2023-01-26|paris': <Days.Day at 0x120378110>,
#  '2023-01-27|paris': <Days.Day at 0x1203781d0>,
#  '2023-01-28|paris': <Days.Day at 0x120378290>,
#  '2023-01-29|paris': <Days.Day at 0x120378350>,
#  '2023-01-30|paris': <Days.Day at 0x120378410>,
#  '2023-01-31|paris': <Days.Day at 0x1203784d0>,
#  '2023-01-01|berlin': <Days.Day at 0x1203787d0>,
#  '2023-01-02|berlin': <Days.Day at 0x120378650>,
#  '2023-01-03|berlin': <Days.Day at 0x120378710>,
#  '2023-01-04|berlin': <Days.Day at 0x120378790>,
#  '2023-01-05|berlin': <Days.Day at 0x120378890>,
#  '2023-01-06|berlin': <Days.Day at 0x120378990>,
#  '2023-01-07|berlin': <Days.Day at 0x120378a10>,
#  '2023-01-08|berlin': <Days.Day at 0x120378ad0>,
#  '2023-01-09|berlin': <Days.Day at 0x120378b90>,
#  '2023-01-10|berlin': <Days.Day at 0x120378c10>,
#  '2023-01-11|berlin': <Days.Day at 0x120378d10>,
#  '2023-01-12|berlin': <Days.Day at 0x120378dd0>,
#  '2023-01-13|berlin': <Days.Day at 0x120378ed0>,
#  '2023-01-14|berlin': <Days.Day at 0x120378f90>,
#  '2023-01-15|berlin': <Days.Day at 0x120379010>,
#  '2023-01-16|berlin': <Days.Day at 0x1203790d0>,
#  '2023-01-17|berlin': <Days.Day at 0x1203791d0>,
#  '2023-01-18|berlin': <Days.Day at 0x120379250>,
#  '2023-01-19|berlin': <Days.Day at 0x120379350>,
#  '2023-01-20|berlin': <Days.Day at 0x1203793d0>,
#  '2023-01-21|berlin': <Days.Day at 0x120379490>,
#  '2023-01-22|berlin': <Days.Day at 0x120379550>,
#  '2023-01-23|berlin': <Days.Day at 0x120379650>,
#  '2023-01-24|berlin': <Days.Day at 0x120379710>,
#  '2023-01-25|berlin': <Days.Day at 0x1203797d0>,
#  '2023-01-26|berlin': <Days.Day at 0x120379850>,
#  '2023-01-27|berlin': <Days.Day at 0x120379910>,
#  '2023-01-28|berlin': <Days.Day at 0x1203799d0>,
#  '2023-01-29|berlin': <Days.Day at 0x120379ad0>,
#  '2023-01-30|berlin': <Days.Day at 0x120379b90>,
#  '2023-01-31|berlin': <Days.Day at 0x120379c50>,
#  '2023-01-01|cairo': <Days.Day at 0x120379f50>,
#  '2023-01-02|cairo': <Days.Day at 0x120379d90>,
#  '2023-01-03|cairo': <Days.Day at 0x120379e90>,
#  '2023-01-04|cairo': <Days.Day at 0x120379f10>,
#  '2023-01-05|cairo': <Days.Day at 0x12037a010>,
#  '2023-01-06|cairo': <Days.Day at 0x12037a0d0>,
#  '2023-01-07|cairo': <Days.Day at 0x12037a190>,
#  '2023-01-08|cairo': <Days.Day at 0x12037a250>,
#  '2023-01-09|cairo': <Days.Day at 0x12037a310>,
#  '2023-01-10|cairo': <Days.Day at 0x12037a3d0>,
#  '2023-01-11|cairo': <Days.Day at 0x12037a490>,
#  '2023-01-12|cairo': <Days.Day at 0x12037a550>,
#  '2023-01-13|cairo': <Days.Day at 0x12037a610>,
#  '2023-01-14|cairo': <Days.Day at 0x12037a6d0>,
#  '2023-01-15|cairo': <Days.Day at 0x12037a790>,
#  '2023-01-16|cairo': <Days.Day at 0x12037a850>,
#  '2023-01-17|cairo': <Days.Day at 0x12037a910>,
#  '2023-01-18|cairo': <Days.Day at 0x12037a9d0>,
#  '2023-01-19|cairo': <Days.Day at 0x12037aa90>,
#  '2023-01-20|cairo': <Days.Day at 0x12037ab50>,
#  '2023-01-21|cairo': <Days.Day at 0x12037ac10>,
#  '2023-01-22|cairo': <Days.Day at 0x12037acd0>,
#  '2023-01-23|cairo': <Days.Day at 0x12037ad90>,
#  '2023-01-24|cairo': <Days.Day at 0x12037ae50>,
#  '2023-01-25|cairo': <Days.Day at 0x12037af10>,
#  '2023-01-26|cairo': <Days.Day at 0x12037afd0>,
#  '2023-01-27|cairo': <Days.Day at 0x12037b090>,
#  '2023-01-28|cairo': <Days.Day at 0x12037b150>,
#  '2023-01-29|cairo': <Days.Day at 0x12037b210>,
#  '2023-01-30|cairo': <Days.Day at 0x12037b2d0>,
#  '2023-01-31|cairo': <Days.Day at 0x12037b390>,
#  '2023-01-01|new delhi': <Days.Day at 0x12037b710>,
#  '2023-01-02|new delhi': <Days.Day at 0x12037b510>,
#  '2023-01-03|new delhi': <Days.Day at 0x12037b5d0>,
#  '2023-01-04|new delhi': <Days.Day at 0x12037b690>,
#  '2023-01-05|new delhi': <Days.Day at 0x12037b790>,
#  '2023-01-06|new delhi': <Days.Day at 0x12037b850>,
#  '2023-01-07|new delhi': <Days.Day at 0x12037b910>,
#  '2023-01-08|new delhi': <Days.Day at 0x12037b9d0>,
#  '2023-01-09|new delhi': <Days.Day at 0x12037ba90>,
#  '2023-01-10|new delhi': <Days.Day at 0x12037bb50>,
#  '2023-01-11|new delhi': <Days.Day at 0x12037bc10>,
#  '2023-01-12|new delhi': <Days.Day at 0x12037bcd0>,
#  '2023-01-13|new delhi': <Days.Day at 0x12037bd90>,
#  '2023-01-14|new delhi': <Days.Day at 0x12037be50>,
#  '2023-01-15|new delhi': <Days.Day at 0x12037bed0>,
#  '2023-01-16|new delhi': <Days.Day at 0x12037bfd0>,
#  '2023-01-17|new delhi': <Days.Day at 0x1203880d0>,
#  '2023-01-18|new delhi': <Days.Day at 0x120388190>,
#  '2023-01-19|new delhi': <Days.Day at 0x120388250>,
#  '2023-01-20|new delhi': <Days.Day at 0x1203882d0>,
#  '2023-01-21|new delhi': <Days.Day at 0x1203883d0>,
#  '2023-01-22|new delhi': <Days.Day at 0x120388450>,
#  '2023-01-23|new delhi': <Days.Day at 0x120388550>,
#  '2023-01-24|new delhi': <Days.Day at 0x120388610>,
#  '2023-01-25|new delhi': <Days.Day at 0x1203886d0>,
#  '2023-01-26|new delhi': <Days.Day at 0x120388790>,
#  '2023-01-27|new delhi': <Days.Day at 0x120388810>,
#  '2023-01-28|new delhi': <Days.Day at 0x120388910>,
#  '2023-01-29|new delhi': <Days.Day at 0x120388990>,
#  '2023-01-30|new delhi': <Days.Day at 0x120388a90>,
#  '2023-01-31|new delhi': <Days.Day at 0x120388b50>}

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print("Average temperature for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getAvgTemperature(c), 2)}°C")
# Out:
# Average temperature for each city:
# Beijing : 0.74°C
# New york : 4.61°C
# Tokyo : 10.81°C
# Sydney : 30.87°C
# London : 8.48°C
# Paris : 6.74°C
# Cairo : 23.87°C
# Berlin : 2.42°C
# Los angeles : 21.65°C
# New delhi : 24.1°C

# %%
print("Total precitpitation for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : {round(a.getTotalPrecipitation(c), 2)}mm")
# Out:
# Total precitpitation for each city:
# Beijing : 5.4mm
# New york : 233.0mm
# Tokyo : 3.7mm
# Sydney : 2.9mm
# London : 137.0mm
# Paris : 74.0mm
# Cairo : 0.0mm
# Berlin : 16.4mm
# Los angeles : 0.0mm
# New delhi : 3.6mm

# %%
print("Minimum and Maximum wind speed for each city:")
for c in a.cities:
    print(f"{c.capitalize()} : Min : {a.getMinWindSpeed(c)}km/h,\n{' '*len(f'{c.capitalize()} : ')}Max : {a.getMaxWindSpeed(c)}km/h")
# Out:
# Minimum and Maximum wind speed for each city:
# Beijing : Min : 10.0km/h,
#           Max : 18.0km/h
# New york : Min : 10.0km/h,
#            Max : 25.0km/h
# Tokyo : Min : 10.0km/h,
#         Max : 22.0km/h
# Sydney : Min : 14.0km/h,
#          Max : 20.0km/h
# London : Min : 12.0km/h,
#          Max : 25.0km/h
# Paris : Min : 18.0km/h,
#         Max : 24.0km/h
# Cairo : Min : 14.0km/h,
#         Max : 20.0km/h
# Berlin : Min : 14.0km/h,
#          Max : 20.0km/h
# Los angeles : Min : 12.0km/h,
#               Max : 20.0km/h
# New delhi : Min : 10.0km/h,
#             Max : 22.0km/h

# %%
a.plotTemperature(*list(a.cities))

# %%
a.plotAvgTemperature(*list(a.cities))

# %%
print(a.categorizeDay("New York", "2023-01-15"))
# Out:
# Cold

# %%
print(a.getDay("2023-01-15", "new york"))

# %%
print(f"Coldest day in New York :\n{a.coldestDay('New York')}\nHotest day in New York :\n{a.hotestDay('New York')}")
# Out:
# Coldest day in New York :
# Date: 2023-01-08
# Location: new york
# Max Temp: 1.0
# Min Temp: -6.0
# Precipitation: 10.0
# Wind Speed: 18.0
# Humidity: 88.0
# Cloud Cover: 40.0
#
# Hotest day in New York :
# Date: 2023-01-03
# Location: new york
# Max Temp: 8.0
# Min Temp: 1.0
# Precipitation: 5.0
# Wind Speed: 15.0
# Humidity: 65.0
# Cloud Cover: 20.0

# %%
a.plotCorrelationMatrix("New York")

# %%
a.correlationMatrix("New York")
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
a.loadTemp("Paris_data_climate.txt")
a.plotCorrelationMatrix("New York")

# %%
a.plotCorrelationMatrix("New York", "Paris")

# %%
corr_NY = a.correlationMatrix("New York")
corr_NY
# Out:
# (array([[ 1.        ,  0.98754809, -0.68241852, -0.64267025, -0.16173548,
#          -0.55057438],
#         [ 0.98754809,  1.        , -0.67108632, -0.66524463, -0.15621472,
#          -0.51438853],
#         [-0.68241852, -0.67108632,  1.        ,  0.11762976, -0.34936123,
#           0.79052773],
#         [-0.64267025, -0.66524463,  0.11762976,  1.        ,  0.58420548,
#           0.02322061],
#         [-0.16173548, -0.15621472, -0.34936123,  0.58420548,  1.        ,
#          -0.41276115],
#         [-0.55057438, -0.51438853,  0.79052773,  0.02322061, -0.41276115,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
len(corr_NY)
# Out:
# 2

# %%
corr_NY[0].shape
# Out:
# (6, 6)

# %%
np.max(corr_NY[0][0][2:])
# Out:
# -0.16173547865568008

# %%
#index of where the np max is in the matrix
type(corr_NY[0])
# Out:
# numpy.ndarray

# %%
#where is the most correlated data (except minimum temp)
np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])
# Out:
# 4

# %%
corr_NY[1][np.max(np.where(corr_NY[0] == np.max(corr_NY[0][0][2:]))[0])]
# Out:
# 'Cloud Cover'

# %%
a.factors_max_temp('new york')
# Out:
# 'Wind Speed'

# %%
a.factors_max_temp('paris')
# Out:
# 'Humidity'

# %%
a.getCityNames()
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
print(a.coldestDay('los angeles'))
# Out:
# Date: 2023-01-06
# Location: los angeles
# Max Temp: 18.0
# Min Temp: 10.0
# Precipitation: 0.0
# Wind Speed: 12.0
# Humidity: 65.0
# Cloud Cover: 18.0

# %%
a.correlationMatrix('los angeles')
# Out:
# (array([[ 1.00000000e+00,  9.49994268e-01,  8.91688777e-01,
#           9.56731686e-04,  8.94116618e-02],
#         [ 9.49994268e-01,  1.00000000e+00,  8.73955359e-01,
#          -2.13100710e-02,  4.97777394e-02],
#         [ 8.91688777e-01,  8.73955359e-01,  1.00000000e+00,
#          -4.97281928e-02, -2.36833834e-02],
#         [ 9.56731686e-04, -2.13100710e-02, -4.97281928e-02,
#           1.00000000e+00,  9.44886482e-01],
#         [ 8.94116618e-02,  4.97777394e-02, -2.36833834e-02,
#           9.44886482e-01,  1.00000000e+00]]),
#  ['Max Temp', 'Min Temp', 'Wind Speed', 'Humidity', 'Cloud Cover'])

# %%
a.plotCorrelationMatrix('los angeles')

# %%
a.factors_max_temp('los angeles')
# Out:
# 'Wind Speed'

# %%
for c in a.getCityNames():
    print(f"max temp in {c.capitalize()} is correlated to {a.factors_max_temp(c)}")
# Out:
# max temp in Beijing is correlated to Cloud Cover
# max temp in London is correlated to Precipitation
# max temp in New delhi is correlated to Humidity
# max temp in Los angeles is correlated to Wind Speed
# max temp in Berlin is correlated to Humidity
# max temp in Sydney is correlated to Humidity
# max temp in New york is correlated to Wind Speed
# max temp in Paris is correlated to Humidity
# max temp in Cairo is correlated to Cloud Cover
# max temp in Tokyo is correlated to Humidity

# %%
corr_TK = a.correlationMatrix('tokyo')
corr_TK
# Out:
# (array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#          -0.0532858 ],
#         [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#          -0.01049208],
#         [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#          -0.17628808],
#         [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#          -0.32054589],
#         [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#           0.24301979],
#         [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#           1.        ]]),
#  ['Max Temp',
#   'Min Temp',
#   'Wind Speed',
#   'Humidity',
#   'Cloud Cover',
#   'Precipitation'])

# %%
corr_TK[0]
# Out:
# array([[ 1.        ,  0.9774873 ,  0.15981949, -0.54018546, -0.14611816,
#         -0.0532858 ],
#        [ 0.9774873 ,  1.        ,  0.16221013, -0.48145988, -0.12401672,
#         -0.01049208],
#        [ 0.15981949,  0.16221013,  1.        ,  0.1666737 ,  0.22757284,
#         -0.17628808],
#        [-0.54018546, -0.48145988,  0.1666737 ,  1.        ,  0.30123969,
#         -0.32054589],
#        [-0.14611816, -0.12401672,  0.22757284,  0.30123969,  1.        ,
#          0.24301979],
#        [-0.0532858 , -0.01049208, -0.17628808, -0.32054589,  0.24301979,
#          1.        ]])

# %%
np.abs
# Out:
# <ufunc 'absolute'>

# %%
corr_TK[0][0, 2:]
# Out:
# array([ 0.15981949, -0.54018546, -0.14611816, -0.0532858 ])

# %%
np.max(corr_TK[0][0][2:])
# Out:
# 0.1598194875836748

# %%
corr_TK[1]
# Out:
# ['Max Temp',
#  'Min Temp',
#  'Wind Speed',
#  'Humidity',
#  'Cloud Cover',
#  'Precipitation']

# %%
np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))
# Out:
# (array([0]), array([2]))

# %%
np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:])))
# Out:
# 2

# %%
corr_TK[1][np.max(np.where(corr_TK[0] == np.max(corr_TK[0][0][2:]))[0])]
# Out:
# 'Max Temp'

# %%
print(a.coldestDay('Paris'))
# Out:
# Date: 2023-01-02
# Location: paris
# Max Temp: 4.0
# Min Temp: -2.0
# Precipitation: 5.0
# Wind Speed: 18.0
# Humidity: 92.0
# Cloud Cover: 80.0
# CO2 Levels: 415.0
# Sea Level Rise: 3.0

# %%
a.getDayArttibutes()
# Out:
# ['date',
#  'location',
#  'maxTemp',
#  'minTemp',
#  'precipitation',
#  'windSpeed',
#  'humidity',
#  'cloudCover',
#  'co2Levels',
#  'seaLevelRise']

# %%
a.compare_variables('humidity', 'windSpeed', 'Paris', 'tokyo', "hello")
# Out:
# Error: hello is not a valid city name

# %%
a.compare_variables('humidity', 'windSpeed', 'Paris')

# %%
a.compare_variables('humidity', 'windSpeed', *a.getCityNames())

# %%
a.cities
# Out:
# {'beijing',
#  'berlin',
#  'cairo',
#  'london',
#  'los angeles',
#  'new delhi',
#  'new york',
#  'paris',
#  'sydney',
#  'tokyo'}

# %%
a.compare_variables('seaLevelRise', 'windSpeed', 'london')

# %%
a.compare_variables('maxTemp', 'precipitation', 'Paris', 'tokyo', "hello")
# Out:
# Error: hello is not a valid city name
